# %% [markdown]
# ##### Local Environment Setup

# %%
import os
import sys
# Set JAVA env variable
os.environ["JAVA_HOME"] = r"C:\Program Files\Eclipse Adoptium\jdk-11.0.26.4-hotspot"
# Set Hadoop environment variables 
os.environ['HADOOP_HOME'] = r'C:\hadoop'
os.environ['PATH'] = os.environ['HADOOP_HOME'] + r'\bin;' + os.environ['PATH']
# Set the Python executable path explicitly
os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

# Get Pipeline Tools Path
sys.path.append(R'C:\GitHub\Tools\de')

# %% [markdown]
# ##### Libraries

# %%
import time
import logging
from datetime import datetime

import numpy as np
import pandas as pd

from typing import Dict


from pyspark.sql import SparkSession
from pyspark.sql import DataFrame
from pyspark.sql import functions as F
from pyspark.sql.types import (StructType, StructField, StringType, 
                            DoubleType, IntegerType, TimestampType, 
                            DateType)
from delta.tables import DeltaTable

# %%
from de_pipeline_tools import *

# %% [markdown]
# ##### Spark Session

# %%
spark = initialize_local_spark_delta_lake("Financial Data Pipeline")
# Out:
# 2025-04-24 15:43:32,260 - INFO - ---Spark session initialized with Delta Lake support---

# %%
# Create a database in the Hive warehouse if doesn't exist
spark.sql("CREATE DATABASE IF NOT EXISTS de_pipelines LOCATION 'C:/hive-warehouse/de_pipelines'")
# Out:
# DataFrame[]

# %% [markdown]
# ## SCD Type 1:
# ##### Intial Creation (Overwrite)

# %% [markdown]
# ##### Inputs/Outputs

# %%
# Intial Creation
data_dir = "../../data"
file_list = [
    "financial_transactions_20250409_113413.csv",
    "financial_transactions_20250410_113413.csv"
]

abs_file_list = []
for file in file_list:
    # Join data_dir with filename
    relative_path = os.path.join(data_dir, file)
    # Convert to absolute path
    abs_path = os.path.abspath(relative_path)
    abs_file_list.append(abs_path)

bronze_table = 'de_pipelines.financial_osb_bronze_type1'
silver_table = 'de_pipelines.financial_osb_silver_type1'
gold_table   = 'de_pipelines.financial_osb_gold_type1'

# %%
def get_schema():
    return StructType([
    StructField("transaction_id", StringType(), False),
    StructField("timestamp", StringType(), True), #load in as string type, handle in silver step     
    StructField("customer_id", StringType(), True),      
    StructField("account_number", StringType(), True),   
    StructField("transaction_type", StringType(), True), 
    StructField("amount", DoubleType(), True),           
    StructField("currency", StringType(), True),         
    StructField("balance_after", DoubleType(), True),    
    StructField("status", StringType(), True),           
    StructField("merchant", StringType(), True),         
    StructField("category", StringType(), True),         
    StructField("location", StringType(), True)          
])

# %% [markdown]
# #### Define: Validation Rules, Transformations, Write Executions

# %%
def bronze_writer(df: DataFrame, table_name, bronze_transform=None):
    """Write data to bronze layer with optional transformation"""
    try:
        if bronze_transform:
            logger.info("Applying transformation within bronze writer")
            transformed_df = bronze_transform(df)
        else:
            transformed_df = df
            
        (transformed_df.write
        .format("delta")
        .mode("overwrite")
        .option("overwriteSchema", "true")
        .saveAsTable(table_name)
        )
    
    except Exception as e:
        logger.error(f"Error in bronze_writer: {str(e)}")
        raise


    return None

# %%
# Define bronze validation rules
bronze_validation_rules = [
    {
        "name": "has_transaction_id",
        "condition": "transaction_id IS NOT NULL",
        "description": "Transaction ID must be present"
    },
    {
        "name": "valid_amount",
        "condition": "amount IS NOT NULL AND amount > 0",
        "description": "Amount must be positive if not null"
    },
    {
        "name": "valid_timestamp",
        "condition": "timestamp IS NOT NULL AND timestamp <= current_timestamp()",
        "description": "Timestamp must not be in the future"
    }
]

# %%
def silver_transform(df:DataFrame) -> DataFrame:

    # Clean any non-timestamp characters first
    df = df.withColumn(
        "timestamp", 
        F.regexp_replace(F.col("timestamp"), "[^0-9\\-: ]", "")
    )

    # Cast to timestamp type
    df = df.withColumn("timestamp", F.col("timestamp").cast("timestamp"))

    # Remove duplicates
    df = df.dropDuplicates(subset=["transaction_id","timestamp"])

    # Standardize Data
    df = (df
            .withColumn("amount", F.abs(F.col("amount")))
            .withColumn("transaction_type", F.lower(F.col("transaction_type")))
            .withColumn("category", F.lower(F.col("category")))
            .withColumn("status", F.lower(F.col("status")))
    )

    # Filter Data
    # Address bronze layer data validation check concerns
    df = df.filter(
                    (F.col('transaction_id').isNotNull()) # transaction id must exist
                    & (F.col('account_number').isNotNull()) # account number must exist
                    & (F.col('amount') > 0) # amount must be positive
                    & ((F.col('timestamp') <= F.current_date()) # must be <= current date
                    |(F.col('timestamp').isNull()))# or must be Null, no future timestamps
    ) 
    
    # Split timestamp into date and time and year_month for paritioning
    df = (df
            .withColumn("transaction_date", F.to_date("timestamp"))
            .withColumn("transaction_time", F.date_format("timestamp", "HH:mm:ss"))
            .withColumn("year_month", F.date_format(F.col("transaction_date"), "yyyy-MM"))
    )
    
    # Add processing timestamp for bookkeeping
    df = (df
            .withColumn("processing_timestamp", F.current_timestamp())
    )

    return df

# %%
def silver_writer(df: DataFrame, table_name, silver_transform=None):
    """Write data to silver layer with optional transformation"""
    try:
        if silver_transform:
            logger.info("Applying transformation within silver writer")
            transformed_df = silver_transform(df)
        else:
            transformed_df = df
            
        (transformed_df.write
        .format("delta")
        .mode("overwrite")
        .option("overwriteSchema", "true")
        .partitionBy("year_month")
        .saveAsTable(table_name)
        )
        
    except Exception as e:
        logger.error(f"Error in silver_writer: {str(e)}")
        raise
    


    return None

# %%
# Define silver validation rules
silver_validation_rules = [
    {
        "name": "valid_transaction_type",
        "condition": "transaction_type IN ('debit', 'credit', 'transfer', 'payment', 'withdrawal', 'deposit') OR transaction_type IS NULL",
        "description": "Transaction type must be one of the valid types"
    },
    {
        "name": "valid_status",
        "condition": "status IN ('completed', 'pending', 'failed', 'cancelled', 'refunded') OR status IS NULL",
        "description": "Status must be one of the valid statuses"
    },
    {
        "name": "valid_currency",
        "condition": "currency IS NOT NULL AND length(currency) = 3",
        "description": "Currency code should be 3 characters if present"
    },
    {
        "name": "valid_timestamp",
        "condition": "timestamp IS NOT NULL AND timestamp <= current_timestamp()",
        "description": "Timestamp must not be NULL or in the future"
    }
]

# %%
def gold_transform(df:DataFrame) -> Dict:
    gold_dfs = {}

    # Gold aggregation 1: Daily summary by category
    daily_category = (df
        .groupBy("transaction_date", "category")
        .agg(
            F.count("transaction_id").alias("transaction_count"),
            F.sum("amount").alias("total_amount"),
            F.avg("amount").alias("avg_amount"),
            F.min("amount").alias("min_amount"),
            F.max("amount").alias("max_amount"),
            F.countDistinct("customer_id").alias("unique_customers")
        )
        .withColumn("processing_timestamp", F.current_timestamp())
    )
    
    gold_dfs["daily_category"] = daily_category
    
    # Gold aggregation 2: Customer summary
    customer_summary = (df
        .groupBy("customer_id")
        .agg(
            F.count("transaction_id").alias("transaction_count"),
            F.sum("amount").alias("total_amount"),
            F.avg("amount").alias("avg_amount"),
            F.min("transaction_date").alias("first_transaction_date"),
            F.max("transaction_date").alias("last_transaction_date"),
            F.approx_count_distinct("category").alias("category_count")
        )
        .withColumn("processing_timestamp", F.current_timestamp())
        .withColumn("days_since_last_transaction", 
                    F.datediff(F.current_date(), F.col("last_transaction_date")))
    )
    
    gold_dfs["customer_summary"] = customer_summary
    
    # Gold aggregation 3: Transaction type summary
    transaction_type_summary = (df
        .groupBy("transaction_type")
        .agg(
            F.count("transaction_id").alias("transaction_count"),
            F.sum("amount").alias("total_amount"),
            F.avg("amount").alias("avg_amount")
        )
        .withColumn("processing_timestamp", F.current_timestamp())
    )
    
    gold_dfs["transaction_type_summary"] = transaction_type_summary

    return gold_dfs

# %%
def gold_writer(df: DataFrame, table_name: str):

    (df.write
        .format("delta")
        .mode("overwrite")
        .option("overwriteSchema", "true")
        .saveAsTable(table_name)
    )

    return None

# %%
# Define gold validation rules
gold_validation_rules = [
    {
        "name": "positive_transaction_counts",
        "condition": "transaction_count > 0",
        "description": "Transaction counts should be positive"
    },
    {
        "name": "valid_total_amounts",
        "condition": "total_amount >= 0",
        "description": "Total amounts should not be negative"
    }
]

# %% [markdown]
# ### Running Full Batch Pipeline

# %%
run_batch_de_pipeline(spark, 'csv', abs_file_list, get_schema(), 
                     bronze_table, silver_table, gold_table, 
                     bronze_transform=None, silver_transform=silver_transform, gold_transform=gold_transform,
                     bronze_writer=bronze_writer, silver_writer=silver_writer, gold_writer=gold_writer,
                     bronze_validation_rules=bronze_validation_rules, 
                     silver_validation_rules=silver_validation_rules, 
                     gold_validation_rules=gold_validation_rules,
                     pipeline_name='Financial_DE_Pipeline')
# Out:
# 2025-04-24 15:43:54,487 - INFO - --Starting data pipeline execution with ID: Financial_DE_Pipeline_20250424_154354--
# 2025-04-24 15:43:54,489 - INFO - Starting bronze layer processing
# 2025-04-24 15:43:55,189 - INFO - Successfully read CSV data from:
#   - c:\GitHub\DE_Pipelines\data\financial_transactions_20250409_113413.csv
#   - c:\GitHub\DE_Pipelines\data\financial_transactions_20250410_113413.csv
# 2025-04-24 15:43:55,190 - INFO - Writing to bronze table: de_pipelines.financial_osb_bronze_type1
# 2025-04-24 15:44:27,379 - INFO - Successfully wrote to bronze table: de_pipelines.financial_osb_bronze_type1
# 2025-04-24 15:44:27,384 - INFO - Write Metrics:
# [
#   {
#     "numOutputRows": "1000",
#     "numOutputBytes": "52336",
#     "numFiles": "2"
#   }
# ]
# 2025-04-24 15:44:28,639 - INFO - Running data quality checks for bronze layer
# 2025-04-24 15:44:34,219 - INFO - Data Quality Metrics for bronze layer:
# 2025-04-24 15:44:34,221 - INFO -   - Shape: [15,1000] (approx. row count)
# 2025-04-24 15:44:34,222 - INFO -   - Schema:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- account_number: string (nullable = true)
#  |-- transaction_type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- balance_after: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#  |-- source_file: string (nullable = false)
#  |-- batch_id: string (nullable = false)
#
# 2025-04-24 15:44:34,225 - INFO -   - Sample size: 40
# 2025-04-24 15:44:34,228 - WARNING -   - Columns with high null percentages: {'merchant': 55.00000000000001, 'category': 57.49999999999999}
# 2025-04-24 15:44:34,230 - INFO - Validating dataframe with 3 rules
# 2025-04-24 15:44:34,770 - INFO - Validation rule 'has_transaction_id' PASSED - 0 records (0.00%) failed
# 2025-04-24 15:44:35,001 - INFO - Validation rule 'valid_amount' FAILED - 24 records (60.00%) failed
# 2025-04-24 15:44:35,271 - INFO - Validation rule 'valid_timestamp' FAILED - 1 records (2.50%) failed
# 2025-04-24 15:44:35,275 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250424_154354",
#   "layer": "bronze",
#   "version": 3,
#   "timestamp": "2025-04-24T15:44:35.274161",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "bronze",
#       "shape": "[15,1000] (approx. row count)",
#       "schema": "root\n |-- transaction_id: string (nullable = true)\n |-- timestamp: string (nullable = true)\n |-- customer_id: string (nullable = true)\n |-- account_number: string (nullable = true)\n |-- transaction_type: string (nullable = true)\n |-- amount: double (nullable = true)\n |-- currency: string (nullable = true)\n |-- balance_after: double (nullable = true)\n |-- status: string (nullable = true)\n |-- merchant: string (nullable = true)\n |-- category: string (nullable = true)\n |-- location: string (nullable = true)\n |-- ingestion_timestamp: timestamp (nullable = false)\n |-- source_file: string (nullable = false)\n |-- batch_id: string (nullable = false)\n",
#       "sample_size": 40,
#       "null_percentages": {
#         "transaction_id": 0.0,
#         "timestamp": 2.5,
#         "customer_id": 0.0,
#         "account_number": 2.5,
#         "transaction_type": 5.0,
#         "amount": 0.0,
#         "currency": 2.5,
#         "balance_after": 0.0,
#         "status": 5.0,
#         "merchant": 55.00000000000001,
#         "category": 57.49999999999999,
#         "location": 0.0,
#         "ingestion_timestamp": 0.0,
#         "source_file": 0.0,
#         "batch_id": 0.0
#       },
#       "high_null_columns": {
#         "merchant": 55.00000000000001,
#         "category": 57.49999999999999
#       },
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:44:34.219803"
#     },
#     "validation_results": {
#       "validation_results": {
#         "has_transaction_id": {
#           "description": "Transaction ID must be present",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_amount": {
#           "description": "Amount must be positive if not null",
#           "failing_count": 24,
#           "failing_percentage": 60.0,
#           "passed": false
#         },
#         "valid_timestamp": {
#           "description": "Timestamp must not be in the future",
#           "failing_count": 1,
#           "failing_percentage": 2.5,
#           "passed": false
#         }
#       },
#       "sample_size": 40,
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:44:35.274161",
#       "all_passed": false
#     },
#     "source_path": [
#       "c:\\GitHub\\DE_Pipelines\\data\\financial_transactions_20250409_113413.csv",
#       "c:\\GitHub\\DE_Pipelines\\data\\financial_transactions_20250410_113413.csv"
#     ],
#     "duration_seconds": 40.78407549858093
#   }
# }
# 2025-04-24 15:44:35,276 - INFO - Bronze layer processing completed in 40.79 seconds
# 2025-04-24 15:44:35,277 - INFO - Starting table optimization
# 2025-04-24 15:44:46,883 - INFO - Optimized de_pipelines.financial_osb_bronze_type1. Files: before=2, after=1
# 2025-04-24 15:44:46,885 - INFO - --Bronze layer successfully optimized in 11.61 seconds--
# 2025-04-24 15:44:46,886 - INFO - Starting silver layer processing
# 2025-04-24 15:44:47,092 - INFO - Successfully read bronze data version 3
# 2025-04-24 15:44:47,094 - INFO - Writing to silver table: de_pipelines.financial_osb_silver_type1
# 2025-04-24 15:44:47,731 - INFO - Applying transformation within silver writer
# 2025-04-24 15:45:02,689 - INFO - Successfully wrote to silver table: de_pipelines.financial_osb_silver_type1
# 2025-04-24 15:45:02,693 - INFO - Write Metrics:
# [
#   {
#     "numOutputRows": "950",
#     "numOutputBytes": "142803",
#     "numFiles": "13"
#   }
# ]
# 2025-04-24 15:45:03,387 - INFO - Running data quality checks for silver layer
# 2025-04-24 15:45:14,452 - INFO - Data Quality Metrics for silver layer:
# 2025-04-24 15:45:14,454 - INFO -   - Shape: [19,950] (approx. row count)
# 2025-04-24 15:45:14,456 - INFO -   - Schema:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- account_number: string (nullable = true)
#  |-- transaction_type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- balance_after: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = true)
#  |-- source_file: string (nullable = true)
#  |-- batch_id: string (nullable = true)
#  |-- transaction_date: date (nullable = true)
#  |-- transaction_time: string (nullable = true)
#  |-- year_month: string (nullable = true)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-24 15:45:14,457 - INFO -   - Sample size: 49
# 2025-04-24 15:45:14,458 - WARNING -   - Columns with high null percentages: {'transaction_type': 6.122448979591836, 'merchant': 44.89795918367347, 'category': 42.857142857142854}
# 2025-04-24 15:45:14,460 - INFO - Validating dataframe with 4 rules
# 2025-04-24 15:45:21,921 - INFO - Validation rule 'valid_transaction_type' FAILED - 22 records (44.90%) failed
# 2025-04-24 15:45:23,529 - INFO - Validation rule 'valid_status' FAILED - 23 records (46.94%) failed
# 2025-04-24 15:45:25,387 - INFO - Validation rule 'valid_currency' FAILED - 1 records (2.04%) failed
# 2025-04-24 15:45:27,200 - INFO - Validation rule 'valid_timestamp' FAILED - 1 records (2.04%) failed
# 2025-04-24 15:45:27,207 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250424_154354",
#   "layer": "silver",
#   "version": 4,
#   "timestamp": "2025-04-24T15:45:27.207127",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "silver",
#       "shape": "[19,950] (approx. row count)",
#       "schema": "root\n |-- transaction_id: string (nullable = true)\n |-- timestamp: timestamp (nullable = true)\n |-- customer_id: string (nullable = true)\n |-- account_number: string (nullable = true)\n |-- transaction_type: string (nullable = true)\n |-- amount: double (nullable = true)\n |-- currency: string (nullable = true)\n |-- balance_after: double (nullable = true)\n |-- status: string (nullable = true)\n |-- merchant: string (nullable = true)\n |-- category: string (nullable = true)\n |-- location: string (nullable = true)\n |-- ingestion_timestamp: timestamp (nullable = true)\n |-- source_file: string (nullable = true)\n |-- batch_id: string (nullable = true)\n |-- transaction_date: date (nullable = true)\n |-- transaction_time: string (nullable = true)\n |-- year_month: string (nullable = true)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 49,
#       "null_percentages": {
#         "transaction_id": 0.0,
#         "timestamp": 2.0408163265306123,
#         "customer_id": 0.0,
#         "account_number": 0.0,
#         "transaction_type": 6.122448979591836,
#         "amount": 0.0,
#         "currency": 2.0408163265306123,
#         "balance_after": 2.0408163265306123,
#         "status": 0.0,
#         "merchant": 44.89795918367347,
#         "category": 42.857142857142854,
#         "location": 0.0,
#         "ingestion_timestamp": 0.0,
#         "source_file": 0.0,
#         "batch_id": 0.0,
#         "transaction_date": 2.0408163265306123,
#         "transaction_time": 2.0408163265306123,
#         "year_month": 2.0408163265306123,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {
#         "transaction_type": 6.122448979591836,
#         "merchant": 44.89795918367347,
#         "category": 42.857142857142854
#       },
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:45:14.452341"
#     },
#     "validation_results": {
#       "validation_results": {
#         "valid_transaction_type": {
#           "description": "Transaction type must be one of the valid types",
#           "failing_count": 22,
#           "failing_percentage": 44.89795918367347,
#           "passed": false
#         },
#         "valid_status": {
#           "description": "Status must be one of the valid statuses",
#           "failing_count": 23,
#           "failing_percentage": 46.93877551020408,
#           "passed": false
#         },
#         "valid_currency": {
#           "description": "Currency code should be 3 characters if present",
#           "failing_count": 1,
#           "failing_percentage": 2.0408163265306123,
#           "passed": false
#         },
#         "valid_timestamp": {
#           "description": "Timestamp must not be NULL or in the future",
#           "failing_count": 1,
#           "failing_percentage": 2.0408163265306123,
#           "passed": false
#         }
#       },
#       "sample_size": 49,
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:45:27.207127",
#       "all_passed": false
#     },
#     "source_bronze_version": 3,
#     "duration_seconds": 40.31790113449097
#   }
# }
# 2025-04-24 15:45:27,209 - INFO - Silver layer processing completed in 40.32 seconds
# 2025-04-24 15:45:27,211 - INFO - Starting table optimization
# 2025-04-24 15:45:39,569 - INFO - Optimized de_pipelines.financial_osb_silver_type1. Files: before=13, after=13
# 2025-04-24 15:45:39,571 - INFO - --Silver layer successfully optimized in 12.36 seconds--
# 2025-04-24 15:45:39,573 - INFO - Starting gold layer processing
# 2025-04-24 15:45:39,745 - INFO - Successfully read silver data version 4
# 2025-04-24 15:45:39,936 - INFO - Transformation function applied
# 2025-04-24 15:45:39,938 - INFO - Writing to gold table: de_pipelines.financial_osb_gold_type1_daily_category
# 2025-04-24 15:45:52,537 - INFO - Successfully wrote to gold table: de_pipelines.financial_osb_gold_type1_daily_category
# 2025-04-24 15:45:52,539 - INFO - Write Metrics:
# [
#   {
#     "numOutputRows": "702",
#     "numOutputBytes": "20686",
#     "numFiles": "1"
#   }
# ]
# 2025-04-24 15:45:52,841 - INFO - Running data quality checks for de_pipelines.financial_osb_gold_type1_daily_category layer
# 2025-04-24 15:46:02,253 - INFO - Data Quality Metrics for de_pipelines.financial_osb_gold_type1_daily_category layer:
# 2025-04-24 15:46:02,255 - INFO -   - Shape: [9,702] (approx. row count)
# 2025-04-24 15:46:02,256 - INFO -   - Schema:
# root
#  |-- transaction_date: date (nullable = true)
#  |-- category: string (nullable = true)
#  |-- transaction_count: long (nullable = false)
#  |-- total_amount: double (nullable = true)
#  |-- avg_amount: double (nullable = true)
#  |-- min_amount: double (nullable = true)
#  |-- max_amount: double (nullable = true)
#  |-- unique_customers: long (nullable = false)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-24 15:46:02,260 - INFO -   - Sample size: 38
# 2025-04-24 15:46:02,261 - WARNING -   - Columns with high null percentages: {'category': 39.473684210526315}
# 2025-04-24 15:46:02,263 - INFO - Validating dataframe with 2 rules
# 2025-04-24 15:46:08,008 - INFO - Validation rule 'positive_transaction_counts' PASSED - 0 records (0.00%) failed
# 2025-04-24 15:46:10,586 - INFO - Validation rule 'valid_total_amounts' PASSED - 0 records (0.00%) failed
# 2025-04-24 15:46:10,591 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250424_154354",
#   "layer": "gold_daily_category",
#   "version": 1,
#   "timestamp": "2025-04-24T15:46:10.591586",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "de_pipelines.financial_osb_gold_type1_daily_category",
#       "shape": "[9,702] (approx. row count)",
#       "schema": "root\n |-- transaction_date: date (nullable = true)\n |-- category: string (nullable = true)\n |-- transaction_count: long (nullable = false)\n |-- total_amount: double (nullable = true)\n |-- avg_amount: double (nullable = true)\n |-- min_amount: double (nullable = true)\n |-- max_amount: double (nullable = true)\n |-- unique_customers: long (nullable = false)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 38,
#       "null_percentages": {
#         "transaction_date": 0.0,
#         "category": 39.473684210526315,
#         "transaction_count": 0.0,
#         "total_amount": 0.0,
#         "avg_amount": 0.0,
#         "min_amount": 0.0,
#         "max_amount": 0.0,
#         "unique_customers": 0.0,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {
#         "category": 39.473684210526315
#       },
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:46:02.253656"
#     },
#     "validation_results": {
#       "validation_results": {
#         "positive_transaction_counts": {
#           "description": "Transaction counts should be positive",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_total_amounts": {
#           "description": "Total amounts should not be negative",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         }
#       },
#       "sample_size": 38,
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:46:10.591586",
#       "all_passed": true
#     },
#     "source_silver_version": 4
#   }
# }
# 2025-04-24 15:46:10,594 - INFO - Writing to gold table: de_pipelines.financial_osb_gold_type1_customer_summary
# 2025-04-24 15:46:18,871 - INFO - Successfully wrote to gold table: de_pipelines.financial_osb_gold_type1_customer_summary
# 2025-04-24 15:46:18,873 - INFO - Write Metrics:
# [
#   {
#     "numOutputRows": "217",
#     "numOutputBytes": "9336",
#     "numFiles": "1"
#   }
# ]
# 2025-04-24 15:46:19,172 - INFO - Running data quality checks for de_pipelines.financial_osb_gold_type1_customer_summary layer
# 2025-04-24 15:46:27,901 - INFO - Data Quality Metrics for de_pipelines.financial_osb_gold_type1_customer_summary layer:
# 2025-04-24 15:46:27,903 - INFO -   - Shape: [9,217] (approx. row count)
# 2025-04-24 15:46:27,905 - INFO -   - Schema:
# root
#  |-- customer_id: string (nullable = true)
#  |-- transaction_count: long (nullable = false)
#  |-- total_amount: double (nullable = true)
#  |-- avg_amount: double (nullable = true)
#  |-- first_transaction_date: date (nullable = true)
#  |-- last_transaction_date: date (nullable = true)
#  |-- category_count: long (nullable = false)
#  |-- processing_timestamp: timestamp (nullable = false)
#  |-- days_since_last_transaction: integer (nullable = true)
#
# 2025-04-24 15:46:27,906 - INFO -   - Sample size: 11
# 2025-04-24 15:46:27,909 - INFO - Validating dataframe with 2 rules
# 2025-04-24 15:46:34,799 - INFO - Validation rule 'positive_transaction_counts' PASSED - 0 records (0.00%) failed
# 2025-04-24 15:46:36,581 - INFO - Validation rule 'valid_total_amounts' PASSED - 0 records (0.00%) failed
# 2025-04-24 15:46:36,587 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250424_154354",
#   "layer": "gold_customer_summary",
#   "version": 1,
#   "timestamp": "2025-04-24T15:46:36.587772",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "de_pipelines.financial_osb_gold_type1_customer_summary",
#       "shape": "[9,217] (approx. row count)",
#       "schema": "root\n |-- customer_id: string (nullable = true)\n |-- transaction_count: long (nullable = false)\n |-- total_amount: double (nullable = true)\n |-- avg_amount: double (nullable = true)\n |-- first_transaction_date: date (nullable = true)\n |-- last_transaction_date: date (nullable = true)\n |-- category_count: long (nullable = false)\n |-- processing_timestamp: timestamp (nullable = false)\n |-- days_since_last_transaction: integer (nullable = true)\n",
#       "sample_size": 11,
#       "null_percentages": {
#         "customer_id": 0.0,
#         "transaction_count": 0.0,
#         "total_amount": 0.0,
#         "avg_amount": 0.0,
#         "first_transaction_date": 0.0,
#         "last_transaction_date": 0.0,
#         "category_count": 0.0,
#         "processing_timestamp": 0.0,
#         "days_since_last_transaction": 0.0
#       },
#       "high_null_columns": {},
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:46:27.901782"
#     },
#     "validation_results": {
#       "validation_results": {
#         "positive_transaction_counts": {
#           "description": "Transaction counts should be positive",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_total_amounts": {
#           "description": "Total amounts should not be negative",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         }
#       },
#       "sample_size": 11,
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:46:36.587772",
#       "all_passed": true
#     },
#     "source_silver_version": 4
#   }
# }
# 2025-04-24 15:46:36,589 - INFO - Writing to gold table: de_pipelines.financial_osb_gold_type1_transaction_type_summary
# 2025-04-24 15:46:44,393 - INFO - Successfully wrote to gold table: de_pipelines.financial_osb_gold_type1_transaction_type_summary
# 2025-04-24 15:46:44,395 - INFO - Write Metrics:
# [
#   {
#     "numOutputRows": "17",
#     "numOutputBytes": "2142",
#     "numFiles": "1"
#   }
# ]
# 2025-04-24 15:46:44,710 - INFO - Running data quality checks for de_pipelines.financial_osb_gold_type1_transaction_type_summary layer
# 2025-04-24 15:46:51,455 - INFO - Data Quality Metrics for de_pipelines.financial_osb_gold_type1_transaction_type_summary layer:
# 2025-04-24 15:46:51,457 - INFO -   - Shape: [5,17] (approx. row count)
# 2025-04-24 15:46:51,459 - INFO -   - Schema:
# root
#  |-- transaction_type: string (nullable = true)
#  |-- transaction_count: long (nullable = false)
#  |-- total_amount: double (nullable = true)
#  |-- avg_amount: double (nullable = true)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-24 15:46:51,462 - INFO -   - Sample size: 1
# 2025-04-24 15:46:51,463 - INFO - Validating dataframe with 2 rules
# 2025-04-24 15:46:56,145 - INFO - Validation rule 'positive_transaction_counts' PASSED - 0 records (0.00%) failed
# 2025-04-24 15:46:57,647 - INFO - Validation rule 'valid_total_amounts' PASSED - 0 records (0.00%) failed
# 2025-04-24 15:46:57,654 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250424_154354",
#   "layer": "gold_transaction_type_summary",
#   "version": 1,
#   "timestamp": "2025-04-24T15:46:57.653847",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "de_pipelines.financial_osb_gold_type1_transaction_type_summary",
#       "shape": "[5,17] (approx. row count)",
#       "schema": "root\n |-- transaction_type: string (nullable = true)\n |-- transaction_count: long (nullable = false)\n |-- total_amount: double (nullable = true)\n |-- avg_amount: double (nullable = true)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 1,
#       "null_percentages": {
#         "transaction_type": 0.0,
#         "transaction_count": 0.0,
#         "total_amount": 0.0,
#         "avg_amount": 0.0,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {},
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:46:51.455422"
#     },
#     "validation_results": {
#       "validation_results": {
#         "positive_transaction_counts": {
#           "description": "Transaction counts should be positive",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_total_amounts": {
#           "description": "Total amounts should not be negative",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         }
#       },
#       "sample_size": 1,
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:46:57.653847",
#       "all_passed": true
#     },
#     "source_silver_version": 4
#   }
# }
# 2025-04-24 15:46:57,656 - INFO - Gold layer processing completed in 78.08 seconds
# 2025-04-24 15:46:57,658 - INFO - Starting table optimization
# 2025-04-24 15:47:00,345 - INFO - Optimized de_pipelines.financial_osb_gold_type1_daily_category. Files: before=1, after=1
# 2025-04-24 15:47:00,347 - INFO - Starting table optimization
# 2025-04-24 15:47:02,421 - INFO - Optimized de_pipelines.financial_osb_gold_type1_customer_summary. Files: before=1, after=1
# 2025-04-24 15:47:02,423 - INFO - Starting table optimization
# 2025-04-24 15:47:04,295 - INFO - Optimized de_pipelines.financial_osb_gold_type1_transaction_type_summary. Files: before=1, after=1
# 2025-04-24 15:47:04,297 - INFO - --Gold layer successfully optimized in 6.64 seconds--
# 2025-04-24 15:47:04,298 - INFO - ---Full pipeline execution completed successfully in 189.81 seconds---
# 2025-04-24 15:47:05,324 - INFO - Spark session stopped
# {'status': 'success',
#  'pipeline_id': 'Financial_DE_Pipeline_20250424_154354',
#  'bronze_version': 3,
#  'silver_version': 4,
#  'timestamp': '2025-04-24T15:47:04.300840',
#  'duration_seconds': 189.81175589561462,
#  'metrics': {'pipeline_id': 'Financial_DE_Pipeline_20250424_154354',
#   'start_time': '2025-04-24T15:43:54.487088',
#   'stages': {'bronze': {'duration_seconds': 40.788586378097534,
#     'version': 3,
#     'status': 'success'},
#    'bronze_optimize': {'layer': 'bronze',
#     'duration_seconds': 11.606544971466064,
#     'status': 'success'},
#    'silver': {'duration_seconds': 40.32490658760071,
#     'version': 4,
#     'status': 'success',
#     'source_bronze_version': 3},
#    'silver_optimize': {'layer': 'silver',
#     'duration_seconds': 12.360381364822388,
#     'status': 'success'},
#    'gold': {'duration_seconds': 78.08485698699951,
#     'status': 'success',
#     'source_silver_version': 4,
#     'tables': ['daily_category',
#      'customer_summary',
#      'transaction_type_summary']},
#    'gold_optimize': {'layer': 'gold',
#     'duration_seconds': 6.639474630355835,
#     'status': 'success'}},
#   'status': 'success',
#   'end_time': '2025-04-24T15:47:04.298844',
#   'total_duration_seconds': 189.81175589561462}}

# %% [markdown]
# ### Running Layers In Isolation

# %%
spark = initialize_local_spark_delta_lake("Financial Data Pipeline - Testing")
# Out:
# 2025-04-24 15:47:05,349 - INFO - ---Spark session initialized with Delta Lake support---

# %% [markdown]
# #### Bronze

# %%
bronzedf, bronze_version = process_batch_bronze_layer(spark, 'csv', abs_file_list, get_schema(), bronze_table,
                               bronze_transform=None, validation_rules=bronze_validation_rules,
                               pipeline_id='test', mode='test', bronze_writer=None)
# Out:
# 2025-04-24 15:47:06,861 - INFO - Starting bronze layer processing
# 2025-04-24 15:47:06,924 - INFO - Successfully read CSV data from:
#   - c:\GitHub\DE_Pipelines\data\financial_transactions_20250409_113413.csv
#   - c:\GitHub\DE_Pipelines\data\financial_transactions_20250410_113413.csv
# 2025-04-24 15:47:06,926 - WARNING - --- Bronze layer in Test Mode ---
# 2025-04-24 15:47:06,928 - INFO - No transformation function defined
# 2025-04-24 15:47:06,929 - INFO - Running data quality checks for bronze layer
# 2025-04-24 15:47:11,475 - INFO - Data Quality Metrics for bronze layer:
# 2025-04-24 15:47:11,476 - INFO -   - Shape: [15,1000] (approx. row count)
# 2025-04-24 15:47:11,478 - INFO -   - Schema:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- account_number: string (nullable = true)
#  |-- transaction_type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- balance_after: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#  |-- source_file: string (nullable = false)
#  |-- batch_id: string (nullable = false)
#
# 2025-04-24 15:47:11,479 - INFO -   - Sample size: 40
# 2025-04-24 15:47:11,480 - WARNING -   - Columns with high null percentages: {'merchant': 55.00000000000001, 'category': 57.49999999999999}
# 2025-04-24 15:47:11,481 - INFO - Validating dataframe with 3 rules
# 2025-04-24 15:47:11,799 - INFO - Validation rule 'has_transaction_id' PASSED - 0 records (0.00%) failed
# 2025-04-24 15:47:11,912 - INFO - Validation rule 'valid_amount' FAILED - 24 records (60.00%) failed
# 2025-04-24 15:47:12,019 - INFO - Validation rule 'valid_timestamp' FAILED - 1 records (2.50%) failed
# 2025-04-24 15:47:12,022 - INFO - Checkpoint created:
# {
#   "pipeline_id": "test",
#   "layer": "bronze",
#   "version": "test",
#   "timestamp": "2025-04-24T15:47:12.022442",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "bronze",
#       "shape": "[15,1000] (approx. row count)",
#       "schema": "root\n |-- transaction_id: string (nullable = true)\n |-- timestamp: string (nullable = true)\n |-- customer_id: string (nullable = true)\n |-- account_number: string (nullable = true)\n |-- transaction_type: string (nullable = true)\n |-- amount: double (nullable = true)\n |-- currency: string (nullable = true)\n |-- balance_after: double (nullable = true)\n |-- status: string (nullable = true)\n |-- merchant: string (nullable = true)\n |-- category: string (nullable = true)\n |-- location: string (nullable = true)\n |-- ingestion_timestamp: timestamp (nullable = false)\n |-- source_file: string (nullable = false)\n |-- batch_id: string (nullable = false)\n",
#       "sample_size": 40,
#       "null_percentages": {
#         "transaction_id": 0.0,
#         "timestamp": 2.5,
#         "customer_id": 0.0,
#         "account_number": 2.5,
#         "transaction_type": 5.0,
#         "amount": 0.0,
#         "currency": 2.5,
#         "balance_after": 0.0,
#         "status": 5.0,
#         "merchant": 55.00000000000001,
#         "category": 57.49999999999999,
#         "location": 0.0,
#         "ingestion_timestamp": 0.0,
#         "source_file": 0.0,
#         "batch_id": 0.0
#       },
#       "high_null_columns": {
#         "merchant": 55.00000000000001,
#         "category": 57.49999999999999
#       },
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:47:11.475181"
#     },
#     "validation_results": {
#       "validation_results": {
#         "has_transaction_id": {
#           "description": "Transaction ID must be present",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_amount": {
#           "description": "Amount must be positive if not null",
#           "failing_count": 24,
#           "failing_percentage": 60.0,
#           "passed": false
#         },
#         "valid_timestamp": {
#           "description": "Timestamp must not be in the future",
#           "failing_count": 1,
#           "failing_percentage": 2.5,
#           "passed": false
#         }
#       },
#       "sample_size": 40,
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:47:12.022442",
#       "all_passed": false
#     },
#     "source_path": [
#       "c:\\GitHub\\DE_Pipelines\\data\\financial_transactions_20250409_113413.csv",
#       "c:\\GitHub\\DE_Pipelines\\data\\financial_transactions_20250410_113413.csv"
#     ],
#     "duration_seconds": 5.1596949100494385
#   }
# }
# 2025-04-24 15:47:12,024 - INFO - Bronze layer processing completed in 5.16 seconds

# %%
bronzedf.show(5)
# Out:
# +--------------+-------------------+-----------+--------------+----------------+-------+--------+-------------+--------+--------------------+---------+---------------+--------------------+--------------------+--------+
# |transaction_id|          timestamp|customer_id|account_number|transaction_type| amount|currency|balance_after|  status|            merchant| category|       location| ingestion_timestamp|         source_file|batch_id|
# +--------------+-------------------+-----------+--------------+----------------+-------+--------+-------------+--------+--------------------+---------+---------------+--------------------+--------------------+--------+
# |   TXN00000001|2023-05-05 03:42:36| CUST001179| ACCT-39450273|        interest|1378.52|     USD|      9544.56|reversed|                NULL|     NULL|Los Angeles, CA|2025-04-24 15:47:...|file:///c:/GitHub...|    test|
# |   TXN00000002|2023-08-11 06:24:46| CUST001188| ACCT-55298556|          refund| 1626.4|     JPY|      9598.17|disputed|               Zelle| shopping|     Austin, TX|2025-04-24 15:47:...|file:///c:/GitHub...|    test|
# |   TXN00000003|2023-06-24 10:10:55| CUST001153|          NULL|          refund|   30.3|     USD|      1800.82|disputed|    American Express|education|            ATM|2025-04-24 15:47:...|file:///c:/GitHub...|    test|
# |   TXN00000004|2023-08-21 09:51:49| CUST001079| ACCT-49823450|      withdrawal|-130.66|     USD|      3709.27|reversed|                NULL|     NULL|         Branch|2025-04-24 15:47:...|file:///c:/GitHub...|    test|
# |   TXN00000005|2023-12-29 19:26:50| CUST001033| ACCT-22201654|         deposit|1958.59|     JPY|      5587.82| pending|Direct Deposit - ...|   income|         Branch|2025-04-24 15:47:...|file:///c:/GitHub...|    test|
# +--------------+-------------------+-----------+--------------+----------------+-------+--------+-------------+--------+--------------------+---------+---------------+--------------------+--------------------+--------+
# only showing top 5 rows

# %% [markdown]
# #### Silver

# %%
silverdf, silver_version = process_batch_silver_layer(spark, bronze_table, bronze_version=None, 
                                                   silver_table=silver_table, 
                                                   silver_transform=silver_transform, 
                                                   validation_rules=silver_validation_rules,
                                                   pipeline_id='test', mode='test', 
                                                   silver_writer=None)
# Out:
# 2025-04-24 15:47:12,201 - INFO - Starting silver layer processing
# 2025-04-24 15:47:12,914 - INFO - Successfully read bronze data version 4
# 2025-04-24 15:47:12,916 - WARNING - --- Silver layer in Test Mode ---
# 2025-04-24 15:47:13,062 - INFO - Transformation function applied in test mode
# 2025-04-24 15:47:13,064 - INFO - Running data quality checks for silver layer
# 2025-04-24 15:47:24,774 - INFO - Data Quality Metrics for silver layer:
# 2025-04-24 15:47:24,776 - INFO -   - Shape: [19,950] (approx. row count)
# 2025-04-24 15:47:24,777 - INFO -   - Schema:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- account_number: string (nullable = true)
#  |-- transaction_type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- balance_after: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = true)
#  |-- source_file: string (nullable = true)
#  |-- batch_id: string (nullable = true)
#  |-- transaction_date: date (nullable = true)
#  |-- transaction_time: string (nullable = true)
#  |-- year_month: string (nullable = true)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-24 15:47:24,780 - INFO -   - Sample size: 49
# 2025-04-24 15:47:24,782 - WARNING -   - Columns with high null percentages: {'transaction_type': 6.122448979591836, 'merchant': 44.89795918367347, 'category': 42.857142857142854}
# 2025-04-24 15:47:24,783 - INFO - Validating dataframe with 4 rules
# 2025-04-24 15:47:31,082 - INFO - Validation rule 'valid_transaction_type' FAILED - 22 records (44.90%) failed
# 2025-04-24 15:47:32,888 - INFO - Validation rule 'valid_status' FAILED - 23 records (46.94%) failed
# 2025-04-24 15:47:34,225 - INFO - Validation rule 'valid_currency' FAILED - 1 records (2.04%) failed
# 2025-04-24 15:47:35,678 - INFO - Validation rule 'valid_timestamp' FAILED - 1 records (2.04%) failed
# 2025-04-24 15:47:35,683 - INFO - Checkpoint created:
# {
#   "pipeline_id": "test",
#   "layer": "silver",
#   "version": "test",
#   "timestamp": "2025-04-24T15:47:35.682465",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "silver",
#       "shape": "[19,950] (approx. row count)",
#       "schema": "root\n |-- transaction_id: string (nullable = true)\n |-- timestamp: timestamp (nullable = true)\n |-- customer_id: string (nullable = true)\n |-- account_number: string (nullable = true)\n |-- transaction_type: string (nullable = true)\n |-- amount: double (nullable = true)\n |-- currency: string (nullable = true)\n |-- balance_after: double (nullable = true)\n |-- status: string (nullable = true)\n |-- merchant: string (nullable = true)\n |-- category: string (nullable = true)\n |-- location: string (nullable = true)\n |-- ingestion_timestamp: timestamp (nullable = true)\n |-- source_file: string (nullable = true)\n |-- batch_id: string (nullable = true)\n |-- transaction_date: date (nullable = true)\n |-- transaction_time: string (nullable = true)\n |-- year_month: string (nullable = true)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 49,
#       "null_percentages": {
#         "transaction_id": 0.0,
#         "timestamp": 2.0408163265306123,
#         "customer_id": 0.0,
#         "account_number": 0.0,
#         "transaction_type": 6.122448979591836,
#         "amount": 0.0,
#         "currency": 2.0408163265306123,
#         "balance_after": 2.0408163265306123,
#         "status": 0.0,
#         "merchant": 44.89795918367347,
#         "category": 42.857142857142854,
#         "location": 0.0,
#         "ingestion_timestamp": 0.0,
#         "source_file": 0.0,
#         "batch_id": 0.0,
#         "transaction_date": 2.0408163265306123,
#         "transaction_time": 2.0408163265306123,
#         "year_month": 2.0408163265306123,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {
#         "transaction_type": 6.122448979591836,
#         "merchant": 44.89795918367347,
#         "category": 42.857142857142854
#       },
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:47:24.774905"
#     },
#     "validation_results": {
#       "validation_results": {
#         "valid_transaction_type": {
#           "description": "Transaction type must be one of the valid types",
#           "failing_count": 22,
#           "failing_percentage": 44.89795918367347,
#           "passed": false
#         },
#         "valid_status": {
#           "description": "Status must be one of the valid statuses",
#           "failing_count": 23,
#           "failing_percentage": 46.93877551020408,
#           "passed": false
#         },
#         "valid_currency": {
#           "description": "Currency code should be 3 characters if present",
#           "failing_count": 1,
#           "failing_percentage": 2.0408163265306123,
#           "passed": false
#         },
#         "valid_timestamp": {
#           "description": "Timestamp must not be NULL or in the future",
#           "failing_count": 1,
#           "failing_percentage": 2.0408163265306123,
#           "passed": false
#         }
#       },
#       "sample_size": 49,
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:47:35.682465",
#       "all_passed": false
#     },
#     "source_bronze_version": 4,
#     "duration_seconds": 23.47823143005371
#   }
# }
# 2025-04-24 15:47:35,684 - INFO - Silver layer processing completed in 23.48 seconds

# %%
silverdf.show(5)
# Out:
# +--------------+-------------------+-----------+--------------+----------------+-------+--------+-------------+--------+--------------------+---------+---------------+--------------------+--------------------+--------------------+
# |transaction_id|          timestamp|customer_id|account_number|transaction_type| amount|currency|balance_after|  status|            merchant| category|       location| ingestion_timestamp|         source_file|            batch_id|
# +--------------+-------------------+-----------+--------------+----------------+-------+--------+-------------+--------+--------------------+---------+---------------+--------------------+--------------------+--------------------+
# |   TXN00000001|2023-05-05 03:42:36| CUST001179| ACCT-39450273|        interest|1378.52|     USD|      9544.56|reversed|                NULL|     NULL|Los Angeles, CA|2025-04-24 15:44:...|file:///c:/GitHub...|Financial_DE_Pipe...|
# |   TXN00000002|2023-08-11 06:24:46| CUST001188| ACCT-55298556|          refund| 1626.4|     JPY|      9598.17|disputed|               Zelle| shopping|     Austin, TX|2025-04-24 15:44:...|file:///c:/GitHub...|Financial_DE_Pipe...|
# |   TXN00000003|2023-06-24 10:10:55| CUST001153|          NULL|          refund|   30.3|     USD|      1800.82|disputed|    American Express|education|            ATM|2025-04-24 15:44:...|file:///c:/GitHub...|Financial_DE_Pipe...|
# |   TXN00000004|2023-08-21 09:51:49| CUST001079| ACCT-49823450|      withdrawal|-130.66|     USD|      3709.27|reversed|                NULL|     NULL|         Branch|2025-04-24 15:44:...|file:///c:/GitHub...|Financial_DE_Pipe...|
# |   TXN00000005|2023-12-29 19:26:50| CUST001033| ACCT-22201654|         deposit|1958.59|     JPY|      5587.82| pending|Direct Deposit - ...|   income|         Branch|2025-04-24 15:44:...|file:///c:/GitHub...|Financial_DE_Pipe...|
# +--------------+-------------------+-----------+--------------+----------------+-------+--------+-------------+--------+--------------------+---------+---------------+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ##### Investigating Silver Validation Check Failures:
# Corrupt "status" column

# %%
silverdf.groupBy('status').count().show()
# Out:
# +---------+-----+
# |   status|count|
# +---------+-----+
# | dqsputed|    1|
# |  pgnding|    1|
# |completed|  206|
# |   failen|    1|
# |   failed|  186|
# |bompleted|    1|
# |     NULL|   19|
# | reyersed|    1|
# |comcleted|    1|
# | disputad|    1|
# | dmsputed|    1|
# | diiputed|    1|
# |  pending|  171|
# | disputed|  204|
# | reverszd|    1|
# | reversed|  204|
# +---------+-----+

# %% [markdown]
# #### Gold

# %%
gold_dfs = process_batch_gold_layer(spark, silver_table, silver_version=None, 
                                 gold_table=gold_table, 
                                 gold_transform=gold_transform, 
                                 validation_rules=gold_validation_rules, 
                                 pipeline_id='test', 
                                 mode='test',
                                 gold_writer=None)
# Out:
# 2025-04-24 15:47:38,415 - INFO - Starting gold layer processing
# 2025-04-24 15:47:39,148 - INFO - Successfully read silver data version 5
# 2025-04-24 15:47:39,278 - INFO - Transformation function applied
# 2025-04-24 15:47:39,280 - WARNING - Gold layer in Test Mode
# 2025-04-24 15:47:39,282 - INFO - Running data quality checks for de_pipelines.financial_osb_gold_type1_daily_category layer
# 2025-04-24 15:47:51,276 - INFO - Data Quality Metrics for de_pipelines.financial_osb_gold_type1_daily_category layer:
# 2025-04-24 15:47:51,277 - INFO -   - Shape: [9,702] (approx. row count)
# 2025-04-24 15:47:51,278 - INFO -   - Schema:
# root
#  |-- transaction_date: date (nullable = true)
#  |-- category: string (nullable = true)
#  |-- transaction_count: long (nullable = false)
#  |-- total_amount: double (nullable = true)
#  |-- avg_amount: double (nullable = true)
#  |-- min_amount: double (nullable = true)
#  |-- max_amount: double (nullable = true)
#  |-- unique_customers: long (nullable = false)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-24 15:47:51,280 - INFO -   - Sample size: 38
# 2025-04-24 15:47:51,282 - WARNING -   - Columns with high null percentages: {'category': 39.473684210526315}
# 2025-04-24 15:47:51,284 - INFO - Validating dataframe with 2 rules
# 2025-04-24 15:47:57,278 - INFO - Validation rule 'positive_transaction_counts' PASSED - 0 records (0.00%) failed
# 2025-04-24 15:47:58,935 - INFO - Validation rule 'valid_total_amounts' PASSED - 0 records (0.00%) failed
# 2025-04-24 15:47:58,944 - INFO - Checkpoint created:
# {
#   "pipeline_id": "test",
#   "layer": "gold_daily_category",
#   "version": "test",
#   "timestamp": "2025-04-24T15:47:58.944046",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "de_pipelines.financial_osb_gold_type1_daily_category",
#       "shape": "[9,702] (approx. row count)",
#       "schema": "root\n |-- transaction_date: date (nullable = true)\n |-- category: string (nullable = true)\n |-- transaction_count: long (nullable = false)\n |-- total_amount: double (nullable = true)\n |-- avg_amount: double (nullable = true)\n |-- min_amount: double (nullable = true)\n |-- max_amount: double (nullable = true)\n |-- unique_customers: long (nullable = false)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 38,
#       "null_percentages": {
#         "transaction_date": 0.0,
#         "category": 39.473684210526315,
#         "transaction_count": 0.0,
#         "total_amount": 0.0,
#         "avg_amount": 0.0,
#         "min_amount": 0.0,
#         "max_amount": 0.0,
#         "unique_customers": 0.0,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {
#         "category": 39.473684210526315
#       },
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:47:51.276151"
#     },
#     "validation_results": {
#       "validation_results": {
#         "positive_transaction_counts": {
#           "description": "Transaction counts should be positive",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_total_amounts": {
#           "description": "Total amounts should not be negative",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         }
#       },
#       "sample_size": 38,
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:47:58.944046",
#       "all_passed": true
#     },
#     "source_silver_version": 5
#   }
# }
# 2025-04-24 15:47:58,946 - INFO - Running data quality checks for de_pipelines.financial_osb_gold_type1_customer_summary layer
# 2025-04-24 15:48:09,128 - INFO - Data Quality Metrics for de_pipelines.financial_osb_gold_type1_customer_summary layer:
# 2025-04-24 15:48:09,130 - INFO -   - Shape: [9,217] (approx. row count)
# 2025-04-24 15:48:09,131 - INFO -   - Schema:
# root
#  |-- customer_id: string (nullable = true)
#  |-- transaction_count: long (nullable = false)
#  |-- total_amount: double (nullable = true)
#  |-- avg_amount: double (nullable = true)
#  |-- first_transaction_date: date (nullable = true)
#  |-- last_transaction_date: date (nullable = true)
#  |-- category_count: long (nullable = false)
#  |-- processing_timestamp: timestamp (nullable = false)
#  |-- days_since_last_transaction: integer (nullable = true)
#
# 2025-04-24 15:48:09,133 - INFO -   - Sample size: 11
# 2025-04-24 15:48:09,135 - INFO - Validating dataframe with 2 rules
# 2025-04-24 15:48:15,336 - INFO - Validation rule 'positive_transaction_counts' PASSED - 0 records (0.00%) failed
# 2025-04-24 15:48:16,792 - INFO - Validation rule 'valid_total_amounts' PASSED - 0 records (0.00%) failed
# 2025-04-24 15:48:16,796 - INFO - Checkpoint created:
# {
#   "pipeline_id": "test",
#   "layer": "gold_customer_summary",
#   "version": "test",
#   "timestamp": "2025-04-24T15:48:16.796778",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "de_pipelines.financial_osb_gold_type1_customer_summary",
#       "shape": "[9,217] (approx. row count)",
#       "schema": "root\n |-- customer_id: string (nullable = true)\n |-- transaction_count: long (nullable = false)\n |-- total_amount: double (nullable = true)\n |-- avg_amount: double (nullable = true)\n |-- first_transaction_date: date (nullable = true)\n |-- last_transaction_date: date (nullable = true)\n |-- category_count: long (nullable = false)\n |-- processing_timestamp: timestamp (nullable = false)\n |-- days_since_last_transaction: integer (nullable = true)\n",
#       "sample_size": 11,
#       "null_percentages": {
#         "customer_id": 0.0,
#         "transaction_count": 0.0,
#         "total_amount": 0.0,
#         "avg_amount": 0.0,
#         "first_transaction_date": 0.0,
#         "last_transaction_date": 0.0,
#         "category_count": 0.0,
#         "processing_timestamp": 0.0,
#         "days_since_last_transaction": 0.0
#       },
#       "high_null_columns": {},
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:48:09.128442"
#     },
#     "validation_results": {
#       "validation_results": {
#         "positive_transaction_counts": {
#           "description": "Transaction counts should be positive",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_total_amounts": {
#           "description": "Total amounts should not be negative",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         }
#       },
#       "sample_size": 11,
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:48:16.796778",
#       "all_passed": true
#     },
#     "source_silver_version": 5
#   }
# }
# 2025-04-24 15:48:16,798 - INFO - Running data quality checks for de_pipelines.financial_osb_gold_type1_transaction_type_summary layer
# 2025-04-24 15:48:23,633 - INFO - Data Quality Metrics for de_pipelines.financial_osb_gold_type1_transaction_type_summary layer:
# 2025-04-24 15:48:23,635 - INFO -   - Shape: [5,17] (approx. row count)
# 2025-04-24 15:48:23,635 - INFO -   - Schema:
# root
#  |-- transaction_type: string (nullable = true)
#  |-- transaction_count: long (nullable = false)
#  |-- total_amount: double (nullable = true)
#  |-- avg_amount: double (nullable = true)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-24 15:48:23,639 - INFO -   - Sample size: 1
# 2025-04-24 15:48:23,641 - INFO - Validating dataframe with 2 rules
# 2025-04-24 15:48:27,418 - INFO - Validation rule 'positive_transaction_counts' PASSED - 0 records (0.00%) failed
# 2025-04-24 15:48:28,941 - INFO - Validation rule 'valid_total_amounts' PASSED - 0 records (0.00%) failed
# 2025-04-24 15:48:28,946 - INFO - Checkpoint created:
# {
#   "pipeline_id": "test",
#   "layer": "gold_transaction_type_summary",
#   "version": "test",
#   "timestamp": "2025-04-24T15:48:28.946447",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "de_pipelines.financial_osb_gold_type1_transaction_type_summary",
#       "shape": "[5,17] (approx. row count)",
#       "schema": "root\n |-- transaction_type: string (nullable = true)\n |-- transaction_count: long (nullable = false)\n |-- total_amount: double (nullable = true)\n |-- avg_amount: double (nullable = true)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 1,
#       "null_percentages": {
#         "transaction_type": 0.0,
#         "transaction_count": 0.0,
#         "total_amount": 0.0,
#         "avg_amount": 0.0,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {},
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:48:23.633996"
#     },
#     "validation_results": {
#       "validation_results": {
#         "positive_transaction_counts": {
#           "description": "Transaction counts should be positive",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_total_amounts": {
#           "description": "Total amounts should not be negative",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         }
#       },
#       "sample_size": 1,
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:48:28.946447",
#       "all_passed": true
#     },
#     "source_silver_version": 5
#   }
# }
# 2025-04-24 15:48:28,948 - INFO - Gold layer processing completed in 50.53 seconds

# %%
for table_name in gold_dfs.keys():
    gold_dfs[table_name].show(5)
# Out:
# +----------------+----------+-----------------+------------+----------+----------+----------+----------------+--------------------+
# |transaction_date|  category|transaction_count|total_amount|avg_amount|min_amount|max_amount|unique_customers|processing_timestamp|
# +----------------+----------+-----------------+------------+----------+----------+----------+----------------+--------------------+
# |      2023-05-25|      fees|                1|       30.89|     30.89|     30.89|     30.89|               1|2025-04-24 15:48:...|
# |      2023-09-25|    income|                1|      1384.1|    1384.1|    1384.1|    1384.1|               1|2025-04-24 15:48:...|
# |      2023-06-22|      NULL|                1|       64.69|     64.69|     64.69|     64.69|               1|2025-04-24 15:48:...|
# |      2023-12-18|investment|                1|      626.53|    626.53|    626.53|    626.53|               1|2025-04-24 15:48:...|
# |      2023-08-28|   housing|                1|       37.49|     37.49|     37.49|     37.49|               1|2025-04-24 15:48:...|
# +----------------+----------+-----------------+------------+----------+----------+----------+----------------+--------------------+
# only showing top 5 rows
#
# +-----------+-----------------+------------------+------------------+----------------------+---------------------+--------------+--------------------+---------------------------+
# |customer_id|transaction_count|      total_amount|        avg_amount|first_transaction_date|last_transaction_date|category_count|processing_timestamp|days_since_last_transaction|
# +-----------+-----------------+------------------+------------------+----------------------+---------------------+--------------+--------------------+---------------------------+
# | CUST001122|                7| 5558.129999999999| 794.0185714285714|            2023-03-20|           2023-12-22|             3|2025-04-24 15:48:...|                        489|
# | CUST001189|                7|           4529.01| 647.0014285714286|            2023-01-24|           2023-11-23|             3|2025-04-24 15:48:...|                        518|
# | CUST001193|                5|         1937500.9|         387500.18|            2023-02-09|           2023-10-23|             1|2025-04-24 15:48:...|                        549|
# | CUST001098|                4|1725.2000000000003|431.30000000000007|            2023-05-13|           2023-12-20|             1|2025-04-24 15:48:...|                        491|
# | CUST001102|                7|2648.9399999999996|378.41999999999996|            2023-02-02|           2023-12-21|             4|2025-04-24 15:48:...|                        490|
# +-----------+-----------------+------------------+------------------+----------------------+---------------------+--------------+--------------------+---------------------------+
# only showing top 5 rows
#
# +----------------+-----------------+------------------+------------------+--------------------+
# |transaction_type|transaction_count|      total_amount|        avg_amount|processing_timestamp|
# +----------------+-----------------+------------------+------------------+--------------------+
# |         dbposit|                1|            383.95|            383.95|2025-04-24 15:48:...|
# |            NULL|               22|14064.100000000002| 639.2772727272728|2025-04-24 15:48:...|
# |      withdrawal|              137|           73410.6|  535.843795620438|2025-04-24 15:48:...|
# |             fee|              122|           3127.05| 25.63155737704918|2025-04-24 15:48:...|
# |        interest|              129|        2067572.54|16027.694108527132|2025-04-24 15:48:...|
# +----------------+-----------------+------------------+------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ## SCD Type 1:
# ##### Change Data Capture (Merge)

# %% [markdown]
# ##### Inputs/Outputs

# %%
# Change Data Capture
file_list = [
    "financial_transactions_20250414_113413.csv",
    "financial_transactions_20250417_113413.csv"
]

abs_file_list = []
for file in file_list:
    # Join data_dir with filename
    relative_path = os.path.join(data_dir, file)
    # Convert to absolute path
    abs_path = os.path.abspath(relative_path)
    abs_file_list.append(abs_path)

# %% [markdown]
# #### Define: Validation Rules(Same), Transformations(Same), Write Executions (Merge)

# %%
def bronze_writer(df: DataFrame, table_name, bronze_transform=None):
    """Write data to bronze layer with optional transformation"""

    # Apply Pre-Transform Filters:

    # drop duplicates
    df = (df
            .orderBy(F.col("timestamp").desc())
            .dropDuplicates(subset=["transaction_id", "account_number"])  # Keeps only the latest record
        )


    try:
        if bronze_transform:
            logger.info("Applying transformation within bronze writer")
            transformed_df = bronze_transform(df)
        else:
            transformed_df = df

        # Merge the source and target DataFrame
        transformed_df.createOrReplaceTempView("source")

        # Execute merge
        spark.sql(f"""
            MERGE INTO {table_name} t
            USING source s
            ON s.transaction_id = t.transaction_id AND s.account_number = t.account_number
            WHEN MATCHED AND (t.amount != s.amount OR t.balance_after != s.balance_after) THEN 
                UPDATE SET *
            WHEN NOT MATCHED THEN
                INSERT *
        """)

    except Exception as e:
        logger.error(f"Error in bronze_writer: {str(e)}")
        raise

    return None

# %%
def silver_writer(df: DataFrame, table_name, silver_transform=None):

    # Apply Pre-Transform Filters:
    
    # get max ingested timestamp from silver table
    max_ts = spark.sql(f"SELECT MAX(ingestion_timestamp) FROM {table_name}").collect()[0][0]

    # filter incoming data to only include records with a later ingested timestamp
    df = df.filter(F.col("ingestion_timestamp") > max_ts)

    # drop duplicates
    df = (df
            .orderBy(F.col("timestamp").desc())
            .dropDuplicates(subset=["transaction_id", "account_number"])  # Keeps only the latest record
        )

    """Write data to silver layer with optional transformation"""
    try:
        if silver_transform:
            logger.info("Applying transformation within silver writer")
            transformed_df = silver_transform(df)
        else:
            transformed_df = df

        # Merge the source and target DataFrame
        transformed_df.createOrReplaceTempView("source")

        # Execute merge
        spark.sql(f"""
            MERGE INTO {table_name} t
            USING source s
            ON s.transaction_id = t.transaction_id 
                AND s.account_number = t.account_number 
            WHEN MATCHED AND (t.amount != s.amount OR t.balance_after != s.balance_after) THEN 
                UPDATE SET *
            WHEN NOT MATCHED THEN
                INSERT *
        """)
            

    except Exception as e:
        logger.error(f"Error in silver_writer: {str(e)}")
        raise



    return None

# %% [markdown]
# #### Running CDC Full Batch Pipeline (Bronze, Silver)

# %%
run_batch_de_pipeline(spark, 'csv', abs_file_list, get_schema(), 
                     bronze_table=bronze_table, silver_table=silver_table, gold_table=None, 
                     bronze_transform=None, silver_transform=silver_transform, gold_transform=None,
                     bronze_writer=bronze_writer, silver_writer=silver_writer, gold_writer=None,
                     bronze_validation_rules=bronze_validation_rules, 
                     silver_validation_rules=silver_validation_rules, 
                     gold_validation_rules=None,
                     pipeline_name='Financial_DE_Pipeline')
# Out:
# 2025-04-24 15:48:32,863 - INFO - --Starting data pipeline execution with ID: Financial_DE_Pipeline_20250424_154832--
# 2025-04-24 15:48:32,864 - INFO - Starting bronze layer processing
# 2025-04-24 15:48:33,003 - INFO - Successfully read CSV data from:
#   - c:\GitHub\DE_Pipelines\data\financial_transactions_20250414_113413.csv
#   - c:\GitHub\DE_Pipelines\data\financial_transactions_20250417_113413.csv
# 2025-04-24 15:48:33,006 - INFO - Writing to bronze table: de_pipelines.financial_osb_bronze_type1
# 2025-04-24 15:48:42,881 - INFO - Successfully wrote to bronze table: de_pipelines.financial_osb_bronze_type1
# 2025-04-24 15:48:42,883 - INFO - Write Metrics:
# [
#   {
#     "numOutputRows": "1540",
#     "numTargetBytesAdded": "59467",
#     "numTargetRowsInserted": "540",
#     "numTargetFilesAdded": "1",
#     "materializeSourceTimeMs": "1716",
#     "numTargetRowsMatchedDeleted": "0",
#     "numTargetFilesRemoved": "1",
#     "numTargetRowsMatchedUpdated": "217",
#     "executionTimeMs": "4798",
#     "numTargetDeletionVectorsUpdated": "0",
#     "numTargetRowsCopied": "783",
#     "rewriteTimeMs": "1523",
#     "numTargetRowsUpdated": "217",
#     "numTargetDeletionVectorsRemoved": "0",
#     "numTargetRowsDeleted": "0",
#     "scanTimeMs": "1525",
#     "numSourceRows": "1500",
#     "numTargetDeletionVectorsAdded": "0",
#     "numTargetChangeFilesAdded": "0",
#     "numTargetRowsNotMatchedBySourceUpdated": "0",
#     "numTargetRowsNotMatchedBySourceDeleted": "0",
#     "numTargetBytesRemoved": "42674"
#   }
# ]
# 2025-04-24 15:48:43,275 - INFO - Running data quality checks for bronze layer
# 2025-04-24 15:48:47,924 - INFO - Data Quality Metrics for bronze layer:
# 2025-04-24 15:48:47,926 - INFO -   - Shape: [15,2750] (approx. row count)
# 2025-04-24 15:48:47,928 - INFO -   - Schema:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- account_number: string (nullable = true)
#  |-- transaction_type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- balance_after: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#  |-- source_file: string (nullable = false)
#  |-- batch_id: string (nullable = false)
#
# 2025-04-24 15:48:47,929 - INFO -   - Sample size: 122
# 2025-04-24 15:48:47,932 - WARNING -   - Columns with high null percentages: {'merchant': 51.63934426229508, 'category': 52.459016393442624}
# 2025-04-24 15:48:47,934 - INFO - Validating dataframe with 3 rules
# 2025-04-24 15:48:48,268 - INFO - Validation rule 'has_transaction_id' FAILED - 2 records (1.64%) failed
# 2025-04-24 15:48:48,376 - INFO - Validation rule 'valid_amount' FAILED - 80 records (65.57%) failed
# 2025-04-24 15:48:48,475 - INFO - Validation rule 'valid_timestamp' FAILED - 2 records (1.64%) failed
# 2025-04-24 15:48:48,478 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250424_154832",
#   "layer": "bronze",
#   "version": 5,
#   "timestamp": "2025-04-24T15:48:48.478403",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "bronze",
#       "shape": "[15,2750] (approx. row count)",
#       "schema": "root\n |-- transaction_id: string (nullable = true)\n |-- timestamp: string (nullable = true)\n |-- customer_id: string (nullable = true)\n |-- account_number: string (nullable = true)\n |-- transaction_type: string (nullable = true)\n |-- amount: double (nullable = true)\n |-- currency: string (nullable = true)\n |-- balance_after: double (nullable = true)\n |-- status: string (nullable = true)\n |-- merchant: string (nullable = true)\n |-- category: string (nullable = true)\n |-- location: string (nullable = true)\n |-- ingestion_timestamp: timestamp (nullable = false)\n |-- source_file: string (nullable = false)\n |-- batch_id: string (nullable = false)\n",
#       "sample_size": 122,
#       "null_percentages": {
#         "transaction_id": 1.639344262295082,
#         "timestamp": 1.639344262295082,
#         "customer_id": 0.819672131147541,
#         "account_number": 0.0,
#         "transaction_type": 2.459016393442623,
#         "amount": 0.819672131147541,
#         "currency": 0.819672131147541,
#         "balance_after": 1.639344262295082,
#         "status": 0.819672131147541,
#         "merchant": 51.63934426229508,
#         "category": 52.459016393442624,
#         "location": 0.819672131147541,
#         "ingestion_timestamp": 0.0,
#         "source_file": 0.0,
#         "batch_id": 0.0
#       },
#       "high_null_columns": {
#         "merchant": 51.63934426229508,
#         "category": 52.459016393442624
#       },
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:48:47.924115"
#     },
#     "validation_results": {
#       "validation_results": {
#         "has_transaction_id": {
#           "description": "Transaction ID must be present",
#           "failing_count": 2,
#           "failing_percentage": 1.639344262295082,
#           "passed": false
#         },
#         "valid_amount": {
#           "description": "Amount must be positive if not null",
#           "failing_count": 80,
#           "failing_percentage": 65.57377049180327,
#           "passed": false
#         },
#         "valid_timestamp": {
#           "description": "Timestamp must not be in the future",
#           "failing_count": 2,
#           "failing_percentage": 1.639344262295082,
#           "passed": false
#         }
#       },
#       "sample_size": 122,
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:48:48.478403",
#       "all_passed": false
#     },
#     "source_path": [
#       "c:\\GitHub\\DE_Pipelines\\data\\financial_transactions_20250414_113413.csv",
#       "c:\\GitHub\\DE_Pipelines\\data\\financial_transactions_20250417_113413.csv"
#     ],
#     "duration_seconds": 15.610901594161987
#   }
# }
# 2025-04-24 15:48:48,480 - INFO - Bronze layer processing completed in 15.61 seconds
# 2025-04-24 15:48:48,481 - INFO - Starting table optimization
# 2025-04-24 15:48:50,482 - INFO - Optimized de_pipelines.financial_osb_bronze_type1. Files: before=1, after=1
# 2025-04-24 15:48:50,483 - INFO - --Bronze layer successfully optimized in 2.00 seconds--
# 2025-04-24 15:48:50,484 - INFO - Starting silver layer processing
# 2025-04-24 15:48:50,551 - INFO - Successfully read bronze data version 5
# 2025-04-24 15:48:50,552 - INFO - Writing to silver table: de_pipelines.financial_osb_silver_type1
# 2025-04-24 15:48:51,777 - INFO - Applying transformation within silver writer
# 2025-04-24 15:49:01,702 - INFO - Successfully wrote to silver table: de_pipelines.financial_osb_silver_type1
# 2025-04-24 15:49:01,704 - INFO - Write Metrics:
# [
#   {
#     "numOutputRows": "1425",
#     "numTargetBytesAdded": "178308",
#     "numTargetRowsInserted": "475",
#     "numTargetFilesAdded": "15",
#     "materializeSourceTimeMs": "2565",
#     "numTargetRowsMatchedDeleted": "0",
#     "numTargetFilesRemoved": "13",
#     "numTargetRowsMatchedUpdated": "216",
#     "executionTimeMs": "5870",
#     "numTargetDeletionVectorsUpdated": "0",
#     "numTargetRowsCopied": "734",
#     "rewriteTimeMs": "1899",
#     "numTargetRowsUpdated": "216",
#     "numTargetDeletionVectorsRemoved": "0",
#     "numTargetRowsDeleted": "0",
#     "scanTimeMs": "1389",
#     "numSourceRows": "691",
#     "numTargetDeletionVectorsAdded": "0",
#     "numTargetChangeFilesAdded": "0",
#     "numTargetRowsNotMatchedBySourceUpdated": "0",
#     "numTargetRowsNotMatchedBySourceDeleted": "0",
#     "numTargetBytesRemoved": "142803"
#   }
# ]
# 2025-04-24 15:49:02,230 - INFO - Running data quality checks for silver layer
# 2025-04-24 15:49:08,641 - INFO - Data Quality Metrics for silver layer:
# 2025-04-24 15:49:08,642 - INFO -   - Shape: [19,1424] (approx. row count)
# 2025-04-24 15:49:08,644 - INFO -   - Schema:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- account_number: string (nullable = true)
#  |-- transaction_type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- balance_after: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = true)
#  |-- source_file: string (nullable = true)
#  |-- batch_id: string (nullable = true)
#  |-- transaction_date: date (nullable = true)
#  |-- transaction_time: string (nullable = true)
#  |-- year_month: string (nullable = true)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-24 15:49:08,644 - INFO -   - Sample size: 67
# 2025-04-24 15:49:08,645 - WARNING -   - Columns with high null percentages: {'merchant': 41.7910447761194, 'category': 40.298507462686565}
# 2025-04-24 15:49:08,646 - INFO - Validating dataframe with 4 rules
# 2025-04-24 15:49:11,817 - INFO - Validation rule 'valid_transaction_type' FAILED - 31 records (46.27%) failed
# 2025-04-24 15:49:11,929 - INFO - Validation rule 'valid_status' FAILED - 29 records (43.28%) failed
# 2025-04-24 15:49:12,047 - INFO - Validation rule 'valid_currency' FAILED - 1 records (1.49%) failed
# 2025-04-24 15:49:12,192 - INFO - Validation rule 'valid_timestamp' FAILED - 1 records (1.49%) failed
# 2025-04-24 15:49:12,195 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250424_154832",
#   "layer": "silver",
#   "version": 6,
#   "timestamp": "2025-04-24T15:49:12.195769",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "silver",
#       "shape": "[19,1424] (approx. row count)",
#       "schema": "root\n |-- transaction_id: string (nullable = true)\n |-- timestamp: timestamp (nullable = true)\n |-- customer_id: string (nullable = true)\n |-- account_number: string (nullable = true)\n |-- transaction_type: string (nullable = true)\n |-- amount: double (nullable = true)\n |-- currency: string (nullable = true)\n |-- balance_after: double (nullable = true)\n |-- status: string (nullable = true)\n |-- merchant: string (nullable = true)\n |-- category: string (nullable = true)\n |-- location: string (nullable = true)\n |-- ingestion_timestamp: timestamp (nullable = true)\n |-- source_file: string (nullable = true)\n |-- batch_id: string (nullable = true)\n |-- transaction_date: date (nullable = true)\n |-- transaction_time: string (nullable = true)\n |-- year_month: string (nullable = true)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 67,
#       "null_percentages": {
#         "transaction_id": 0.0,
#         "timestamp": 1.4925373134328357,
#         "customer_id": 0.0,
#         "account_number": 0.0,
#         "transaction_type": 4.477611940298507,
#         "amount": 0.0,
#         "currency": 1.4925373134328357,
#         "balance_after": 0.0,
#         "status": 0.0,
#         "merchant": 41.7910447761194,
#         "category": 40.298507462686565,
#         "location": 0.0,
#         "ingestion_timestamp": 0.0,
#         "source_file": 0.0,
#         "batch_id": 0.0,
#         "transaction_date": 1.4925373134328357,
#         "transaction_time": 1.4925373134328357,
#         "year_month": 1.4925373134328357,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {
#         "merchant": 41.7910447761194,
#         "category": 40.298507462686565
#       },
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:49:08.641988"
#     },
#     "validation_results": {
#       "validation_results": {
#         "valid_transaction_type": {
#           "description": "Transaction type must be one of the valid types",
#           "failing_count": 31,
#           "failing_percentage": 46.26865671641791,
#           "passed": false
#         },
#         "valid_status": {
#           "description": "Status must be one of the valid statuses",
#           "failing_count": 29,
#           "failing_percentage": 43.28358208955223,
#           "passed": false
#         },
#         "valid_currency": {
#           "description": "Currency code should be 3 characters if present",
#           "failing_count": 1,
#           "failing_percentage": 1.4925373134328357,
#           "passed": false
#         },
#         "valid_timestamp": {
#           "description": "Timestamp must not be NULL or in the future",
#           "failing_count": 1,
#           "failing_percentage": 1.4925373134328357,
#           "passed": false
#         }
#       },
#       "sample_size": 67,
#       "sample_ratio": 0.05,
#       "timestamp": "2025-04-24T15:49:12.195769",
#       "all_passed": false
#     },
#     "source_bronze_version": 5,
#     "duration_seconds": 21.709290027618408
#   }
# }
# 2025-04-24 15:49:12,197 - INFO - Silver layer processing completed in 21.71 seconds
# 2025-04-24 15:49:12,199 - INFO - Starting table optimization
# 2025-04-24 15:49:22,215 - INFO - Optimized de_pipelines.financial_osb_silver_type1. Files: before=15, after=15
# 2025-04-24 15:49:22,217 - INFO - --Silver layer successfully optimized in 10.02 seconds--
# 2025-04-24 15:49:22,218 - INFO - -- Gold layer not defined --
# 2025-04-24 15:49:22,220 - INFO - ---Full pipeline execution completed successfully in 49.36 seconds---
# 2025-04-24 15:49:23,096 - INFO - Spark session stopped
# {'status': 'success',
#  'pipeline_id': 'Financial_DE_Pipeline_20250424_154832',
#  'bronze_version': 5,
#  'silver_version': 6,
#  'timestamp': '2025-04-24T15:49:22.222828',
#  'duration_seconds': 49.357311964035034,
#  'metrics': {'pipeline_id': 'Financial_DE_Pipeline_20250424_154832',
#   'start_time': '2025-04-24T15:48:32.863503',
#   'stages': {'bronze': {'duration_seconds': 15.616908073425293,
#     'version': 5,
#     'status': 'success'},
#    'bronze_optimize': {'layer': 'bronze',
#     'duration_seconds': 2.0020623207092285,
#     'status': 'success'},
#    'silver': {'duration_seconds': 21.71529245376587,
#     'version': 6,
#     'status': 'success',
#     'source_bronze_version': 5},
#    'silver_optimize': {'layer': 'silver',
#     'duration_seconds': 10.017763137817383,
#     'status': 'success'}},
#   'status': 'success',
#   'end_time': '2025-04-24T15:49:22.220815',
#   'total_duration_seconds': 49.357311964035034}}
