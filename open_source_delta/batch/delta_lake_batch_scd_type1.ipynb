# %% [markdown]
# ##### Local Environment Setup

# %%
import os
import sys
# Set JAVA env variable
os.environ["JAVA_HOME"] = r"C:\Program Files\Eclipse Adoptium\jdk-11.0.26.4-hotspot"
# Set Hadoop environment variables 
os.environ['HADOOP_HOME'] = r'C:\hadoop'
os.environ['PATH'] = os.environ['HADOOP_HOME'] + r'\bin;' + os.environ['PATH']
# Set the Python executable path explicitly
os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

# Get Pipeline Tools Path
sys.path.append(R'C:\GitHub\Tools\de')

# %% [markdown]
# ##### Libraries

# %%
import time
import logging
from datetime import datetime

import numpy as np
import pandas as pd

from typing import Dict


from pyspark.sql import SparkSession
from pyspark.sql import DataFrame
from pyspark.sql import functions as F
from pyspark.sql.types import (StructType, StructField, StringType, 
                            DoubleType, IntegerType, TimestampType, 
                            DateType)
from delta.tables import DeltaTable

# %%
from de_pipeline_tools import *

# %% [markdown]
# ##### Spark Session

# %%
spark = initialize_local_spark_delta_lake("Financial Data Pipeline")
# Out:
# 2025-04-17 13:33:35,200 - INFO - ---Spark session initialized with Delta Lake support---

# %%
# Create a database in the Hive warehouse if doesn't exist
spark.sql("CREATE DATABASE IF NOT EXISTS de_pipelines LOCATION 'C:/hive-warehouse/de_pipelines'")
# Out:
# DataFrame[]

# %% [markdown]
# ## SCD Type 1:
# ##### Intial Creation (Overwrite)

# %% [markdown]
# ##### Inputs/Outputs

# %%
# Intial Creation
data_dir = "../../data"
file_list = [
    "financial_transactions_20250409_113413.csv",
    "financial_transactions_20250410_113413.csv"
]

abs_file_list = []
for file in file_list:
    # Join data_dir with filename
    relative_path = os.path.join(data_dir, file)
    # Convert to absolute path
    abs_path = os.path.abspath(relative_path)
    abs_file_list.append(abs_path)

bronze_table = 'de_pipelines.financial_osb_bronze_type1'
silver_table = 'de_pipelines.financial_osb_silver_type1'
gold_table   = 'de_pipelines.financial_osb_gold_type1'

# %%
def get_schema():
    return StructType([
    StructField("transaction_id", StringType(), False),
    StructField("timestamp", StringType(), True), #load in as string type, handle in silver step     
    StructField("customer_id", StringType(), True),      
    StructField("account_number", StringType(), True),   
    StructField("transaction_type", StringType(), True), 
    StructField("amount", DoubleType(), True),           
    StructField("currency", StringType(), True),         
    StructField("balance_after", DoubleType(), True),    
    StructField("status", StringType(), True),           
    StructField("merchant", StringType(), True),         
    StructField("category", StringType(), True),         
    StructField("location", StringType(), True)          
])

# %% [markdown]
# #### Define: Validation Rules, Transformations, Write Executions

# %%
def bronze_writer(df: DataFrame, table_name: str) -> None:
    (df.write
        .format("delta")
        .mode("overwrite")
        .option("overwriteSchema", "true")
        .saveAsTable(table_name)
    )

    # Get delta operation metrics
    metricsdf = spark.sql(f"DESCRIBE HISTORY {table_name} LIMIT 1")
    metrics = metricsdf.select("operationMetrics").collect()[0][0]
    
    return metrics

# %%
# Define bronze validation rules
bronze_validation_rules = [
    {
        "name": "has_transaction_id",
        "condition": "transaction_id IS NOT NULL",
        "description": "Transaction ID must be present"
    },
    {
        "name": "valid_amount",
        "condition": "amount IS NOT NULL AND amount > 0",
        "description": "Amount must be positive if not null"
    },
    {
        "name": "valid_timestamp",
        "condition": "timestamp IS NOT NULL AND timestamp <= current_timestamp()",
        "description": "Timestamp must not be in the future"
    }
]

# %%
def silver_transform(df:DataFrame) -> DataFrame:

    # Clean any non-timestamp characters first
    df = df.withColumn(
        "transaction_timestamp", 
        F.regexp_replace(F.col("timestamp"), "[^0-9\\-: ]", "")
    )

    # Use try_cast to handle invalid timestamps gracefully by returning NULL
#     df = df.withColumn(
#         "transaction_timestamp",
#         F.expr("try_cast(transaction_timestamp as timestamp)")
#     )

    # Cast to timestamp type
    df = df.withColumn("transaction_timestamp", F.col("transaction_timestamp").cast("timestamp"))

    # Remove duplicates
    df = df.dropDuplicates(subset=["transaction_id","transaction_timestamp"])

    # Standardize Data
    df = (df
            .withColumn("amount", F.abs(F.col("amount")))
            .withColumn("transaction_type", F.lower(F.col("transaction_type")))
            .withColumn("category", F.lower(F.col("category")))
            .withColumn("status", F.lower(F.col("status")))
    )

    # Filter Data
    # Address bronze layer data validation check concerns
    df = df.filter(
                    (F.col('transaction_id').isNotNull()) # transaction id must exist
                    & (F.col('account_number').isNotNull()) # account number must exist
                    & (F.col('amount') > 0) # amount must be positive
                    & ((F.col('transaction_timestamp') <= F.current_date()) # must be <= current date
                    |(F.col('transaction_timestamp').isNull()))# or must be Null, no future timestamps
    ) 
    
    # Split timestamp into date and time and year_month for paritioning
    df = (df
            .withColumn("transaction_date", F.to_date("transaction_timestamp"))
            .withColumn("transaction_time", F.date_format("transaction_timestamp", "HH:mm:ss"))
            .withColumn("year_month", F.date_format(F.col("transaction_date"), "yyyy-MM"))
    )
    
    # Add processing timestamp for bookkeeping
    df = (df
            .withColumn("processing_timestamp", F.current_timestamp())
    )

    return df

# %%
def silver_writer(df: DataFrame, table_name: str) -> None:
    (df.write
        .format("delta")
        .mode("overwrite")
        .option("overwriteSchema", "true")
        .partitionBy("year_month")
        .saveAsTable(table_name)
    )

    # Get delta operation metrics
    metricsdf = spark.sql(f"DESCRIBE HISTORY {table_name} LIMIT 1")
    metrics = metricsdf.select("operationMetrics").collect()[0][0]

    return metrics

# %%
# Define silver validation rules
silver_validation_rules = [
    {
        "name": "valid_transaction_type",
        "condition": "transaction_type IN ('debit', 'credit', 'transfer', 'payment', 'withdrawal', 'deposit') OR transaction_type IS NULL",
        "description": "Transaction type must be one of the valid types"
    },
    {
        "name": "valid_status",
        "condition": "status IN ('completed', 'pending', 'failed', 'cancelled', 'refunded') OR status IS NULL",
        "description": "Status must be one of the valid statuses"
    },
    {
        "name": "valid_currency",
        "condition": "currency IS NOT NULL AND length(currency) = 3",
        "description": "Currency code should be 3 characters if present"
    },
    {
        "name": "valid_transaction_timestamp",
        "condition": "transaction_timestamp IS NOT NULL AND transaction_timestamp <= current_timestamp()",
        "description": "Transaction timestamp must not be NULL or in the future"
    }
]

# %%
def gold_transform(df:DataFrame) -> Dict:
    gold_dfs = {}

    # Gold aggregation 1: Daily summary by category
    daily_category = (df
        .groupBy("transaction_date", "category")
        .agg(
            F.count("transaction_id").alias("transaction_count"),
            F.sum("amount").alias("total_amount"),
            F.avg("amount").alias("avg_amount"),
            F.min("amount").alias("min_amount"),
            F.max("amount").alias("max_amount"),
            F.countDistinct("customer_id").alias("unique_customers")
        )
        .withColumn("processing_timestamp", F.current_timestamp())
    )
    
    gold_dfs["daily_category"] = daily_category
    
    # Gold aggregation 2: Customer summary
    customer_summary = (df
        .groupBy("customer_id")
        .agg(
            F.count("transaction_id").alias("transaction_count"),
            F.sum("amount").alias("total_amount"),
            F.avg("amount").alias("avg_amount"),
            F.min("transaction_date").alias("first_transaction_date"),
            F.max("transaction_date").alias("last_transaction_date"),
            F.approx_count_distinct("category").alias("category_count")
        )
        .withColumn("processing_timestamp", F.current_timestamp())
        .withColumn("days_since_last_transaction", 
                    F.datediff(F.current_date(), F.col("last_transaction_date")))
    )
    
    gold_dfs["customer_summary"] = customer_summary
    
    # Gold aggregation 3: Transaction type summary
    transaction_type_summary = (df
        .groupBy("transaction_type")
        .agg(
            F.count("transaction_id").alias("transaction_count"),
            F.sum("amount").alias("total_amount"),
            F.avg("amount").alias("avg_amount")
        )
        .withColumn("processing_timestamp", F.current_timestamp())
    )
    
    gold_dfs["transaction_type_summary"] = transaction_type_summary

    return gold_dfs

# %%
def gold_writer(df: DataFrame, table_name: str) -> None:
    (df.write
        .format("delta")
        .mode("overwrite")
        .option("overwriteSchema", "true")
        .saveAsTable(table_name)
    )

    # Get delta operation metrics
    metricsdf = spark.sql(f"DESCRIBE HISTORY {table_name} LIMIT 1")
    metrics = metricsdf.select("operationMetrics").collect()[0][0]

    return metrics

# %%
# Define gold validation rules
gold_validation_rules = [
    {
        "name": "positive_transaction_counts",
        "condition": "transaction_count > 0",
        "description": "Transaction counts should be positive"
    },
    {
        "name": "valid_total_amounts",
        "condition": "total_amount >= 0",
        "description": "Total amounts should not be negative"
    }
]

# %% [markdown]
# ### Running Full Batch Pipeline

# %%
run_batch_de_pipeline(spark, 'csv', abs_file_list, get_schema(), 
                     bronze_table, silver_table, gold_table, 
                     bronze_transform=None, silver_transform=silver_transform, gold_transform=gold_transform,
                     bronze_writer=bronze_writer, silver_writer=silver_writer, gold_writer=gold_writer,
                     bronze_validation_rules=bronze_validation_rules, 
                     silver_validation_rules=silver_validation_rules, 
                     gold_validation_rules=gold_validation_rules,
                     pipeline_name='Financial_DE_Pipeline')
# Out:
# 2025-04-17 13:33:36,321 - INFO - --Starting data pipeline execution with ID: Financial_DE_Pipeline_20250417_133336--
# 2025-04-17 13:33:36,323 - INFO - Starting bronze layer processing
# 2025-04-17 13:33:37,120 - INFO - Successfully read CSV data from:
#   - c:\GitHub\DE_Pipelines\data\financial_transactions_20250409_113413.csv
#   - c:\GitHub\DE_Pipelines\data\financial_transactions_20250410_113413.csv
# 2025-04-17 13:33:37,122 - INFO - No transformation function defined
# 2025-04-17 13:34:13,028 - INFO - Successfully wrote bronze table: de_pipelines.financial_osb_bronze_type1
# 2025-04-17 13:34:13,031 - INFO - Write Metrics:
# {
#   "numOutputRows": "1000",
#   "numOutputBytes": "52334",
#   "numFiles": "2"
# }
# 2025-04-17 13:34:14,487 - INFO - Running data quality checks for bronze layer
# 2025-04-17 13:34:20,005 - INFO - Data Quality Metrics for bronze layer:
# 2025-04-17 13:34:20,007 - INFO -   - Shape: [15,1000] (approx. row count)
# 2025-04-17 13:34:20,009 - INFO -   - Schema:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- account_number: string (nullable = true)
#  |-- transaction_type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- balance_after: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#  |-- source_file: string (nullable = false)
#  |-- batch_id: string (nullable = false)
#
# 2025-04-17 13:34:20,012 - INFO -   - Sample size: 95
# 2025-04-17 13:34:20,014 - WARNING -   - Columns with high null percentages: {'merchant': 47.368421052631575, 'category': 49.473684210526315}
# 2025-04-17 13:34:20,016 - INFO - Validating dataframe with 3 rules
# 2025-04-17 13:34:20,671 - INFO - Validation rule 'has_transaction_id' FAILED - 1 records (1.05%) failed
# 2025-04-17 13:34:21,059 - INFO - Validation rule 'valid_amount' FAILED - 66 records (69.47%) failed
# 2025-04-17 13:34:21,371 - INFO - Validation rule 'valid_timestamp' FAILED - 2 records (2.11%) failed
# 2025-04-17 13:34:21,375 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250417_133336",
#   "layer": "bronze",
#   "version": 20,
#   "timestamp": "2025-04-17T13:34:21.375368",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "bronze",
#       "shape": "[15,1000] (approx. row count)",
#       "schema": "root\n |-- transaction_id: string (nullable = true)\n |-- timestamp: string (nullable = true)\n |-- customer_id: string (nullable = true)\n |-- account_number: string (nullable = true)\n |-- transaction_type: string (nullable = true)\n |-- amount: double (nullable = true)\n |-- currency: string (nullable = true)\n |-- balance_after: double (nullable = true)\n |-- status: string (nullable = true)\n |-- merchant: string (nullable = true)\n |-- category: string (nullable = true)\n |-- location: string (nullable = true)\n |-- ingestion_timestamp: timestamp (nullable = false)\n |-- source_file: string (nullable = false)\n |-- batch_id: string (nullable = false)\n",
#       "sample_size": 95,
#       "null_percentages": {
#         "transaction_id": 1.0526315789473684,
#         "timestamp": 2.1052631578947367,
#         "customer_id": 0.0,
#         "account_number": 2.1052631578947367,
#         "transaction_type": 2.1052631578947367,
#         "amount": 0.0,
#         "currency": 2.1052631578947367,
#         "balance_after": 0.0,
#         "status": 2.1052631578947367,
#         "merchant": 47.368421052631575,
#         "category": 49.473684210526315,
#         "location": 0.0,
#         "ingestion_timestamp": 0.0,
#         "source_file": 0.0,
#         "batch_id": 0.0
#       },
#       "high_null_columns": {
#         "merchant": 47.368421052631575,
#         "category": 49.473684210526315
#       },
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-17T13:34:20.005500"
#     },
#     "validation_results": {
#       "validation_results": {
#         "has_transaction_id": {
#           "description": "Transaction ID must be present",
#           "failing_count": 1,
#           "failing_percentage": 1.0526315789473684,
#           "passed": false
#         },
#         "valid_amount": {
#           "description": "Amount must be positive if not null",
#           "failing_count": 66,
#           "failing_percentage": 69.47368421052632,
#           "passed": false
#         },
#         "valid_timestamp": {
#           "description": "Timestamp must not be in the future",
#           "failing_count": 2,
#           "failing_percentage": 2.1052631578947367,
#           "passed": false
#         }
#       },
#       "sample_size": 95,
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-17T13:34:21.375368",
#       "all_passed": false
#     },
#     "source_path": [
#       "c:\\GitHub\\DE_Pipelines\\data\\financial_transactions_20250409_113413.csv",
#       "c:\\GitHub\\DE_Pipelines\\data\\financial_transactions_20250410_113413.csv"
#     ],
#     "duration_seconds": 45.049487352371216
#   }
# }
# 2025-04-17 13:34:21,377 - INFO - Bronze layer processing completed in 45.05 seconds
# 2025-04-17 13:34:21,381 - INFO - Starting table optimization
# 2025-04-17 13:34:33,183 - INFO - Optimized de_pipelines.financial_osb_bronze_type1. Files: before=2, after=1
# 2025-04-17 13:34:33,185 - INFO - --Bronze layer successfully optimized in 11.80 seconds--
# 2025-04-17 13:34:33,187 - INFO - Starting silver layer processing
# 2025-04-17 13:34:33,469 - INFO - Successfully read bronze data version 20
# 2025-04-17 13:34:33,688 - INFO - Transformation function applied
# 2025-04-17 13:34:48,219 - INFO - Successfully wrote silver table: de_pipelines.financial_osb_silver_type1
# 2025-04-17 13:34:48,221 - INFO - Write Metrics:
# {
#   "numOutputRows": "950",
#   "numOutputBytes": "158085",
#   "numFiles": "13"
# }
# 2025-04-17 13:34:48,684 - INFO - Running data quality checks for silver layer
# 2025-04-17 13:35:00,383 - INFO - Data Quality Metrics for silver layer:
# 2025-04-17 13:35:00,386 - INFO -   - Shape: [20,950] (approx. row count)
# 2025-04-17 13:35:00,387 - INFO -   - Schema:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- account_number: string (nullable = true)
#  |-- transaction_type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- balance_after: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = true)
#  |-- source_file: string (nullable = true)
#  |-- batch_id: string (nullable = true)
#  |-- transaction_timestamp: timestamp (nullable = true)
#  |-- transaction_date: date (nullable = true)
#  |-- transaction_time: string (nullable = true)
#  |-- year_month: string (nullable = true)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-17 13:35:00,390 - INFO -   - Sample size: 92
# 2025-04-17 13:35:00,391 - WARNING -   - Columns with high null percentages: {'merchant': 48.91304347826087, 'category': 46.73913043478261}
# 2025-04-17 13:35:00,392 - INFO - Validating dataframe with 4 rules
# 2025-04-17 13:35:07,859 - INFO - Validation rule 'valid_transaction_type' FAILED - 38 records (41.30%) failed
# 2025-04-17 13:35:09,406 - INFO - Validation rule 'valid_status' FAILED - 39 records (42.39%) failed
# 2025-04-17 13:35:11,124 - INFO - Validation rule 'valid_currency' FAILED - 3 records (3.26%) failed
# 2025-04-17 13:35:12,523 - INFO - Validation rule 'valid_transaction_timestamp' FAILED - 1 records (1.09%) failed
# 2025-04-17 13:35:12,529 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250417_133336",
#   "layer": "silver",
#   "version": 14,
#   "timestamp": "2025-04-17T13:35:12.528219",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "silver",
#       "shape": "[20,950] (approx. row count)",
#       "schema": "root\n |-- transaction_id: string (nullable = true)\n |-- timestamp: string (nullable = true)\n |-- customer_id: string (nullable = true)\n |-- account_number: string (nullable = true)\n |-- transaction_type: string (nullable = true)\n |-- amount: double (nullable = true)\n |-- currency: string (nullable = true)\n |-- balance_after: double (nullable = true)\n |-- status: string (nullable = true)\n |-- merchant: string (nullable = true)\n |-- category: string (nullable = true)\n |-- location: string (nullable = true)\n |-- ingestion_timestamp: timestamp (nullable = true)\n |-- source_file: string (nullable = true)\n |-- batch_id: string (nullable = true)\n |-- transaction_timestamp: timestamp (nullable = true)\n |-- transaction_date: date (nullable = true)\n |-- transaction_time: string (nullable = true)\n |-- year_month: string (nullable = true)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 92,
#       "null_percentages": {
#         "transaction_id": 0.0,
#         "timestamp": 1.0869565217391304,
#         "customer_id": 1.0869565217391304,
#         "account_number": 0.0,
#         "transaction_type": 3.260869565217391,
#         "amount": 0.0,
#         "currency": 3.260869565217391,
#         "balance_after": 1.0869565217391304,
#         "status": 1.0869565217391304,
#         "merchant": 48.91304347826087,
#         "category": 46.73913043478261,
#         "location": 0.0,
#         "ingestion_timestamp": 0.0,
#         "source_file": 0.0,
#         "batch_id": 0.0,
#         "transaction_timestamp": 1.0869565217391304,
#         "transaction_date": 1.0869565217391304,
#         "transaction_time": 1.0869565217391304,
#         "year_month": 1.0869565217391304,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {
#         "merchant": 48.91304347826087,
#         "category": 46.73913043478261
#       },
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-17T13:35:00.383351"
#     },
#     "validation_results": {
#       "validation_results": {
#         "valid_transaction_type": {
#           "description": "Transaction type must be one of the valid types",
#           "failing_count": 38,
#           "failing_percentage": 41.30434782608695,
#           "passed": false
#         },
#         "valid_status": {
#           "description": "Status must be one of the valid statuses",
#           "failing_count": 39,
#           "failing_percentage": 42.391304347826086,
#           "passed": false
#         },
#         "valid_currency": {
#           "description": "Currency code should be 3 characters if present",
#           "failing_count": 3,
#           "failing_percentage": 3.260869565217391,
#           "passed": false
#         },
#         "valid_transaction_timestamp": {
#           "description": "Transaction timestamp must not be NULL or in the future",
#           "failing_count": 1,
#           "failing_percentage": 1.0869565217391304,
#           "passed": false
#         }
#       },
#       "sample_size": 92,
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-17T13:35:12.528219",
#       "all_passed": false
#     },
#     "source_bronze_version": 20,
#     "duration_seconds": 39.339667320251465
#   }
# }
# 2025-04-17 13:35:12,530 - INFO - Silver layer processing completed in 39.34 seconds
# 2025-04-17 13:35:12,532 - INFO - Starting table optimization
# 2025-04-17 13:35:24,896 - INFO - Optimized de_pipelines.financial_osb_silver_type1. Files: before=13, after=13
# 2025-04-17 13:35:24,897 - INFO - --Silver layer successfully optimized in 12.37 seconds--
# 2025-04-17 13:35:24,899 - INFO - Starting gold layer processing
# 2025-04-17 13:35:25,131 - INFO - Successfully read silver data version 14
# 2025-04-17 13:35:25,299 - INFO - Transformation function applied
# 2025-04-17 13:35:38,553 - INFO - Successfully wrote gold table: de_pipelines.financial_osb_gold_type1_daily_category
# 2025-04-17 13:35:38,555 - INFO - Write Metrics:
# {
#   "numOutputRows": "702",
#   "numOutputBytes": "20694",
#   "numFiles": "1"
# }
# 2025-04-17 13:35:38,963 - INFO - Running data quality checks for de_pipelines.financial_osb_gold_type1_daily_category layer
# 2025-04-17 13:35:47,648 - INFO - Data Quality Metrics for de_pipelines.financial_osb_gold_type1_daily_category layer:
# 2025-04-17 13:35:47,649 - INFO -   - Shape: [9,702] (approx. row count)
# 2025-04-17 13:35:47,650 - INFO -   - Schema:
# root
#  |-- transaction_date: date (nullable = true)
#  |-- category: string (nullable = true)
#  |-- transaction_count: long (nullable = false)
#  |-- total_amount: double (nullable = true)
#  |-- avg_amount: double (nullable = true)
#  |-- min_amount: double (nullable = true)
#  |-- max_amount: double (nullable = true)
#  |-- unique_customers: long (nullable = false)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-17 13:35:47,653 - INFO -   - Sample size: 151
# 2025-04-17 13:35:47,655 - WARNING -   - Columns with high null percentages: {'category': 40.397350993377486}
# 2025-04-17 13:35:47,656 - INFO - Validating dataframe with 2 rules
# 2025-04-17 13:35:53,261 - INFO - Validation rule 'positive_transaction_counts' PASSED - 0 records (0.00%) failed
# 2025-04-17 13:35:55,325 - INFO - Validation rule 'valid_total_amounts' PASSED - 0 records (0.00%) failed
# 2025-04-17 13:35:55,331 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250417_133336",
#   "layer": "gold_daily_category",
#   "version": 4,
#   "timestamp": "2025-04-17T13:35:55.331952",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "de_pipelines.financial_osb_gold_type1_daily_category",
#       "shape": "[9,702] (approx. row count)",
#       "schema": "root\n |-- transaction_date: date (nullable = true)\n |-- category: string (nullable = true)\n |-- transaction_count: long (nullable = false)\n |-- total_amount: double (nullable = true)\n |-- avg_amount: double (nullable = true)\n |-- min_amount: double (nullable = true)\n |-- max_amount: double (nullable = true)\n |-- unique_customers: long (nullable = false)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 151,
#       "null_percentages": {
#         "transaction_date": 0.0,
#         "category": 40.397350993377486,
#         "transaction_count": 0.0,
#         "total_amount": 0.0,
#         "avg_amount": 0.0,
#         "min_amount": 0.0,
#         "max_amount": 0.0,
#         "unique_customers": 0.0,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {
#         "category": 40.397350993377486
#       },
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-17T13:35:47.648242"
#     },
#     "validation_results": {
#       "validation_results": {
#         "positive_transaction_counts": {
#           "description": "Transaction counts should be positive",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_total_amounts": {
#           "description": "Total amounts should not be negative",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         }
#       },
#       "sample_size": 151,
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-17T13:35:55.331952",
#       "all_passed": true
#     },
#     "source_silver_version": 14
#   }
# }
# 2025-04-17 13:36:02,446 - INFO - Successfully wrote gold table: de_pipelines.financial_osb_gold_type1_customer_summary
# 2025-04-17 13:36:02,448 - INFO - Write Metrics:
# {
#   "numOutputRows": "217",
#   "numOutputBytes": "9353",
#   "numFiles": "1"
# }
# 2025-04-17 13:36:02,763 - INFO - Running data quality checks for de_pipelines.financial_osb_gold_type1_customer_summary layer
# 2025-04-17 13:36:12,826 - INFO - Data Quality Metrics for de_pipelines.financial_osb_gold_type1_customer_summary layer:
# 2025-04-17 13:36:12,827 - INFO -   - Shape: [9,217] (approx. row count)
# 2025-04-17 13:36:12,829 - INFO -   - Schema:
# root
#  |-- customer_id: string (nullable = true)
#  |-- transaction_count: long (nullable = false)
#  |-- total_amount: double (nullable = true)
#  |-- avg_amount: double (nullable = true)
#  |-- first_transaction_date: date (nullable = true)
#  |-- last_transaction_date: date (nullable = true)
#  |-- category_count: long (nullable = false)
#  |-- processing_timestamp: timestamp (nullable = false)
#  |-- days_since_last_transaction: integer (nullable = true)
#
# 2025-04-17 13:36:12,832 - INFO -   - Sample size: 51
# 2025-04-17 13:36:12,833 - INFO - Validating dataframe with 2 rules
# 2025-04-17 13:36:18,458 - INFO - Validation rule 'positive_transaction_counts' PASSED - 0 records (0.00%) failed
# 2025-04-17 13:36:20,418 - INFO - Validation rule 'valid_total_amounts' PASSED - 0 records (0.00%) failed
# 2025-04-17 13:36:20,425 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250417_133336",
#   "layer": "gold_customer_summary",
#   "version": 4,
#   "timestamp": "2025-04-17T13:36:20.425801",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "de_pipelines.financial_osb_gold_type1_customer_summary",
#       "shape": "[9,217] (approx. row count)",
#       "schema": "root\n |-- customer_id: string (nullable = true)\n |-- transaction_count: long (nullable = false)\n |-- total_amount: double (nullable = true)\n |-- avg_amount: double (nullable = true)\n |-- first_transaction_date: date (nullable = true)\n |-- last_transaction_date: date (nullable = true)\n |-- category_count: long (nullable = false)\n |-- processing_timestamp: timestamp (nullable = false)\n |-- days_since_last_transaction: integer (nullable = true)\n",
#       "sample_size": 51,
#       "null_percentages": {
#         "customer_id": 0.0,
#         "transaction_count": 0.0,
#         "total_amount": 0.0,
#         "avg_amount": 0.0,
#         "first_transaction_date": 0.0,
#         "last_transaction_date": 0.0,
#         "category_count": 0.0,
#         "processing_timestamp": 0.0,
#         "days_since_last_transaction": 0.0
#       },
#       "high_null_columns": {},
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-17T13:36:12.826588"
#     },
#     "validation_results": {
#       "validation_results": {
#         "positive_transaction_counts": {
#           "description": "Transaction counts should be positive",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_total_amounts": {
#           "description": "Total amounts should not be negative",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         }
#       },
#       "sample_size": 51,
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-17T13:36:20.425801",
#       "all_passed": true
#     },
#     "source_silver_version": 14
#   }
# }
# 2025-04-17 13:36:27,173 - INFO - Successfully wrote gold table: de_pipelines.financial_osb_gold_type1_transaction_type_summary
# 2025-04-17 13:36:27,175 - INFO - Write Metrics:
# {
#   "numOutputRows": "17",
#   "numOutputBytes": "2150",
#   "numFiles": "1"
# }
# 2025-04-17 13:36:27,573 - INFO - Running data quality checks for de_pipelines.financial_osb_gold_type1_transaction_type_summary layer
# 2025-04-17 13:36:34,346 - INFO - Data Quality Metrics for de_pipelines.financial_osb_gold_type1_transaction_type_summary layer:
# 2025-04-17 13:36:34,348 - INFO -   - Shape: [5,17] (approx. row count)
# 2025-04-17 13:36:34,349 - INFO -   - Schema:
# root
#  |-- transaction_type: string (nullable = true)
#  |-- transaction_count: long (nullable = false)
#  |-- total_amount: double (nullable = true)
#  |-- avg_amount: double (nullable = true)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-17 13:36:34,351 - INFO -   - Sample size: 3
# 2025-04-17 13:36:34,353 - INFO - Validating dataframe with 2 rules
# 2025-04-17 13:36:39,531 - INFO - Validation rule 'positive_transaction_counts' PASSED - 0 records (0.00%) failed
# 2025-04-17 13:36:41,067 - INFO - Validation rule 'valid_total_amounts' PASSED - 0 records (0.00%) failed
# 2025-04-17 13:36:41,073 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250417_133336",
#   "layer": "gold_transaction_type_summary",
#   "version": 4,
#   "timestamp": "2025-04-17T13:36:41.073364",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "de_pipelines.financial_osb_gold_type1_transaction_type_summary",
#       "shape": "[5,17] (approx. row count)",
#       "schema": "root\n |-- transaction_type: string (nullable = true)\n |-- transaction_count: long (nullable = false)\n |-- total_amount: double (nullable = true)\n |-- avg_amount: double (nullable = true)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 3,
#       "null_percentages": {
#         "transaction_type": 0.0,
#         "transaction_count": 0.0,
#         "total_amount": 0.0,
#         "avg_amount": 0.0,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {},
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-17T13:36:34.346919"
#     },
#     "validation_results": {
#       "validation_results": {
#         "positive_transaction_counts": {
#           "description": "Transaction counts should be positive",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_total_amounts": {
#           "description": "Total amounts should not be negative",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         }
#       },
#       "sample_size": 3,
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-17T13:36:41.073364",
#       "all_passed": true
#     },
#     "source_silver_version": 14
#   }
# }
# 2025-04-17 13:36:41,075 - INFO - Gold layer processing completed in 76.17 seconds
# 2025-04-17 13:36:41,076 - INFO - Starting table optimization
# 2025-04-17 13:36:42,842 - INFO - Optimized de_pipelines.financial_osb_gold_type1_daily_category. Files: before=1, after=1
# 2025-04-17 13:36:42,844 - INFO - Starting table optimization
# 2025-04-17 13:36:44,943 - INFO - Optimized de_pipelines.financial_osb_gold_type1_customer_summary. Files: before=1, after=1
# 2025-04-17 13:36:44,944 - INFO - Starting table optimization
# 2025-04-17 13:36:46,801 - INFO - Optimized de_pipelines.financial_osb_gold_type1_transaction_type_summary. Files: before=1, after=1
# 2025-04-17 13:36:46,802 - INFO - --Gold layer successfully optimized in 5.73 seconds--
# 2025-04-17 13:36:46,803 - INFO - ---Full pipeline execution completed successfully in 190.48 seconds---
# 2025-04-17 13:36:48,269 - INFO - Spark session stopped
# {'status': 'success',
#  'pipeline_id': 'Financial_DE_Pipeline_20250417_133336',
#  'bronze_version': 20,
#  'silver_version': 14,
#  'timestamp': '2025-04-17T13:36:46.806846',
#  'duration_seconds': 190.48249983787537,
#  'metrics': {'pipeline_id': 'Financial_DE_Pipeline_20250417_133336',
#   'start_time': '2025-04-17T13:33:36.321350',
#   'stages': {'bronze': {'duration_seconds': 45.059016942977905,
#     'version': 20,
#     'status': 'success'},
#    'bronze_optimize': {'layer': 'bronze',
#     'duration_seconds': 11.804271221160889,
#     'status': 'success'},
#    'silver': {'duration_seconds': 39.34456992149353,
#     'version': 14,
#     'status': 'success',
#     'source_bronze_version': 20},
#    'silver_optimize': {'layer': 'silver',
#     'duration_seconds': 12.365763425827026,
#     'status': 'success'},
#    'gold': {'duration_seconds': 76.17637181282043,
#     'status': 'success',
#     'source_silver_version': 14,
#     'tables': ['daily_category',
#      'customer_summary',
#      'transaction_type_summary']},
#    'gold_optimize': {'layer': 'gold',
#     'duration_seconds': 5.726491212844849,
#     'status': 'success'}},
#   'status': 'success',
#   'end_time': '2025-04-17T13:36:46.803850',
#   'total_duration_seconds': 190.48249983787537}}

# %% [markdown]
# ### Running Layers In Isolation

# %%
spark = initialize_local_spark_delta_lake("Financial Data Pipeline - Testing")
# Out:
# 2025-04-17 13:36:48,289 - INFO - ---Spark session initialized with Delta Lake support---

# %% [markdown]
# #### Bronze

# %%
bronzedf, bronze_version = process_batch_bronze_layer(spark, 'csv', abs_file_list, get_schema(), bronze_table,
                               bronze_transform=None, validation_rules=bronze_validation_rules,
                               pipeline_id='test', mode='test', bronze_writer=bronze_writer)
# Out:
# 2025-04-17 13:36:50,129 - INFO - Starting bronze layer processing
# 2025-04-17 13:36:50,189 - INFO - Successfully read CSV data from:
#   - c:\GitHub\DE_Pipelines\data\financial_transactions_20250409_113413.csv
#   - c:\GitHub\DE_Pipelines\data\financial_transactions_20250410_113413.csv
# 2025-04-17 13:36:50,190 - INFO - No transformation function defined
# 2025-04-17 13:36:50,191 - WARNING - --- Bronze layer in Test Mode ---
# 2025-04-17 13:36:50,194 - INFO - Running data quality checks for bronze layer
# 2025-04-17 13:36:54,446 - INFO - Data Quality Metrics for bronze layer:
# 2025-04-17 13:36:54,447 - INFO -   - Shape: [15,1000] (approx. row count)
# 2025-04-17 13:36:54,449 - INFO -   - Schema:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- account_number: string (nullable = true)
#  |-- transaction_type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- balance_after: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#  |-- source_file: string (nullable = false)
#  |-- batch_id: string (nullable = false)
#
# 2025-04-17 13:36:54,450 - INFO -   - Sample size: 95
# 2025-04-17 13:36:54,452 - WARNING -   - Columns with high null percentages: {'merchant': 47.368421052631575, 'category': 49.473684210526315}
# 2025-04-17 13:36:54,453 - INFO - Validating dataframe with 3 rules
# 2025-04-17 13:36:54,747 - INFO - Validation rule 'has_transaction_id' FAILED - 1 records (1.05%) failed
# 2025-04-17 13:36:54,861 - INFO - Validation rule 'valid_amount' FAILED - 66 records (69.47%) failed
# 2025-04-17 13:36:54,950 - INFO - Validation rule 'valid_timestamp' FAILED - 2 records (2.11%) failed
# 2025-04-17 13:36:54,953 - INFO - Checkpoint created:
# {
#   "pipeline_id": "test",
#   "layer": "bronze",
#   "version": "test",
#   "timestamp": "2025-04-17T13:36:54.952992",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "bronze",
#       "shape": "[15,1000] (approx. row count)",
#       "schema": "root\n |-- transaction_id: string (nullable = true)\n |-- timestamp: string (nullable = true)\n |-- customer_id: string (nullable = true)\n |-- account_number: string (nullable = true)\n |-- transaction_type: string (nullable = true)\n |-- amount: double (nullable = true)\n |-- currency: string (nullable = true)\n |-- balance_after: double (nullable = true)\n |-- status: string (nullable = true)\n |-- merchant: string (nullable = true)\n |-- category: string (nullable = true)\n |-- location: string (nullable = true)\n |-- ingestion_timestamp: timestamp (nullable = false)\n |-- source_file: string (nullable = false)\n |-- batch_id: string (nullable = false)\n",
#       "sample_size": 95,
#       "null_percentages": {
#         "transaction_id": 1.0526315789473684,
#         "timestamp": 2.1052631578947367,
#         "customer_id": 0.0,
#         "account_number": 2.1052631578947367,
#         "transaction_type": 2.1052631578947367,
#         "amount": 0.0,
#         "currency": 2.1052631578947367,
#         "balance_after": 0.0,
#         "status": 2.1052631578947367,
#         "merchant": 47.368421052631575,
#         "category": 49.473684210526315,
#         "location": 0.0,
#         "ingestion_timestamp": 0.0,
#         "source_file": 0.0,
#         "batch_id": 0.0
#       },
#       "high_null_columns": {
#         "merchant": 47.368421052631575,
#         "category": 49.473684210526315
#       },
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-17T13:36:54.446887"
#     },
#     "validation_results": {
#       "validation_results": {
#         "has_transaction_id": {
#           "description": "Transaction ID must be present",
#           "failing_count": 1,
#           "failing_percentage": 1.0526315789473684,
#           "passed": false
#         },
#         "valid_amount": {
#           "description": "Amount must be positive if not null",
#           "failing_count": 66,
#           "failing_percentage": 69.47368421052632,
#           "passed": false
#         },
#         "valid_timestamp": {
#           "description": "Timestamp must not be in the future",
#           "failing_count": 2,
#           "failing_percentage": 2.1052631578947367,
#           "passed": false
#         }
#       },
#       "sample_size": 95,
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-17T13:36:54.952992",
#       "all_passed": false
#     },
#     "source_path": [
#       "c:\\GitHub\\DE_Pipelines\\data\\financial_transactions_20250409_113413.csv",
#       "c:\\GitHub\\DE_Pipelines\\data\\financial_transactions_20250410_113413.csv"
#     ],
#     "duration_seconds": 4.82211709022522
#   }
# }
# 2025-04-17 13:36:54,954 - INFO - Bronze layer processing completed in 4.82 seconds

# %%
bronzedf.show(5)
# Out:
# +--------------+-------------------+-----------+--------------+----------------+-------+--------+-------------+--------+--------------------+---------+---------------+--------------------+--------------------+--------+
# |transaction_id|          timestamp|customer_id|account_number|transaction_type| amount|currency|balance_after|  status|            merchant| category|       location| ingestion_timestamp|         source_file|batch_id|
# +--------------+-------------------+-----------+--------------+----------------+-------+--------+-------------+--------+--------------------+---------+---------------+--------------------+--------------------+--------+
# |   TXN00000001|2023-05-05 03:42:36| CUST001179| ACCT-39450273|        interest|1378.52|     USD|      9544.56|reversed|                NULL|     NULL|Los Angeles, CA|2025-04-17 13:36:...|file:///c:/GitHub...|    test|
# |   TXN00000002|2023-08-11 06:24:46| CUST001188| ACCT-55298556|          refund| 1626.4|     JPY|      9598.17|disputed|               Zelle| shopping|     Austin, TX|2025-04-17 13:36:...|file:///c:/GitHub...|    test|
# |   TXN00000003|2023-06-24 10:10:55| CUST001153|          NULL|          refund|   30.3|     USD|      1800.82|disputed|    American Express|education|            ATM|2025-04-17 13:36:...|file:///c:/GitHub...|    test|
# |   TXN00000004|2023-08-21 09:51:49| CUST001079| ACCT-49823450|      withdrawal|-130.66|     USD|      3709.27|reversed|                NULL|     NULL|         Branch|2025-04-17 13:36:...|file:///c:/GitHub...|    test|
# |   TXN00000005|2023-12-29 19:26:50| CUST001033| ACCT-22201654|         deposit|1958.59|     JPY|      5587.82| pending|Direct Deposit - ...|   income|         Branch|2025-04-17 13:36:...|file:///c:/GitHub...|    test|
# +--------------+-------------------+-----------+--------------+----------------+-------+--------+-------------+--------+--------------------+---------+---------------+--------------------+--------------------+--------+
# only showing top 5 rows

# %% [markdown]
# #### Silver

# %%
silverdf, silver_version = process_batch_silver_layer(spark, bronze_table, bronze_version=None, 
                                                   silver_table=silver_table, 
                                                   silver_transform=silver_transform, 
                                                   validation_rules=silver_validation_rules,
                                                   pipeline_id='test', mode='test', 
                                                   silver_writer=silver_writer)
# Out:
# 2025-04-17 13:36:55,136 - INFO - Starting silver layer processing
# 2025-04-17 13:36:56,181 - INFO - Successfully read bronze data version 21
# 2025-04-17 13:36:56,312 - INFO - Transformation function applied
# 2025-04-17 13:36:56,314 - WARNING - --- Silver layer in Test Mode ---
# 2025-04-17 13:36:56,318 - INFO - Running data quality checks for silver layer
# 2025-04-17 13:37:08,398 - INFO - Data Quality Metrics for silver layer:
# 2025-04-17 13:37:08,399 - INFO -   - Shape: [20,950] (approx. row count)
# 2025-04-17 13:37:08,401 - INFO -   - Schema:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- account_number: string (nullable = true)
#  |-- transaction_type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- balance_after: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = true)
#  |-- source_file: string (nullable = true)
#  |-- batch_id: string (nullable = true)
#  |-- transaction_timestamp: timestamp (nullable = true)
#  |-- transaction_date: date (nullable = true)
#  |-- transaction_time: string (nullable = true)
#  |-- year_month: string (nullable = true)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-17 13:37:08,402 - INFO -   - Sample size: 92
# 2025-04-17 13:37:08,405 - WARNING -   - Columns with high null percentages: {'merchant': 48.91304347826087, 'category': 46.73913043478261}
# 2025-04-17 13:37:08,406 - INFO - Validating dataframe with 4 rules
# 2025-04-17 13:37:14,449 - INFO - Validation rule 'valid_transaction_type' FAILED - 38 records (41.30%) failed
# 2025-04-17 13:37:16,401 - INFO - Validation rule 'valid_status' FAILED - 39 records (42.39%) failed
# 2025-04-17 13:37:18,174 - INFO - Validation rule 'valid_currency' FAILED - 3 records (3.26%) failed
# 2025-04-17 13:37:19,786 - INFO - Validation rule 'valid_transaction_timestamp' FAILED - 1 records (1.09%) failed
# 2025-04-17 13:37:19,792 - INFO - Checkpoint created:
# {
#   "pipeline_id": "test",
#   "layer": "silver",
#   "version": "test",
#   "timestamp": "2025-04-17T13:37:19.791624",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "silver",
#       "shape": "[20,950] (approx. row count)",
#       "schema": "root\n |-- transaction_id: string (nullable = true)\n |-- timestamp: string (nullable = true)\n |-- customer_id: string (nullable = true)\n |-- account_number: string (nullable = true)\n |-- transaction_type: string (nullable = true)\n |-- amount: double (nullable = true)\n |-- currency: string (nullable = true)\n |-- balance_after: double (nullable = true)\n |-- status: string (nullable = true)\n |-- merchant: string (nullable = true)\n |-- category: string (nullable = true)\n |-- location: string (nullable = true)\n |-- ingestion_timestamp: timestamp (nullable = true)\n |-- source_file: string (nullable = true)\n |-- batch_id: string (nullable = true)\n |-- transaction_timestamp: timestamp (nullable = true)\n |-- transaction_date: date (nullable = true)\n |-- transaction_time: string (nullable = true)\n |-- year_month: string (nullable = true)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 92,
#       "null_percentages": {
#         "transaction_id": 0.0,
#         "timestamp": 1.0869565217391304,
#         "customer_id": 1.0869565217391304,
#         "account_number": 0.0,
#         "transaction_type": 3.260869565217391,
#         "amount": 0.0,
#         "currency": 3.260869565217391,
#         "balance_after": 1.0869565217391304,
#         "status": 1.0869565217391304,
#         "merchant": 48.91304347826087,
#         "category": 46.73913043478261,
#         "location": 0.0,
#         "ingestion_timestamp": 0.0,
#         "source_file": 0.0,
#         "batch_id": 0.0,
#         "transaction_timestamp": 1.0869565217391304,
#         "transaction_date": 1.0869565217391304,
#         "transaction_time": 1.0869565217391304,
#         "year_month": 1.0869565217391304,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {
#         "merchant": 48.91304347826087,
#         "category": 46.73913043478261
#       },
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-17T13:37:08.397102"
#     },
#     "validation_results": {
#       "validation_results": {
#         "valid_transaction_type": {
#           "description": "Transaction type must be one of the valid types",
#           "failing_count": 38,
#           "failing_percentage": 41.30434782608695,
#           "passed": false
#         },
#         "valid_status": {
#           "description": "Status must be one of the valid statuses",
#           "failing_count": 39,
#           "failing_percentage": 42.391304347826086,
#           "passed": false
#         },
#         "valid_currency": {
#           "description": "Currency code should be 3 characters if present",
#           "failing_count": 3,
#           "failing_percentage": 3.260869565217391,
#           "passed": false
#         },
#         "valid_transaction_timestamp": {
#           "description": "Transaction timestamp must not be NULL or in the future",
#           "failing_count": 1,
#           "failing_percentage": 1.0869565217391304,
#           "passed": false
#         }
#       },
#       "sample_size": 92,
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-17T13:37:19.791624",
#       "all_passed": false
#     },
#     "source_bronze_version": 21,
#     "duration_seconds": 24.652437925338745
#   }
# }
# 2025-04-17 13:37:19,793 - INFO - Silver layer processing completed in 24.65 seconds

# %%
silverdf.show(5)
# Out:
# +--------------+-------------------+-----------+--------------+----------------+-------+--------+-------------+--------+--------------------+--------+---------------+--------------------+--------------------+--------------------+---------------------+----------------+----------------+----------+--------------------+
# |transaction_id|          timestamp|customer_id|account_number|transaction_type| amount|currency|balance_after|  status|            merchant|category|       location| ingestion_timestamp|         source_file|            batch_id|transaction_timestamp|transaction_date|transaction_time|year_month|processing_timestamp|
# +--------------+-------------------+-----------+--------------+----------------+-------+--------+-------------+--------+--------------------+--------+---------------+--------------------+--------------------+--------------------+---------------------+----------------+----------------+----------+--------------------+
# |   TXN00000001|2023-05-05 03:42:36| CUST001179| ACCT-39450273|        interest|1378.52|     USD|      9544.56|reversed|                NULL|    NULL|Los Angeles, CA|2025-04-17 13:33:...|file:///c:/GitHub...|Financial_DE_Pipe...|  2023-05-05 03:42:36|      2023-05-05|        03:42:36|   2023-05|2025-04-17 13:37:...|
# |   TXN00000002|2023-08-11 06:24:46| CUST001188| ACCT-55298556|          refund| 1626.4|     JPY|      9598.17|disputed|               Zelle|shopping|     Austin, TX|2025-04-17 13:33:...|file:///c:/GitHub...|Financial_DE_Pipe...|  2023-08-11 06:24:46|      2023-08-11|        06:24:46|   2023-08|2025-04-17 13:37:...|
# |   TXN00000004|2023-08-21 09:51:49| CUST001079| ACCT-49823450|      withdrawal| 130.66|     USD|      3709.27|reversed|                NULL|    NULL|         Branch|2025-04-17 13:33:...|file:///c:/GitHub...|Financial_DE_Pipe...|  2023-08-21 09:51:49|      2023-08-21|        09:51:49|   2023-08|2025-04-17 13:37:...|
# |   TXN00000005|2023-12-29 19:26:50| CUST001033| ACCT-22201654|         deposit|1958.59|     JPY|      5587.82| pending|Direct Deposit - ...|  income|         Branch|2025-04-17 13:33:...|file:///c:/GitHub...|Financial_DE_Pipe...|  2023-12-29 19:26:50|      2023-12-29|        19:26:50|   2023-12|2025-04-17 13:37:...|
# |   TXN00000006|2023-01-28 05:31:27| CUST001039| ACCT-31227574|         deposit|1997.84|     USD|       8020.5|disputed|Direct Deposit - ...|  income|     Boston, MA|2025-04-17 13:33:...|file:///c:/GitHub...|Financial_DE_Pipe...|  2023-01-28 05:31:27|      2023-01-28|        05:31:27|   2023-01|2025-04-17 13:37:...|
# +--------------+-------------------+-----------+--------------+----------------+-------+--------+-------------+--------+--------------------+--------+---------------+--------------------+--------------------+--------------------+---------------------+----------------+----------------+----------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ##### Investigating Silver Validation Check Failures:
# Corrupt "status" column

# %%
silverdf.groupBy('status').count().show()
# Out:
# +---------+-----+
# |   status|count|
# +---------+-----+
# | dqsputed|    1|
# |  pgnding|    1|
# |completed|  195|
# |   failen|    1|
# |   failed|  179|
# |bompleted|    1|
# |     NULL|   17|
# |comcleted|    1|
# | disputad|    1|
# | dmsputed|    1|
# | diiputed|    1|
# |  pending|  164|
# | disputed|  190|
# | reverszd|    1|
# | reversed|  196|
# +---------+-----+

# %% [markdown]
# #### Gold

# %%
gold_dfs = process_batch_gold_layer(spark, silver_table, silver_version=None, 
                                 gold_table=gold_table, 
                                 gold_transform=gold_transform, 
                                 validation_rules=gold_validation_rules, 
                                 pipeline_id='test', 
                                 mode='test',
                                 gold_writer=gold_writer)
# Out:
# 2025-04-17 13:37:22,971 - INFO - Starting gold layer processing
# 2025-04-17 13:37:23,940 - INFO - Successfully read silver data version 15
# 2025-04-17 13:37:24,098 - INFO - Transformation function applied
# 2025-04-17 13:37:24,100 - WARNING - Gold layer in Test Mode
# 2025-04-17 13:37:24,101 - INFO - Running data quality checks for de_pipelines.financial_osb_gold_type1_daily_category layer
# 2025-04-17 13:37:36,329 - INFO - Data Quality Metrics for de_pipelines.financial_osb_gold_type1_daily_category layer:
# 2025-04-17 13:37:36,330 - INFO -   - Shape: [9,702] (approx. row count)
# 2025-04-17 13:37:36,332 - INFO -   - Schema:
# root
#  |-- transaction_date: date (nullable = true)
#  |-- category: string (nullable = true)
#  |-- transaction_count: long (nullable = false)
#  |-- total_amount: double (nullable = true)
#  |-- avg_amount: double (nullable = true)
#  |-- min_amount: double (nullable = true)
#  |-- max_amount: double (nullable = true)
#  |-- unique_customers: long (nullable = false)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-17 13:37:36,333 - INFO -   - Sample size: 151
# 2025-04-17 13:37:36,334 - WARNING -   - Columns with high null percentages: {'category': 40.397350993377486}
# 2025-04-17 13:37:36,335 - INFO - Validating dataframe with 2 rules
# 2025-04-17 13:37:41,487 - INFO - Validation rule 'positive_transaction_counts' PASSED - 0 records (0.00%) failed
# 2025-04-17 13:37:42,987 - INFO - Validation rule 'valid_total_amounts' PASSED - 0 records (0.00%) failed
# 2025-04-17 13:37:42,994 - INFO - Checkpoint created:
# {
#   "pipeline_id": "test",
#   "layer": "gold_daily_category",
#   "version": "test",
#   "timestamp": "2025-04-17T13:37:42.994785",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "de_pipelines.financial_osb_gold_type1_daily_category",
#       "shape": "[9,702] (approx. row count)",
#       "schema": "root\n |-- transaction_date: date (nullable = true)\n |-- category: string (nullable = true)\n |-- transaction_count: long (nullable = false)\n |-- total_amount: double (nullable = true)\n |-- avg_amount: double (nullable = true)\n |-- min_amount: double (nullable = true)\n |-- max_amount: double (nullable = true)\n |-- unique_customers: long (nullable = false)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 151,
#       "null_percentages": {
#         "transaction_date": 0.0,
#         "category": 40.397350993377486,
#         "transaction_count": 0.0,
#         "total_amount": 0.0,
#         "avg_amount": 0.0,
#         "min_amount": 0.0,
#         "max_amount": 0.0,
#         "unique_customers": 0.0,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {
#         "category": 40.397350993377486
#       },
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-17T13:37:36.329113"
#     },
#     "validation_results": {
#       "validation_results": {
#         "positive_transaction_counts": {
#           "description": "Transaction counts should be positive",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_total_amounts": {
#           "description": "Total amounts should not be negative",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         }
#       },
#       "sample_size": 151,
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-17T13:37:42.994785",
#       "all_passed": true
#     },
#     "source_silver_version": 15
#   }
# }
# 2025-04-17 13:37:42,996 - INFO - Running data quality checks for de_pipelines.financial_osb_gold_type1_customer_summary layer
# 2025-04-17 13:37:52,896 - INFO - Data Quality Metrics for de_pipelines.financial_osb_gold_type1_customer_summary layer:
# 2025-04-17 13:37:52,900 - INFO -   - Shape: [9,217] (approx. row count)
# 2025-04-17 13:37:52,901 - INFO -   - Schema:
# root
#  |-- customer_id: string (nullable = true)
#  |-- transaction_count: long (nullable = false)
#  |-- total_amount: double (nullable = true)
#  |-- avg_amount: double (nullable = true)
#  |-- first_transaction_date: date (nullable = true)
#  |-- last_transaction_date: date (nullable = true)
#  |-- category_count: long (nullable = false)
#  |-- processing_timestamp: timestamp (nullable = false)
#  |-- days_since_last_transaction: integer (nullable = true)
#
# 2025-04-17 13:37:52,902 - INFO -   - Sample size: 51
# 2025-04-17 13:37:52,905 - INFO - Validating dataframe with 2 rules
# 2025-04-17 13:37:59,428 - INFO - Validation rule 'positive_transaction_counts' PASSED - 0 records (0.00%) failed
# 2025-04-17 13:38:01,252 - INFO - Validation rule 'valid_total_amounts' PASSED - 0 records (0.00%) failed
# 2025-04-17 13:38:01,257 - INFO - Checkpoint created:
# {
#   "pipeline_id": "test",
#   "layer": "gold_customer_summary",
#   "version": "test",
#   "timestamp": "2025-04-17T13:38:01.256884",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "de_pipelines.financial_osb_gold_type1_customer_summary",
#       "shape": "[9,217] (approx. row count)",
#       "schema": "root\n |-- customer_id: string (nullable = true)\n |-- transaction_count: long (nullable = false)\n |-- total_amount: double (nullable = true)\n |-- avg_amount: double (nullable = true)\n |-- first_transaction_date: date (nullable = true)\n |-- last_transaction_date: date (nullable = true)\n |-- category_count: long (nullable = false)\n |-- processing_timestamp: timestamp (nullable = false)\n |-- days_since_last_transaction: integer (nullable = true)\n",
#       "sample_size": 51,
#       "null_percentages": {
#         "customer_id": 0.0,
#         "transaction_count": 0.0,
#         "total_amount": 0.0,
#         "avg_amount": 0.0,
#         "first_transaction_date": 0.0,
#         "last_transaction_date": 0.0,
#         "category_count": 0.0,
#         "processing_timestamp": 0.0,
#         "days_since_last_transaction": 0.0
#       },
#       "high_null_columns": {},
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-17T13:37:52.896360"
#     },
#     "validation_results": {
#       "validation_results": {
#         "positive_transaction_counts": {
#           "description": "Transaction counts should be positive",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_total_amounts": {
#           "description": "Total amounts should not be negative",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         }
#       },
#       "sample_size": 51,
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-17T13:38:01.256884",
#       "all_passed": true
#     },
#     "source_silver_version": 15
#   }
# }
# 2025-04-17 13:38:01,258 - INFO - Running data quality checks for de_pipelines.financial_osb_gold_type1_transaction_type_summary layer
# 2025-04-17 13:38:07,929 - INFO - Data Quality Metrics for de_pipelines.financial_osb_gold_type1_transaction_type_summary layer:
# 2025-04-17 13:38:07,931 - INFO -   - Shape: [5,17] (approx. row count)
# 2025-04-17 13:38:07,933 - INFO -   - Schema:
# root
#  |-- transaction_type: string (nullable = true)
#  |-- transaction_count: long (nullable = false)
#  |-- total_amount: double (nullable = true)
#  |-- avg_amount: double (nullable = true)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-17 13:38:07,936 - INFO -   - Sample size: 3
# 2025-04-17 13:38:07,937 - INFO - Validating dataframe with 2 rules
# 2025-04-17 13:38:12,152 - INFO - Validation rule 'positive_transaction_counts' PASSED - 0 records (0.00%) failed
# 2025-04-17 13:38:13,529 - INFO - Validation rule 'valid_total_amounts' PASSED - 0 records (0.00%) failed
# 2025-04-17 13:38:13,533 - INFO - Checkpoint created:
# {
#   "pipeline_id": "test",
#   "layer": "gold_transaction_type_summary",
#   "version": "test",
#   "timestamp": "2025-04-17T13:38:13.533925",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "de_pipelines.financial_osb_gold_type1_transaction_type_summary",
#       "shape": "[5,17] (approx. row count)",
#       "schema": "root\n |-- transaction_type: string (nullable = true)\n |-- transaction_count: long (nullable = false)\n |-- total_amount: double (nullable = true)\n |-- avg_amount: double (nullable = true)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 3,
#       "null_percentages": {
#         "transaction_type": 0.0,
#         "transaction_count": 0.0,
#         "total_amount": 0.0,
#         "avg_amount": 0.0,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {},
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-17T13:38:07.929098"
#     },
#     "validation_results": {
#       "validation_results": {
#         "positive_transaction_counts": {
#           "description": "Transaction counts should be positive",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_total_amounts": {
#           "description": "Total amounts should not be negative",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         }
#       },
#       "sample_size": 3,
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-17T13:38:13.533925",
#       "all_passed": true
#     },
#     "source_silver_version": 15
#   }
# }
# 2025-04-17 13:38:13,535 - INFO - Gold layer processing completed in 50.56 seconds

# %%
for table_name in gold_dfs.keys():
    gold_dfs[table_name].show(5)
# Out:
# +----------------+----------+-----------------+------------+----------+----------+----------+----------------+--------------------+
# |transaction_date|  category|transaction_count|total_amount|avg_amount|min_amount|max_amount|unique_customers|processing_timestamp|
# +----------------+----------+-----------------+------------+----------+----------+----------+----------------+--------------------+
# |      2023-05-25|      fees|                1|       30.89|     30.89|     30.89|     30.89|               1|2025-04-17 13:38:...|
# |      2023-09-25|    income|                1|      1384.1|    1384.1|    1384.1|    1384.1|               1|2025-04-17 13:38:...|
# |      2023-06-22|      NULL|                1|       64.69|     64.69|     64.69|     64.69|               1|2025-04-17 13:38:...|
# |      2023-12-18|investment|                1|      626.53|    626.53|    626.53|    626.53|               1|2025-04-17 13:38:...|
# |      2023-08-28|   housing|                1|       37.49|     37.49|     37.49|     37.49|               1|2025-04-17 13:38:...|
# +----------------+----------+-----------------+------------+----------+----------+----------+----------------+--------------------+
# only showing top 5 rows
#
# +-----------+-----------------+-----------------+------------------+----------------------+---------------------+--------------+--------------------+---------------------------+
# |customer_id|transaction_count|     total_amount|        avg_amount|first_transaction_date|last_transaction_date|category_count|processing_timestamp|days_since_last_transaction|
# +-----------+-----------------+-----------------+------------------+----------------------+---------------------+--------------+--------------------+---------------------------+
# | CUST001174|                4|          2254.47|          563.6175|            2023-01-04|           2023-11-27|             3|2025-04-17 13:38:...|                        507|
# | CUST001122|                7|5558.130000000001| 794.0185714285716|            2023-03-20|           2023-12-22|             3|2025-04-17 13:38:...|                        482|
# | CUST001189|                7|          4529.01| 647.0014285714286|            2023-01-24|           2023-11-23|             3|2025-04-17 13:38:...|                        511|
# | CUST001019|                3|          4251.93|1417.3100000000002|            2023-02-22|           2023-08-11|             3|2025-04-17 13:38:...|                        615|
# | CUST001119|                1|            435.6|             435.6|            2023-03-15|           2023-03-15|             0|2025-04-17 13:38:...|                        764|
# +-----------+-----------------+-----------------+------------------+----------------------+---------------------+--------------+--------------------+---------------------------+
# only showing top 5 rows
#
# +----------------+-----------------+------------------+------------------+--------------------+
# |transaction_type|transaction_count|      total_amount|        avg_amount|processing_timestamp|
# +----------------+-----------------+------------------+------------------+--------------------+
# |         pakment|                1|            149.82|            149.82|2025-04-17 13:38:...|
# |         dbposit|                1|            383.95|            383.95|2025-04-17 13:38:...|
# |            NULL|               22|14064.100000000002| 639.2772727272728|2025-04-17 13:38:...|
# |      withdrawal|              137|           73410.6|  535.843795620438|2025-04-17 13:38:...|
# |             fee|              122|3108.9700000000003|25.483360655737705|2025-04-17 13:38:...|
# +----------------+-----------------+------------------+------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ## SCD Type 1:
# ##### Change Data Capture (Merge)

# %% [markdown]
# ##### Inputs/Outputs

# %%
# Change Data Capture
file_list = [
    "financial_transactions_20250414_113413.csv",
    "financial_transactions_20250417_113413.csv"
]

abs_file_list = []
for file in file_list:
    # Join data_dir with filename
    relative_path = os.path.join(data_dir, file)
    # Convert to absolute path
    abs_path = os.path.abspath(relative_path)
    abs_file_list.append(abs_path)

# %% [markdown]
# #### Define: Validation Rules(Same), Transformations(Same), Write Executions (Merge)

# %%
def bronze_writer(df: DataFrame, table_name: str) -> None:

    # drop duplicates
    df = (df
            .orderBy(F.col("timestamp").desc())
            .dropDuplicates(subset=["transaction_id", "account_number"])  # Keeps only the latest record
        )

    # Merge the source and target DataFrame
    df.createOrReplaceTempView("source")

    # Execute merge
    spark.sql(f"""
        MERGE INTO {table_name} t
        USING source s
        ON s.transaction_id = t.transaction_id AND s.account_number = t.account_number
        WHEN MATCHED AND (t.amount != s.amount OR t.balance_after != s.balance_after) THEN 
            UPDATE SET *
        WHEN NOT MATCHED THEN
            INSERT *
    """)

    # Get delta operation metrics
    metricsdf = spark.sql(f"DESCRIBE HISTORY {table_name} LIMIT 1")
    metrics = metricsdf.select("operationMetrics").collect()[0][0]

    return metrics

# %%
def silver_writer(df: DataFrame, table_name: str) -> None:

    # drop duplicates
    df = (df
            .orderBy(F.col("transaction_timestamp").desc())
            .dropDuplicates(subset=["transaction_id", "account_number"])  # Keeps only the latest record
        )

    # Merge the source and target DataFrame
    df.createOrReplaceTempView("source")

    # Execute merge
    spark.sql(f"""
        MERGE INTO {table_name} t
        USING source s
        ON s.transaction_id = t.transaction_id 
            AND s.account_number = t.account_number 
        WHEN MATCHED AND (t.amount != s.amount OR t.balance_after != s.balance_after) THEN 
            UPDATE SET *
        WHEN NOT MATCHED THEN
            INSERT *
    """)

    # Get delta operation metrics
    metricsdf = spark.sql(f"DESCRIBE HISTORY {table_name} LIMIT 1")
    metrics = metricsdf.select("operationMetrics").collect()[0][0]

    return metrics

# %% [markdown]
# #### Running CDC Full Batch Pipeline (Bronze, Silver)

# %%
run_batch_de_pipeline(spark, 'csv', abs_file_list, get_schema(), 
                     bronze_table=bronze_table, silver_table=silver_table, gold_table=None, 
                     bronze_transform=None, silver_transform=silver_transform, gold_transform=None,
                     bronze_writer=bronze_writer, silver_writer=silver_writer, gold_writer=None,
                     bronze_validation_rules=bronze_validation_rules, 
                     silver_validation_rules=silver_validation_rules, 
                     gold_validation_rules=None,
                     pipeline_name='Financial_DE_Pipeline')
# Out:
# 2025-04-17 13:38:17,034 - INFO - --Starting data pipeline execution with ID: Financial_DE_Pipeline_20250417_133817--
# 2025-04-17 13:38:17,036 - INFO - Starting bronze layer processing
# 2025-04-17 13:38:17,085 - INFO - Successfully read CSV data from:
#   - c:\GitHub\DE_Pipelines\data\financial_transactions_20250414_113413.csv
#   - c:\GitHub\DE_Pipelines\data\financial_transactions_20250417_113413.csv
# 2025-04-17 13:38:17,087 - INFO - No transformation function defined
# 2025-04-17 13:38:27,098 - INFO - Successfully wrote bronze table: de_pipelines.financial_osb_bronze_type1
# 2025-04-17 13:38:27,100 - INFO - Write Metrics:
# {
#   "numOutputRows": "1540",
#   "numTargetBytesAdded": "59485",
#   "numTargetRowsInserted": "540",
#   "numTargetFilesAdded": "1",
#   "materializeSourceTimeMs": "1607",
#   "numTargetRowsMatchedDeleted": "0",
#   "numTargetFilesRemoved": "1",
#   "numTargetRowsMatchedUpdated": "216",
#   "executionTimeMs": "5714",
#   "numTargetDeletionVectorsUpdated": "0",
#   "numTargetRowsCopied": "784",
#   "rewriteTimeMs": "1591",
#   "numTargetRowsUpdated": "216",
#   "numTargetDeletionVectorsRemoved": "0",
#   "numTargetRowsDeleted": "0",
#   "scanTimeMs": "2467",
#   "numSourceRows": "1500",
#   "numTargetDeletionVectorsAdded": "0",
#   "numTargetChangeFilesAdded": "0",
#   "numTargetRowsNotMatchedBySourceUpdated": "0",
#   "numTargetRowsNotMatchedBySourceDeleted": "0",
#   "numTargetBytesRemoved": "42676"
# }
# 2025-04-17 13:38:27,432 - INFO - Running data quality checks for bronze layer
# 2025-04-17 13:38:31,589 - INFO - Data Quality Metrics for bronze layer:
# 2025-04-17 13:38:31,590 - INFO -   - Shape: [15,2750] (approx. row count)
# 2025-04-17 13:38:31,591 - INFO -   - Schema:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- account_number: string (nullable = true)
#  |-- transaction_type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- balance_after: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#  |-- source_file: string (nullable = false)
#  |-- batch_id: string (nullable = false)
#
# 2025-04-17 13:38:31,593 - INFO -   - Sample size: 276
# 2025-04-17 13:38:31,594 - WARNING -   - Columns with high null percentages: {'merchant': 50.36231884057971, 'category': 51.08695652173913}
# 2025-04-17 13:38:31,596 - INFO - Validating dataframe with 3 rules
# 2025-04-17 13:38:31,844 - INFO - Validation rule 'has_transaction_id' FAILED - 5 records (1.81%) failed
# 2025-04-17 13:38:31,937 - INFO - Validation rule 'valid_amount' FAILED - 170 records (61.59%) failed
# 2025-04-17 13:38:32,023 - INFO - Validation rule 'valid_timestamp' FAILED - 5 records (1.81%) failed
# 2025-04-17 13:38:32,027 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250417_133817",
#   "layer": "bronze",
#   "version": 22,
#   "timestamp": "2025-04-17T13:38:32.026346",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "bronze",
#       "shape": "[15,2750] (approx. row count)",
#       "schema": "root\n |-- transaction_id: string (nullable = true)\n |-- timestamp: string (nullable = true)\n |-- customer_id: string (nullable = true)\n |-- account_number: string (nullable = true)\n |-- transaction_type: string (nullable = true)\n |-- amount: double (nullable = true)\n |-- currency: string (nullable = true)\n |-- balance_after: double (nullable = true)\n |-- status: string (nullable = true)\n |-- merchant: string (nullable = true)\n |-- category: string (nullable = true)\n |-- location: string (nullable = true)\n |-- ingestion_timestamp: timestamp (nullable = false)\n |-- source_file: string (nullable = false)\n |-- batch_id: string (nullable = false)\n",
#       "sample_size": 276,
#       "null_percentages": {
#         "transaction_id": 1.8115942028985508,
#         "timestamp": 1.8115942028985508,
#         "customer_id": 1.4492753623188406,
#         "account_number": 2.1739130434782608,
#         "transaction_type": 2.898550724637681,
#         "amount": 1.8115942028985508,
#         "currency": 1.4492753623188406,
#         "balance_after": 1.8115942028985508,
#         "status": 1.4492753623188406,
#         "merchant": 50.36231884057971,
#         "category": 51.08695652173913,
#         "location": 0.7246376811594203,
#         "ingestion_timestamp": 0.0,
#         "source_file": 0.0,
#         "batch_id": 0.0
#       },
#       "high_null_columns": {
#         "merchant": 50.36231884057971,
#         "category": 51.08695652173913
#       },
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-17T13:38:31.588089"
#     },
#     "validation_results": {
#       "validation_results": {
#         "has_transaction_id": {
#           "description": "Transaction ID must be present",
#           "failing_count": 5,
#           "failing_percentage": 1.8115942028985508,
#           "passed": false
#         },
#         "valid_amount": {
#           "description": "Amount must be positive if not null",
#           "failing_count": 170,
#           "failing_percentage": 61.59420289855072,
#           "passed": false
#         },
#         "valid_timestamp": {
#           "description": "Timestamp must not be in the future",
#           "failing_count": 5,
#           "failing_percentage": 1.8115942028985508,
#           "passed": false
#         }
#       },
#       "sample_size": 276,
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-17T13:38:32.026346",
#       "all_passed": false
#     },
#     "source_path": [
#       "c:\\GitHub\\DE_Pipelines\\data\\financial_transactions_20250414_113413.csv",
#       "c:\\GitHub\\DE_Pipelines\\data\\financial_transactions_20250417_113413.csv"
#     ],
#     "duration_seconds": 14.98881220817566
#   }
# }
# 2025-04-17 13:38:32,028 - INFO - Bronze layer processing completed in 14.99 seconds
# 2025-04-17 13:38:32,030 - INFO - Starting table optimization
# 2025-04-17 13:38:34,138 - INFO - Optimized de_pipelines.financial_osb_bronze_type1. Files: before=1, after=1
# 2025-04-17 13:38:34,140 - INFO - --Bronze layer successfully optimized in 2.11 seconds--
# 2025-04-17 13:38:34,141 - INFO - Starting silver layer processing
# 2025-04-17 13:38:34,287 - INFO - Successfully read bronze data version 22
# 2025-04-17 13:38:34,408 - INFO - Transformation function applied
# 2025-04-17 13:38:45,698 - INFO - Successfully wrote silver table: de_pipelines.financial_osb_silver_type1
# 2025-04-17 13:38:45,700 - INFO - Write Metrics:
# {
#   "numOutputRows": "1425",
#   "numTargetBytesAdded": "198921",
#   "numTargetRowsInserted": "475",
#   "numTargetFilesAdded": "15",
#   "materializeSourceTimeMs": "3040",
#   "numTargetRowsMatchedDeleted": "0",
#   "numTargetFilesRemoved": "13",
#   "numTargetRowsMatchedUpdated": "215",
#   "executionTimeMs": "7005",
#   "numTargetDeletionVectorsUpdated": "0",
#   "numTargetRowsCopied": "735",
#   "rewriteTimeMs": "2184",
#   "numTargetRowsUpdated": "215",
#   "numTargetDeletionVectorsRemoved": "0",
#   "numTargetRowsDeleted": "0",
#   "scanTimeMs": "1750",
#   "numSourceRows": "1424",
#   "numTargetDeletionVectorsAdded": "0",
#   "numTargetChangeFilesAdded": "0",
#   "numTargetRowsNotMatchedBySourceUpdated": "0",
#   "numTargetRowsNotMatchedBySourceDeleted": "0",
#   "numTargetBytesRemoved": "158085"
# }
# 2025-04-17 13:38:46,068 - INFO - Running data quality checks for silver layer
# 2025-04-17 13:38:53,244 - INFO - Data Quality Metrics for silver layer:
# 2025-04-17 13:38:53,246 - INFO -   - Shape: [20,1424] (approx. row count)
# 2025-04-17 13:38:53,248 - INFO -   - Schema:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- account_number: string (nullable = true)
#  |-- transaction_type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- balance_after: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = true)
#  |-- source_file: string (nullable = true)
#  |-- batch_id: string (nullable = true)
#  |-- transaction_timestamp: timestamp (nullable = true)
#  |-- transaction_date: date (nullable = true)
#  |-- transaction_time: string (nullable = true)
#  |-- year_month: string (nullable = true)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-17 13:38:53,250 - INFO -   - Sample size: 132
# 2025-04-17 13:38:53,253 - WARNING -   - Columns with high null percentages: {'merchant': 48.484848484848484, 'category': 46.96969696969697}
# 2025-04-17 13:38:53,255 - INFO - Validating dataframe with 4 rules
# 2025-04-17 13:38:57,017 - INFO - Validation rule 'valid_transaction_type' FAILED - 56 records (42.42%) failed
# 2025-04-17 13:38:57,134 - INFO - Validation rule 'valid_status' FAILED - 59 records (44.70%) failed
# 2025-04-17 13:38:57,233 - INFO - Validation rule 'valid_currency' FAILED - 3 records (2.27%) failed
# 2025-04-17 13:38:57,375 - INFO - Validation rule 'valid_transaction_timestamp' FAILED - 2 records (1.52%) failed
# 2025-04-17 13:38:57,379 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250417_133817",
#   "layer": "silver",
#   "version": 16,
#   "timestamp": "2025-04-17T13:38:57.379241",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "silver",
#       "shape": "[20,1424] (approx. row count)",
#       "schema": "root\n |-- transaction_id: string (nullable = true)\n |-- timestamp: string (nullable = true)\n |-- customer_id: string (nullable = true)\n |-- account_number: string (nullable = true)\n |-- transaction_type: string (nullable = true)\n |-- amount: double (nullable = true)\n |-- currency: string (nullable = true)\n |-- balance_after: double (nullable = true)\n |-- status: string (nullable = true)\n |-- merchant: string (nullable = true)\n |-- category: string (nullable = true)\n |-- location: string (nullable = true)\n |-- ingestion_timestamp: timestamp (nullable = true)\n |-- source_file: string (nullable = true)\n |-- batch_id: string (nullable = true)\n |-- transaction_timestamp: timestamp (nullable = true)\n |-- transaction_date: date (nullable = true)\n |-- transaction_time: string (nullable = true)\n |-- year_month: string (nullable = true)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 132,
#       "null_percentages": {
#         "transaction_id": 0.0,
#         "timestamp": 1.5151515151515151,
#         "customer_id": 0.7575757575757576,
#         "account_number": 0.0,
#         "transaction_type": 2.272727272727273,
#         "amount": 0.0,
#         "currency": 2.272727272727273,
#         "balance_after": 0.7575757575757576,
#         "status": 0.7575757575757576,
#         "merchant": 48.484848484848484,
#         "category": 46.96969696969697,
#         "location": 0.0,
#         "ingestion_timestamp": 0.0,
#         "source_file": 0.0,
#         "batch_id": 0.0,
#         "transaction_timestamp": 1.5151515151515151,
#         "transaction_date": 1.5151515151515151,
#         "transaction_time": 1.5151515151515151,
#         "year_month": 1.5151515151515151,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {
#         "merchant": 48.484848484848484,
#         "category": 46.96969696969697
#       },
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-17T13:38:53.244124"
#     },
#     "validation_results": {
#       "validation_results": {
#         "valid_transaction_type": {
#           "description": "Transaction type must be one of the valid types",
#           "failing_count": 56,
#           "failing_percentage": 42.42424242424242,
#           "passed": false
#         },
#         "valid_status": {
#           "description": "Status must be one of the valid statuses",
#           "failing_count": 59,
#           "failing_percentage": 44.696969696969695,
#           "passed": false
#         },
#         "valid_currency": {
#           "description": "Currency code should be 3 characters if present",
#           "failing_count": 3,
#           "failing_percentage": 2.272727272727273,
#           "passed": false
#         },
#         "valid_transaction_timestamp": {
#           "description": "Transaction timestamp must not be NULL or in the future",
#           "failing_count": 2,
#           "failing_percentage": 1.5151515151515151,
#           "passed": false
#         }
#       },
#       "sample_size": 132,
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-17T13:38:57.379241",
#       "all_passed": false
#     },
#     "source_bronze_version": 22,
#     "duration_seconds": 23.235817432403564
#   }
# }
# 2025-04-17 13:38:57,381 - INFO - Silver layer processing completed in 23.24 seconds
# 2025-04-17 13:38:57,382 - INFO - Starting table optimization
# 2025-04-17 13:39:10,397 - INFO - Optimized de_pipelines.financial_osb_silver_type1. Files: before=15, after=15
# 2025-04-17 13:39:10,398 - INFO - --Silver layer successfully optimized in 13.02 seconds--
# 2025-04-17 13:39:10,400 - INFO - -- Gold layer not defined --
# 2025-04-17 13:39:10,401 - INFO - ---Full pipeline execution completed successfully in 53.37 seconds---
# 2025-04-17 13:39:11,415 - INFO - Spark session stopped
# {'status': 'success',
#  'pipeline_id': 'Financial_DE_Pipeline_20250417_133817',
#  'bronze_version': 22,
#  'silver_version': 16,
#  'timestamp': '2025-04-17T13:39:10.404042',
#  'duration_seconds': 53.36703586578369,
#  'metrics': {'pipeline_id': 'Financial_DE_Pipeline_20250417_133817',
#   'start_time': '2025-04-17T13:38:17.034009',
#   'stages': {'bronze': {'duration_seconds': 14.993812084197998,
#     'version': 22,
#     'status': 'success'},
#    'bronze_optimize': {'layer': 'bronze',
#     'duration_seconds': 2.1090800762176514,
#     'status': 'success'},
#    'silver': {'duration_seconds': 23.24081802368164,
#     'version': 16,
#     'status': 'success',
#     'source_bronze_version': 22},
#    'silver_optimize': {'layer': 'silver',
#     'duration_seconds': 13.015802145004272,
#     'status': 'success'}},
#   'status': 'success',
#   'end_time': '2025-04-17T13:39:10.401045',
#   'total_duration_seconds': 53.36703586578369}}
