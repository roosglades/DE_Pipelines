# %% [markdown]
# ##### Local Environment Setup

# %%
import os
import sys
# Set JAVA env variable
os.environ["JAVA_HOME"] = r"C:\Program Files\Eclipse Adoptium\jdk-11.0.26.4-hotspot"
# Set Hadoop environment variables 
os.environ['HADOOP_HOME'] = r'C:\hadoop'
os.environ['PATH'] = os.environ['HADOOP_HOME'] + r'\bin;' + os.environ['PATH']
# Set the Python executable path explicitly
os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

# Get Pipeline Tools Path
sys.path.append(R'C:\GitHub\Tools\de')

# %% [markdown]
# ##### Libraries

# %%
import time
import logging
from datetime import datetime

import numpy as np
import pandas as pd

from typing import Dict


from pyspark.sql import SparkSession
from pyspark.sql import DataFrame
from pyspark.sql import functions as F
from pyspark.sql.types import (StructType, StructField, StringType, 
                            DoubleType, IntegerType, TimestampType, 
                            DateType)
from delta.tables import DeltaTable

# %%
from de_pipeline_tools import *

# %% [markdown]
# ##### Spark Session

# %%
spark = initialize_local_spark_delta_lake("Financial Data Pipeline")
# Out:
# 2025-04-19 15:02:10,163 - INFO - ---Spark session initialized with Delta Lake support---

# %%
# Create a database in the Hive warehouse if doesn't exist
spark.sql("CREATE DATABASE IF NOT EXISTS de_pipelines LOCATION 'C:/hive-warehouse/de_pipelines'")
# Out:
# DataFrame[]

# %% [markdown]
# ## SCD Type 1:
# ##### Intial Creation (Overwrite)

# %% [markdown]
# ##### Inputs/Outputs

# %%
# Intial Creation
data_dir = "../../data"
file_list = [
    "financial_transactions_20250409_113413.csv",
    "financial_transactions_20250410_113413.csv"
]

abs_file_list = []
for file in file_list:
    # Join data_dir with filename
    relative_path = os.path.join(data_dir, file)
    # Convert to absolute path
    abs_path = os.path.abspath(relative_path)
    abs_file_list.append(abs_path)

bronze_table = 'de_pipelines.financial_osb_bronze_type1'
silver_table = 'de_pipelines.financial_osb_silver_type1'
gold_table   = 'de_pipelines.financial_osb_gold_type1'

# %%
def get_schema():
    return StructType([
    StructField("transaction_id", StringType(), False),
    StructField("timestamp", StringType(), True), #load in as string type, handle in silver step     
    StructField("customer_id", StringType(), True),      
    StructField("account_number", StringType(), True),   
    StructField("transaction_type", StringType(), True), 
    StructField("amount", DoubleType(), True),           
    StructField("currency", StringType(), True),         
    StructField("balance_after", DoubleType(), True),    
    StructField("status", StringType(), True),           
    StructField("merchant", StringType(), True),         
    StructField("category", StringType(), True),         
    StructField("location", StringType(), True)          
])

# %% [markdown]
# #### Define: Validation Rules, Transformations, Write Executions

# %%
def bronze_writer(df: DataFrame, table_name: str):

    (df.write
        .format("delta")
        .mode("overwrite")
        .option("overwriteSchema", "true")
        .saveAsTable(table_name)
    )
    
    return None

# %%
# Define bronze validation rules
bronze_validation_rules = [
    {
        "name": "has_transaction_id",
        "condition": "transaction_id IS NOT NULL",
        "description": "Transaction ID must be present"
    },
    {
        "name": "valid_amount",
        "condition": "amount IS NOT NULL AND amount > 0",
        "description": "Amount must be positive if not null"
    },
    {
        "name": "valid_timestamp",
        "condition": "timestamp IS NOT NULL AND timestamp <= current_timestamp()",
        "description": "Timestamp must not be in the future"
    }
]

# %%
def silver_transform(df:DataFrame) -> DataFrame:

    # Clean any non-timestamp characters first
    df = df.withColumn(
        "timestamp", 
        F.regexp_replace(F.col("timestamp"), "[^0-9\\-: ]", "")
    )

    # Cast to timestamp type
    df = df.withColumn("timestamp", F.col("timestamp").cast("timestamp"))

    # Remove duplicates
    df = df.dropDuplicates(subset=["transaction_id","timestamp"])

    # Standardize Data
    df = (df
            .withColumn("amount", F.abs(F.col("amount")))
            .withColumn("transaction_type", F.lower(F.col("transaction_type")))
            .withColumn("category", F.lower(F.col("category")))
            .withColumn("status", F.lower(F.col("status")))
    )

    # Filter Data
    # Address bronze layer data validation check concerns
    df = df.filter(
                    (F.col('transaction_id').isNotNull()) # transaction id must exist
                    & (F.col('account_number').isNotNull()) # account number must exist
                    & (F.col('amount') > 0) # amount must be positive
                    & ((F.col('timestamp') <= F.current_date()) # must be <= current date
                    |(F.col('timestamp').isNull()))# or must be Null, no future timestamps
    ) 
    
    # Split timestamp into date and time and year_month for paritioning
    df = (df
            .withColumn("transaction_date", F.to_date("timestamp"))
            .withColumn("transaction_time", F.date_format("timestamp", "HH:mm:ss"))
            .withColumn("year_month", F.date_format(F.col("transaction_date"), "yyyy-MM"))
    )
    
    # Add processing timestamp for bookkeeping
    df = (df
            .withColumn("processing_timestamp", F.current_timestamp())
    )

    return df

# %%
def silver_writer(df: DataFrame, table_name: str):
    
    (df.write
        .format("delta")
        .mode("overwrite")
        .option("overwriteSchema", "true")
        .partitionBy("year_month")
        .saveAsTable(table_name)
    )

    return None

# %%
# Define silver validation rules
silver_validation_rules = [
    {
        "name": "valid_transaction_type",
        "condition": "transaction_type IN ('debit', 'credit', 'transfer', 'payment', 'withdrawal', 'deposit') OR transaction_type IS NULL",
        "description": "Transaction type must be one of the valid types"
    },
    {
        "name": "valid_status",
        "condition": "status IN ('completed', 'pending', 'failed', 'cancelled', 'refunded') OR status IS NULL",
        "description": "Status must be one of the valid statuses"
    },
    {
        "name": "valid_currency",
        "condition": "currency IS NOT NULL AND length(currency) = 3",
        "description": "Currency code should be 3 characters if present"
    },
    {
        "name": "valid_timestamp",
        "condition": "timestamp IS NOT NULL AND timestamp <= current_timestamp()",
        "description": "Timestamp must not be NULL or in the future"
    }
]

# %%
def gold_transform(df:DataFrame) -> Dict:
    gold_dfs = {}

    # Gold aggregation 1: Daily summary by category
    daily_category = (df
        .groupBy("transaction_date", "category")
        .agg(
            F.count("transaction_id").alias("transaction_count"),
            F.sum("amount").alias("total_amount"),
            F.avg("amount").alias("avg_amount"),
            F.min("amount").alias("min_amount"),
            F.max("amount").alias("max_amount"),
            F.countDistinct("customer_id").alias("unique_customers")
        )
        .withColumn("processing_timestamp", F.current_timestamp())
    )
    
    gold_dfs["daily_category"] = daily_category
    
    # Gold aggregation 2: Customer summary
    customer_summary = (df
        .groupBy("customer_id")
        .agg(
            F.count("transaction_id").alias("transaction_count"),
            F.sum("amount").alias("total_amount"),
            F.avg("amount").alias("avg_amount"),
            F.min("transaction_date").alias("first_transaction_date"),
            F.max("transaction_date").alias("last_transaction_date"),
            F.approx_count_distinct("category").alias("category_count")
        )
        .withColumn("processing_timestamp", F.current_timestamp())
        .withColumn("days_since_last_transaction", 
                    F.datediff(F.current_date(), F.col("last_transaction_date")))
    )
    
    gold_dfs["customer_summary"] = customer_summary
    
    # Gold aggregation 3: Transaction type summary
    transaction_type_summary = (df
        .groupBy("transaction_type")
        .agg(
            F.count("transaction_id").alias("transaction_count"),
            F.sum("amount").alias("total_amount"),
            F.avg("amount").alias("avg_amount")
        )
        .withColumn("processing_timestamp", F.current_timestamp())
    )
    
    gold_dfs["transaction_type_summary"] = transaction_type_summary

    return gold_dfs

# %%
def gold_writer(df: DataFrame, table_name: str):

    (df.write
        .format("delta")
        .mode("overwrite")
        .option("overwriteSchema", "true")
        .saveAsTable(table_name)
    )

    return None

# %%
# Define gold validation rules
gold_validation_rules = [
    {
        "name": "positive_transaction_counts",
        "condition": "transaction_count > 0",
        "description": "Transaction counts should be positive"
    },
    {
        "name": "valid_total_amounts",
        "condition": "total_amount >= 0",
        "description": "Total amounts should not be negative"
    }
]

# %% [markdown]
# ### Running Full Batch Pipeline

# %%
run_batch_de_pipeline(spark, 'csv', abs_file_list, get_schema(), 
                     bronze_table, silver_table, gold_table, 
                     bronze_transform=None, silver_transform=silver_transform, gold_transform=gold_transform,
                     bronze_writer=bronze_writer, silver_writer=silver_writer, gold_writer=gold_writer,
                     bronze_validation_rules=bronze_validation_rules, 
                     silver_validation_rules=silver_validation_rules, 
                     gold_validation_rules=gold_validation_rules,
                     pipeline_name='Financial_DE_Pipeline')
# Out:
# 2025-04-19 15:02:35,785 - INFO - --Starting data pipeline execution with ID: Financial_DE_Pipeline_20250419_150235--
# 2025-04-19 15:02:35,787 - INFO - Starting bronze layer processing
# 2025-04-19 15:02:36,514 - INFO - Successfully read CSV data from:
#   - c:\GitHub\DE_Pipelines\data\financial_transactions_20250409_113413.csv
#   - c:\GitHub\DE_Pipelines\data\financial_transactions_20250410_113413.csv
# 2025-04-19 15:02:36,516 - INFO - No transformation function defined
# 2025-04-19 15:02:36,518 - INFO - Writing to bronze table: de_pipelines.financial_osb_bronze_type1
# 2025-04-19 15:03:08,623 - INFO - Successfully wrote to bronze table: de_pipelines.financial_osb_bronze_type1
# 2025-04-19 15:03:08,625 - INFO - Write Metrics:
# [
#   {
#     "numOutputRows": "1000",
#     "numOutputBytes": "52334",
#     "numFiles": "2"
#   }
# ]
# 2025-04-19 15:03:09,352 - INFO - Running data quality checks for bronze layer
# 2025-04-19 15:03:14,123 - INFO - Data Quality Metrics for bronze layer:
# 2025-04-19 15:03:14,125 - INFO -   - Shape: [15,1000] (approx. row count)
# 2025-04-19 15:03:14,127 - INFO -   - Schema:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- account_number: string (nullable = true)
#  |-- transaction_type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- balance_after: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#  |-- source_file: string (nullable = false)
#  |-- batch_id: string (nullable = false)
#
# 2025-04-19 15:03:14,128 - INFO -   - Sample size: 95
# 2025-04-19 15:03:14,133 - WARNING -   - Columns with high null percentages: {'merchant': 47.368421052631575, 'category': 49.473684210526315}
# 2025-04-19 15:03:14,136 - INFO - Validating dataframe with 3 rules
# 2025-04-19 15:03:14,660 - INFO - Validation rule 'has_transaction_id' FAILED - 1 records (1.05%) failed
# 2025-04-19 15:03:14,884 - INFO - Validation rule 'valid_amount' FAILED - 66 records (69.47%) failed
# 2025-04-19 15:03:15,132 - INFO - Validation rule 'valid_timestamp' FAILED - 2 records (2.11%) failed
# 2025-04-19 15:03:15,137 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250419_150235",
#   "layer": "bronze",
#   "version": 25,
#   "timestamp": "2025-04-19T15:03:15.137617",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "bronze",
#       "shape": "[15,1000] (approx. row count)",
#       "schema": "root\n |-- transaction_id: string (nullable = true)\n |-- timestamp: string (nullable = true)\n |-- customer_id: string (nullable = true)\n |-- account_number: string (nullable = true)\n |-- transaction_type: string (nullable = true)\n |-- amount: double (nullable = true)\n |-- currency: string (nullable = true)\n |-- balance_after: double (nullable = true)\n |-- status: string (nullable = true)\n |-- merchant: string (nullable = true)\n |-- category: string (nullable = true)\n |-- location: string (nullable = true)\n |-- ingestion_timestamp: timestamp (nullable = false)\n |-- source_file: string (nullable = false)\n |-- batch_id: string (nullable = false)\n",
#       "sample_size": 95,
#       "null_percentages": {
#         "transaction_id": 1.0526315789473684,
#         "timestamp": 2.1052631578947367,
#         "customer_id": 0.0,
#         "account_number": 2.1052631578947367,
#         "transaction_type": 2.1052631578947367,
#         "amount": 0.0,
#         "currency": 2.1052631578947367,
#         "balance_after": 0.0,
#         "status": 2.1052631578947367,
#         "merchant": 47.368421052631575,
#         "category": 49.473684210526315,
#         "location": 0.0,
#         "ingestion_timestamp": 0.0,
#         "source_file": 0.0,
#         "batch_id": 0.0
#       },
#       "high_null_columns": {
#         "merchant": 47.368421052631575,
#         "category": 49.473684210526315
#       },
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-19T15:03:14.123161"
#     },
#     "validation_results": {
#       "validation_results": {
#         "has_transaction_id": {
#           "description": "Transaction ID must be present",
#           "failing_count": 1,
#           "failing_percentage": 1.0526315789473684,
#           "passed": false
#         },
#         "valid_amount": {
#           "description": "Amount must be positive if not null",
#           "failing_count": 66,
#           "failing_percentage": 69.47368421052632,
#           "passed": false
#         },
#         "valid_timestamp": {
#           "description": "Timestamp must not be in the future",
#           "failing_count": 2,
#           "failing_percentage": 2.1052631578947367,
#           "passed": false
#         }
#       },
#       "sample_size": 95,
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-19T15:03:15.137617",
#       "all_passed": false
#     },
#     "source_path": [
#       "c:\\GitHub\\DE_Pipelines\\data\\financial_transactions_20250409_113413.csv",
#       "c:\\GitHub\\DE_Pipelines\\data\\financial_transactions_20250410_113413.csv"
#     ],
#     "duration_seconds": 39.3483521938324
#   }
# }
# 2025-04-19 15:03:15,140 - INFO - Bronze layer processing completed in 39.35 seconds
# 2025-04-19 15:03:15,142 - INFO - Starting table optimization
# 2025-04-19 15:03:24,870 - INFO - Optimized de_pipelines.financial_osb_bronze_type1. Files: before=2, after=1
# 2025-04-19 15:03:24,872 - INFO - --Bronze layer successfully optimized in 9.73 seconds--
# 2025-04-19 15:03:24,874 - INFO - Starting silver layer processing
# 2025-04-19 15:03:25,210 - INFO - Successfully read bronze data version 25
# 2025-04-19 15:03:25,387 - INFO - Transformation function applied
# 2025-04-19 15:03:25,389 - INFO - Writing to silver table: de_pipelines.financial_osb_silver_type1
# 2025-04-19 15:03:40,967 - INFO - Successfully wrote to silver table: de_pipelines.financial_osb_silver_type1
# 2025-04-19 15:03:40,969 - INFO - Write Metrics:
# [
#   {
#     "numOutputRows": "950",
#     "numOutputBytes": "142790",
#     "numFiles": "13"
#   }
# ]
# 2025-04-19 15:03:41,448 - INFO - Running data quality checks for silver layer
# 2025-04-19 15:03:51,562 - INFO - Data Quality Metrics for silver layer:
# 2025-04-19 15:03:51,564 - INFO -   - Shape: [19,950] (approx. row count)
# 2025-04-19 15:03:51,565 - INFO -   - Schema:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- account_number: string (nullable = true)
#  |-- transaction_type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- balance_after: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = true)
#  |-- source_file: string (nullable = true)
#  |-- batch_id: string (nullable = true)
#  |-- transaction_date: date (nullable = true)
#  |-- transaction_time: string (nullable = true)
#  |-- year_month: string (nullable = true)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-19 15:03:51,569 - INFO -   - Sample size: 92
# 2025-04-19 15:03:51,570 - WARNING -   - Columns with high null percentages: {'merchant': 48.91304347826087, 'category': 46.73913043478261}
# 2025-04-19 15:03:51,572 - INFO - Validating dataframe with 4 rules
# 2025-04-19 15:03:58,203 - INFO - Validation rule 'valid_transaction_type' FAILED - 38 records (41.30%) failed
# 2025-04-19 15:04:00,011 - INFO - Validation rule 'valid_status' FAILED - 39 records (42.39%) failed
# 2025-04-19 15:04:02,089 - INFO - Validation rule 'valid_currency' FAILED - 3 records (3.26%) failed
# 2025-04-19 15:04:03,723 - INFO - Validation rule 'valid_timestamp' FAILED - 1 records (1.09%) failed
# 2025-04-19 15:04:03,732 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250419_150235",
#   "layer": "silver",
#   "version": 19,
#   "timestamp": "2025-04-19T15:04:03.732803",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "silver",
#       "shape": "[19,950] (approx. row count)",
#       "schema": "root\n |-- transaction_id: string (nullable = true)\n |-- timestamp: timestamp (nullable = true)\n |-- customer_id: string (nullable = true)\n |-- account_number: string (nullable = true)\n |-- transaction_type: string (nullable = true)\n |-- amount: double (nullable = true)\n |-- currency: string (nullable = true)\n |-- balance_after: double (nullable = true)\n |-- status: string (nullable = true)\n |-- merchant: string (nullable = true)\n |-- category: string (nullable = true)\n |-- location: string (nullable = true)\n |-- ingestion_timestamp: timestamp (nullable = true)\n |-- source_file: string (nullable = true)\n |-- batch_id: string (nullable = true)\n |-- transaction_date: date (nullable = true)\n |-- transaction_time: string (nullable = true)\n |-- year_month: string (nullable = true)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 92,
#       "null_percentages": {
#         "transaction_id": 0.0,
#         "timestamp": 1.0869565217391304,
#         "customer_id": 1.0869565217391304,
#         "account_number": 0.0,
#         "transaction_type": 3.260869565217391,
#         "amount": 0.0,
#         "currency": 3.260869565217391,
#         "balance_after": 1.0869565217391304,
#         "status": 1.0869565217391304,
#         "merchant": 48.91304347826087,
#         "category": 46.73913043478261,
#         "location": 0.0,
#         "ingestion_timestamp": 0.0,
#         "source_file": 0.0,
#         "batch_id": 0.0,
#         "transaction_date": 1.0869565217391304,
#         "transaction_time": 1.0869565217391304,
#         "year_month": 1.0869565217391304,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {
#         "merchant": 48.91304347826087,
#         "category": 46.73913043478261
#       },
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-19T15:03:51.562940"
#     },
#     "validation_results": {
#       "validation_results": {
#         "valid_transaction_type": {
#           "description": "Transaction type must be one of the valid types",
#           "failing_count": 38,
#           "failing_percentage": 41.30434782608695,
#           "passed": false
#         },
#         "valid_status": {
#           "description": "Status must be one of the valid statuses",
#           "failing_count": 39,
#           "failing_percentage": 42.391304347826086,
#           "passed": false
#         },
#         "valid_currency": {
#           "description": "Currency code should be 3 characters if present",
#           "failing_count": 3,
#           "failing_percentage": 3.260869565217391,
#           "passed": false
#         },
#         "valid_timestamp": {
#           "description": "Timestamp must not be NULL or in the future",
#           "failing_count": 1,
#           "failing_percentage": 1.0869565217391304,
#           "passed": false
#         }
#       },
#       "sample_size": 92,
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-19T15:04:03.732803",
#       "all_passed": false
#     },
#     "source_bronze_version": 25,
#     "duration_seconds": 38.85700345039368
#   }
# }
# 2025-04-19 15:04:03,733 - INFO - Silver layer processing completed in 38.86 seconds
# 2025-04-19 15:04:03,735 - INFO - Starting table optimization
# 2025-04-19 15:04:20,135 - INFO - Optimized de_pipelines.financial_osb_silver_type1. Files: before=13, after=13
# 2025-04-19 15:04:20,136 - INFO - --Silver layer successfully optimized in 16.40 seconds--
# 2025-04-19 15:04:20,138 - INFO - Starting gold layer processing
# 2025-04-19 15:04:20,398 - INFO - Successfully read silver data version 19
# 2025-04-19 15:04:20,587 - INFO - Transformation function applied
# 2025-04-19 15:04:20,589 - INFO - Writing to gold table: de_pipelines.financial_osb_gold_type1_daily_category
# 2025-04-19 15:04:32,149 - INFO - Successfully wrote to gold table: de_pipelines.financial_osb_gold_type1_daily_category
# 2025-04-19 15:04:32,151 - INFO - Write Metrics:
# [
#   {
#     "numOutputRows": "702",
#     "numOutputBytes": "20686",
#     "numFiles": "1"
#   }
# ]
# 2025-04-19 15:04:32,499 - INFO - Running data quality checks for de_pipelines.financial_osb_gold_type1_daily_category layer
# 2025-04-19 15:04:40,898 - INFO - Data Quality Metrics for de_pipelines.financial_osb_gold_type1_daily_category layer:
# 2025-04-19 15:04:40,900 - INFO -   - Shape: [9,702] (approx. row count)
# 2025-04-19 15:04:40,901 - INFO -   - Schema:
# root
#  |-- transaction_date: date (nullable = true)
#  |-- category: string (nullable = true)
#  |-- transaction_count: long (nullable = false)
#  |-- total_amount: double (nullable = true)
#  |-- avg_amount: double (nullable = true)
#  |-- min_amount: double (nullable = true)
#  |-- max_amount: double (nullable = true)
#  |-- unique_customers: long (nullable = false)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-19 15:04:40,904 - INFO -   - Sample size: 151
# 2025-04-19 15:04:40,906 - WARNING -   - Columns with high null percentages: {'category': 40.397350993377486}
# 2025-04-19 15:04:40,907 - INFO - Validating dataframe with 2 rules
# 2025-04-19 15:04:46,591 - INFO - Validation rule 'positive_transaction_counts' PASSED - 0 records (0.00%) failed
# 2025-04-19 15:04:47,982 - INFO - Validation rule 'valid_total_amounts' PASSED - 0 records (0.00%) failed
# 2025-04-19 15:04:47,987 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250419_150235",
#   "layer": "gold_daily_category",
#   "version": 5,
#   "timestamp": "2025-04-19T15:04:47.987779",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "de_pipelines.financial_osb_gold_type1_daily_category",
#       "shape": "[9,702] (approx. row count)",
#       "schema": "root\n |-- transaction_date: date (nullable = true)\n |-- category: string (nullable = true)\n |-- transaction_count: long (nullable = false)\n |-- total_amount: double (nullable = true)\n |-- avg_amount: double (nullable = true)\n |-- min_amount: double (nullable = true)\n |-- max_amount: double (nullable = true)\n |-- unique_customers: long (nullable = false)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 151,
#       "null_percentages": {
#         "transaction_date": 0.0,
#         "category": 40.397350993377486,
#         "transaction_count": 0.0,
#         "total_amount": 0.0,
#         "avg_amount": 0.0,
#         "min_amount": 0.0,
#         "max_amount": 0.0,
#         "unique_customers": 0.0,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {
#         "category": 40.397350993377486
#       },
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-19T15:04:40.898104"
#     },
#     "validation_results": {
#       "validation_results": {
#         "positive_transaction_counts": {
#           "description": "Transaction counts should be positive",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_total_amounts": {
#           "description": "Total amounts should not be negative",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         }
#       },
#       "sample_size": 151,
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-19T15:04:47.987779",
#       "all_passed": true
#     },
#     "source_silver_version": 19
#   }
# }
# 2025-04-19 15:04:47,989 - INFO - Writing to gold table: de_pipelines.financial_osb_gold_type1_customer_summary
# 2025-04-19 15:04:56,136 - INFO - Successfully wrote to gold table: de_pipelines.financial_osb_gold_type1_customer_summary
# 2025-04-19 15:04:56,137 - INFO - Write Metrics:
# [
#   {
#     "numOutputRows": "217",
#     "numOutputBytes": "9336",
#     "numFiles": "1"
#   }
# ]
# 2025-04-19 15:04:56,514 - INFO - Running data quality checks for de_pipelines.financial_osb_gold_type1_customer_summary layer
# 2025-04-19 15:05:06,573 - INFO - Data Quality Metrics for de_pipelines.financial_osb_gold_type1_customer_summary layer:
# 2025-04-19 15:05:06,574 - INFO -   - Shape: [9,217] (approx. row count)
# 2025-04-19 15:05:06,576 - INFO -   - Schema:
# root
#  |-- customer_id: string (nullable = true)
#  |-- transaction_count: long (nullable = false)
#  |-- total_amount: double (nullable = true)
#  |-- avg_amount: double (nullable = true)
#  |-- first_transaction_date: date (nullable = true)
#  |-- last_transaction_date: date (nullable = true)
#  |-- category_count: long (nullable = false)
#  |-- processing_timestamp: timestamp (nullable = false)
#  |-- days_since_last_transaction: integer (nullable = true)
#
# 2025-04-19 15:05:06,578 - INFO -   - Sample size: 51
# 2025-04-19 15:05:06,580 - INFO - Validating dataframe with 2 rules
# 2025-04-19 15:05:12,707 - INFO - Validation rule 'positive_transaction_counts' PASSED - 0 records (0.00%) failed
# 2025-04-19 15:05:14,192 - INFO - Validation rule 'valid_total_amounts' PASSED - 0 records (0.00%) failed
# 2025-04-19 15:05:14,198 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250419_150235",
#   "layer": "gold_customer_summary",
#   "version": 5,
#   "timestamp": "2025-04-19T15:05:14.198158",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "de_pipelines.financial_osb_gold_type1_customer_summary",
#       "shape": "[9,217] (approx. row count)",
#       "schema": "root\n |-- customer_id: string (nullable = true)\n |-- transaction_count: long (nullable = false)\n |-- total_amount: double (nullable = true)\n |-- avg_amount: double (nullable = true)\n |-- first_transaction_date: date (nullable = true)\n |-- last_transaction_date: date (nullable = true)\n |-- category_count: long (nullable = false)\n |-- processing_timestamp: timestamp (nullable = false)\n |-- days_since_last_transaction: integer (nullable = true)\n",
#       "sample_size": 51,
#       "null_percentages": {
#         "customer_id": 0.0,
#         "transaction_count": 0.0,
#         "total_amount": 0.0,
#         "avg_amount": 0.0,
#         "first_transaction_date": 0.0,
#         "last_transaction_date": 0.0,
#         "category_count": 0.0,
#         "processing_timestamp": 0.0,
#         "days_since_last_transaction": 0.0
#       },
#       "high_null_columns": {},
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-19T15:05:06.572180"
#     },
#     "validation_results": {
#       "validation_results": {
#         "positive_transaction_counts": {
#           "description": "Transaction counts should be positive",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_total_amounts": {
#           "description": "Total amounts should not be negative",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         }
#       },
#       "sample_size": 51,
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-19T15:05:14.198158",
#       "all_passed": true
#     },
#     "source_silver_version": 19
#   }
# }
# 2025-04-19 15:05:14,200 - INFO - Writing to gold table: de_pipelines.financial_osb_gold_type1_transaction_type_summary
# 2025-04-19 15:05:21,624 - INFO - Successfully wrote to gold table: de_pipelines.financial_osb_gold_type1_transaction_type_summary
# 2025-04-19 15:05:21,626 - INFO - Write Metrics:
# [
#   {
#     "numOutputRows": "17",
#     "numOutputBytes": "2142",
#     "numFiles": "1"
#   }
# ]
# 2025-04-19 15:05:21,937 - INFO - Running data quality checks for de_pipelines.financial_osb_gold_type1_transaction_type_summary layer
# 2025-04-19 15:05:28,900 - INFO - Data Quality Metrics for de_pipelines.financial_osb_gold_type1_transaction_type_summary layer:
# 2025-04-19 15:05:28,902 - INFO -   - Shape: [5,17] (approx. row count)
# 2025-04-19 15:05:28,903 - INFO -   - Schema:
# root
#  |-- transaction_type: string (nullable = true)
#  |-- transaction_count: long (nullable = false)
#  |-- total_amount: double (nullable = true)
#  |-- avg_amount: double (nullable = true)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-19 15:05:28,906 - INFO -   - Sample size: 3
# 2025-04-19 15:05:28,907 - INFO - Validating dataframe with 2 rules
# 2025-04-19 15:05:32,989 - INFO - Validation rule 'positive_transaction_counts' PASSED - 0 records (0.00%) failed
# 2025-04-19 15:05:34,256 - INFO - Validation rule 'valid_total_amounts' PASSED - 0 records (0.00%) failed
# 2025-04-19 15:05:34,260 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250419_150235",
#   "layer": "gold_transaction_type_summary",
#   "version": 5,
#   "timestamp": "2025-04-19T15:05:34.260441",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "de_pipelines.financial_osb_gold_type1_transaction_type_summary",
#       "shape": "[5,17] (approx. row count)",
#       "schema": "root\n |-- transaction_type: string (nullable = true)\n |-- transaction_count: long (nullable = false)\n |-- total_amount: double (nullable = true)\n |-- avg_amount: double (nullable = true)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 3,
#       "null_percentages": {
#         "transaction_type": 0.0,
#         "transaction_count": 0.0,
#         "total_amount": 0.0,
#         "avg_amount": 0.0,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {},
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-19T15:05:28.900424"
#     },
#     "validation_results": {
#       "validation_results": {
#         "positive_transaction_counts": {
#           "description": "Transaction counts should be positive",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_total_amounts": {
#           "description": "Total amounts should not be negative",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         }
#       },
#       "sample_size": 3,
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-19T15:05:34.260441",
#       "all_passed": true
#     },
#     "source_silver_version": 19
#   }
# }
# 2025-04-19 15:05:34,262 - INFO - Gold layer processing completed in 74.12 seconds
# 2025-04-19 15:05:34,264 - INFO - Starting table optimization
# 2025-04-19 15:05:36,210 - INFO - Optimized de_pipelines.financial_osb_gold_type1_daily_category. Files: before=1, after=1
# 2025-04-19 15:05:36,211 - INFO - Starting table optimization
# 2025-04-19 15:05:38,151 - INFO - Optimized de_pipelines.financial_osb_gold_type1_customer_summary. Files: before=1, after=1
# 2025-04-19 15:05:38,152 - INFO - Starting table optimization
# 2025-04-19 15:05:40,156 - INFO - Optimized de_pipelines.financial_osb_gold_type1_transaction_type_summary. Files: before=1, after=1
# 2025-04-19 15:05:40,158 - INFO - --Gold layer successfully optimized in 5.89 seconds--
# 2025-04-19 15:05:40,159 - INFO - ---Full pipeline execution completed successfully in 184.37 seconds---
# 2025-04-19 15:05:41,493 - INFO - Spark session stopped
# {'status': 'success',
#  'pipeline_id': 'Financial_DE_Pipeline_20250419_150235',
#  'bronze_version': 25,
#  'silver_version': 19,
#  'timestamp': '2025-04-19T15:05:40.161266',
#  'duration_seconds': 184.37400603294373,
#  'metrics': {'pipeline_id': 'Financial_DE_Pipeline_20250419_150235',
#   'start_time': '2025-04-19T15:02:35.785262',
#   'stages': {'bronze': {'duration_seconds': 39.355348348617554,
#     'version': 25,
#     'status': 'success'},
#    'bronze_optimize': {'layer': 'bronze',
#     'duration_seconds': 9.730194568634033,
#     'status': 'success'},
#    'silver': {'duration_seconds': 38.86100745201111,
#     'version': 19,
#     'status': 'success',
#     'source_bronze_version': 25},
#    'silver_optimize': {'layer': 'silver',
#     'duration_seconds': 16.40110206604004,
#     'status': 'success'},
#    'gold': {'duration_seconds': 74.1245186328888,
#     'status': 'success',
#     'source_silver_version': 19,
#     'tables': ['daily_category',
#      'customer_summary',
#      'transaction_type_summary']},
#    'gold_optimize': {'layer': 'gold',
#     'duration_seconds': 5.8948211669921875,
#     'status': 'success'}},
#   'status': 'success',
#   'end_time': '2025-04-19T15:05:40.159268',
#   'total_duration_seconds': 184.37400603294373}}

# %% [markdown]
# ### Running Layers In Isolation

# %%
spark = initialize_local_spark_delta_lake("Financial Data Pipeline - Testing")
# Out:
# 2025-04-19 15:05:41,535 - INFO - ---Spark session initialized with Delta Lake support---

# %% [markdown]
# #### Bronze

# %%
bronzedf, bronze_version = process_batch_bronze_layer(spark, 'csv', abs_file_list, get_schema(), bronze_table,
                               bronze_transform=None, validation_rules=bronze_validation_rules,
                               pipeline_id='test', mode='test', bronze_writer=None)
# Out:
# 2025-04-19 15:05:43,074 - INFO - Starting bronze layer processing
# 2025-04-19 15:05:43,140 - INFO - Successfully read CSV data from:
#   - c:\GitHub\DE_Pipelines\data\financial_transactions_20250409_113413.csv
#   - c:\GitHub\DE_Pipelines\data\financial_transactions_20250410_113413.csv
# 2025-04-19 15:05:43,141 - INFO - No transformation function defined
# 2025-04-19 15:05:43,143 - WARNING - --- Bronze layer in Test Mode ---
# 2025-04-19 15:05:43,144 - INFO - Running data quality checks for bronze layer
# 2025-04-19 15:05:47,617 - INFO - Data Quality Metrics for bronze layer:
# 2025-04-19 15:05:47,618 - INFO -   - Shape: [15,1000] (approx. row count)
# 2025-04-19 15:05:47,620 - INFO -   - Schema:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- account_number: string (nullable = true)
#  |-- transaction_type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- balance_after: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#  |-- source_file: string (nullable = false)
#  |-- batch_id: string (nullable = false)
#
# 2025-04-19 15:05:47,621 - INFO -   - Sample size: 95
# 2025-04-19 15:05:47,622 - WARNING -   - Columns with high null percentages: {'merchant': 47.368421052631575, 'category': 49.473684210526315}
# 2025-04-19 15:05:47,624 - INFO - Validating dataframe with 3 rules
# 2025-04-19 15:05:48,106 - INFO - Validation rule 'has_transaction_id' FAILED - 1 records (1.05%) failed
# 2025-04-19 15:05:48,233 - INFO - Validation rule 'valid_amount' FAILED - 66 records (69.47%) failed
# 2025-04-19 15:05:48,336 - INFO - Validation rule 'valid_timestamp' FAILED - 2 records (2.11%) failed
# 2025-04-19 15:05:48,339 - INFO - Checkpoint created:
# {
#   "pipeline_id": "test",
#   "layer": "bronze",
#   "version": "test",
#   "timestamp": "2025-04-19T15:05:48.338351",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "bronze",
#       "shape": "[15,1000] (approx. row count)",
#       "schema": "root\n |-- transaction_id: string (nullable = true)\n |-- timestamp: string (nullable = true)\n |-- customer_id: string (nullable = true)\n |-- account_number: string (nullable = true)\n |-- transaction_type: string (nullable = true)\n |-- amount: double (nullable = true)\n |-- currency: string (nullable = true)\n |-- balance_after: double (nullable = true)\n |-- status: string (nullable = true)\n |-- merchant: string (nullable = true)\n |-- category: string (nullable = true)\n |-- location: string (nullable = true)\n |-- ingestion_timestamp: timestamp (nullable = false)\n |-- source_file: string (nullable = false)\n |-- batch_id: string (nullable = false)\n",
#       "sample_size": 95,
#       "null_percentages": {
#         "transaction_id": 1.0526315789473684,
#         "timestamp": 2.1052631578947367,
#         "customer_id": 0.0,
#         "account_number": 2.1052631578947367,
#         "transaction_type": 2.1052631578947367,
#         "amount": 0.0,
#         "currency": 2.1052631578947367,
#         "balance_after": 0.0,
#         "status": 2.1052631578947367,
#         "merchant": 47.368421052631575,
#         "category": 49.473684210526315,
#         "location": 0.0,
#         "ingestion_timestamp": 0.0,
#         "source_file": 0.0,
#         "batch_id": 0.0
#       },
#       "high_null_columns": {
#         "merchant": 47.368421052631575,
#         "category": 49.473684210526315
#       },
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-19T15:05:47.617975"
#     },
#     "validation_results": {
#       "validation_results": {
#         "has_transaction_id": {
#           "description": "Transaction ID must be present",
#           "failing_count": 1,
#           "failing_percentage": 1.0526315789473684,
#           "passed": false
#         },
#         "valid_amount": {
#           "description": "Amount must be positive if not null",
#           "failing_count": 66,
#           "failing_percentage": 69.47368421052632,
#           "passed": false
#         },
#         "valid_timestamp": {
#           "description": "Timestamp must not be in the future",
#           "failing_count": 2,
#           "failing_percentage": 2.1052631578947367,
#           "passed": false
#         }
#       },
#       "sample_size": 95,
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-19T15:05:48.338351",
#       "all_passed": false
#     },
#     "source_path": [
#       "c:\\GitHub\\DE_Pipelines\\data\\financial_transactions_20250409_113413.csv",
#       "c:\\GitHub\\DE_Pipelines\\data\\financial_transactions_20250410_113413.csv"
#     ],
#     "duration_seconds": 5.263326644897461
#   }
# }
# 2025-04-19 15:05:48,340 - INFO - Bronze layer processing completed in 5.27 seconds

# %%
bronzedf.show(5)
# Out:
# +--------------+-------------------+-----------+--------------+----------------+-------+--------+-------------+--------+--------------------+---------+---------------+--------------------+--------------------+--------+
# |transaction_id|          timestamp|customer_id|account_number|transaction_type| amount|currency|balance_after|  status|            merchant| category|       location| ingestion_timestamp|         source_file|batch_id|
# +--------------+-------------------+-----------+--------------+----------------+-------+--------+-------------+--------+--------------------+---------+---------------+--------------------+--------------------+--------+
# |   TXN00000001|2023-05-05 03:42:36| CUST001179| ACCT-39450273|        interest|1378.52|     USD|      9544.56|reversed|                NULL|     NULL|Los Angeles, CA|2025-04-19 15:05:...|file:///c:/GitHub...|    test|
# |   TXN00000002|2023-08-11 06:24:46| CUST001188| ACCT-55298556|          refund| 1626.4|     JPY|      9598.17|disputed|               Zelle| shopping|     Austin, TX|2025-04-19 15:05:...|file:///c:/GitHub...|    test|
# |   TXN00000003|2023-06-24 10:10:55| CUST001153|          NULL|          refund|   30.3|     USD|      1800.82|disputed|    American Express|education|            ATM|2025-04-19 15:05:...|file:///c:/GitHub...|    test|
# |   TXN00000004|2023-08-21 09:51:49| CUST001079| ACCT-49823450|      withdrawal|-130.66|     USD|      3709.27|reversed|                NULL|     NULL|         Branch|2025-04-19 15:05:...|file:///c:/GitHub...|    test|
# |   TXN00000005|2023-12-29 19:26:50| CUST001033| ACCT-22201654|         deposit|1958.59|     JPY|      5587.82| pending|Direct Deposit - ...|   income|         Branch|2025-04-19 15:05:...|file:///c:/GitHub...|    test|
# +--------------+-------------------+-----------+--------------+----------------+-------+--------+-------------+--------+--------------------+---------+---------------+--------------------+--------------------+--------+
# only showing top 5 rows

# %% [markdown]
# #### Silver

# %%
silverdf, silver_version = process_batch_silver_layer(spark, bronze_table, bronze_version=None, 
                                                   silver_table=silver_table, 
                                                   silver_transform=silver_transform, 
                                                   validation_rules=silver_validation_rules,
                                                   pipeline_id='test', mode='test', 
                                                   silver_writer=None)
# Out:
# 2025-04-19 15:05:48,540 - INFO - Starting silver layer processing
# 2025-04-19 15:05:49,420 - INFO - Successfully read bronze data version 26
# 2025-04-19 15:05:49,560 - INFO - Transformation function applied
# 2025-04-19 15:05:49,562 - WARNING - --- Silver layer in Test Mode ---
# 2025-04-19 15:05:49,563 - INFO - Running data quality checks for silver layer
# 2025-04-19 15:06:01,144 - INFO - Data Quality Metrics for silver layer:
# 2025-04-19 15:06:01,147 - INFO -   - Shape: [19,950] (approx. row count)
# 2025-04-19 15:06:01,147 - INFO -   - Schema:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- account_number: string (nullable = true)
#  |-- transaction_type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- balance_after: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = true)
#  |-- source_file: string (nullable = true)
#  |-- batch_id: string (nullable = true)
#  |-- transaction_date: date (nullable = true)
#  |-- transaction_time: string (nullable = true)
#  |-- year_month: string (nullable = true)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-19 15:06:01,149 - INFO -   - Sample size: 92
# 2025-04-19 15:06:01,151 - WARNING -   - Columns with high null percentages: {'merchant': 48.91304347826087, 'category': 46.73913043478261}
# 2025-04-19 15:06:01,153 - INFO - Validating dataframe with 4 rules
# 2025-04-19 15:06:06,393 - INFO - Validation rule 'valid_transaction_type' FAILED - 38 records (41.30%) failed
# 2025-04-19 15:06:07,884 - INFO - Validation rule 'valid_status' FAILED - 39 records (42.39%) failed
# 2025-04-19 15:06:09,291 - INFO - Validation rule 'valid_currency' FAILED - 3 records (3.26%) failed
# 2025-04-19 15:06:10,836 - INFO - Validation rule 'valid_timestamp' FAILED - 1 records (1.09%) failed
# 2025-04-19 15:06:10,843 - INFO - Checkpoint created:
# {
#   "pipeline_id": "test",
#   "layer": "silver",
#   "version": "test",
#   "timestamp": "2025-04-19T15:06:10.842764",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "silver",
#       "shape": "[19,950] (approx. row count)",
#       "schema": "root\n |-- transaction_id: string (nullable = true)\n |-- timestamp: timestamp (nullable = true)\n |-- customer_id: string (nullable = true)\n |-- account_number: string (nullable = true)\n |-- transaction_type: string (nullable = true)\n |-- amount: double (nullable = true)\n |-- currency: string (nullable = true)\n |-- balance_after: double (nullable = true)\n |-- status: string (nullable = true)\n |-- merchant: string (nullable = true)\n |-- category: string (nullable = true)\n |-- location: string (nullable = true)\n |-- ingestion_timestamp: timestamp (nullable = true)\n |-- source_file: string (nullable = true)\n |-- batch_id: string (nullable = true)\n |-- transaction_date: date (nullable = true)\n |-- transaction_time: string (nullable = true)\n |-- year_month: string (nullable = true)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 92,
#       "null_percentages": {
#         "transaction_id": 0.0,
#         "timestamp": 1.0869565217391304,
#         "customer_id": 1.0869565217391304,
#         "account_number": 0.0,
#         "transaction_type": 3.260869565217391,
#         "amount": 0.0,
#         "currency": 3.260869565217391,
#         "balance_after": 1.0869565217391304,
#         "status": 1.0869565217391304,
#         "merchant": 48.91304347826087,
#         "category": 46.73913043478261,
#         "location": 0.0,
#         "ingestion_timestamp": 0.0,
#         "source_file": 0.0,
#         "batch_id": 0.0,
#         "transaction_date": 1.0869565217391304,
#         "transaction_time": 1.0869565217391304,
#         "year_month": 1.0869565217391304,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {
#         "merchant": 48.91304347826087,
#         "category": 46.73913043478261
#       },
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-19T15:06:01.144659"
#     },
#     "validation_results": {
#       "validation_results": {
#         "valid_transaction_type": {
#           "description": "Transaction type must be one of the valid types",
#           "failing_count": 38,
#           "failing_percentage": 41.30434782608695,
#           "passed": false
#         },
#         "valid_status": {
#           "description": "Status must be one of the valid statuses",
#           "failing_count": 39,
#           "failing_percentage": 42.391304347826086,
#           "passed": false
#         },
#         "valid_currency": {
#           "description": "Currency code should be 3 characters if present",
#           "failing_count": 3,
#           "failing_percentage": 3.260869565217391,
#           "passed": false
#         },
#         "valid_timestamp": {
#           "description": "Timestamp must not be NULL or in the future",
#           "failing_count": 1,
#           "failing_percentage": 1.0869565217391304,
#           "passed": false
#         }
#       },
#       "sample_size": 92,
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-19T15:06:10.842764",
#       "all_passed": false
#     },
#     "source_bronze_version": 26,
#     "duration_seconds": 22.299314498901367
#   }
# }
# 2025-04-19 15:06:10,846 - INFO - Silver layer processing completed in 22.30 seconds

# %%
silverdf.show(5)
# Out:
# +--------------+-------------------+-----------+--------------+----------------+-------+--------+-------------+--------+--------------------+--------+---------------+--------------------+--------------------+--------------------+----------------+----------------+----------+--------------------+
# |transaction_id|          timestamp|customer_id|account_number|transaction_type| amount|currency|balance_after|  status|            merchant|category|       location| ingestion_timestamp|         source_file|            batch_id|transaction_date|transaction_time|year_month|processing_timestamp|
# +--------------+-------------------+-----------+--------------+----------------+-------+--------+-------------+--------+--------------------+--------+---------------+--------------------+--------------------+--------------------+----------------+----------------+----------+--------------------+
# |   TXN00000001|2023-05-05 03:42:36| CUST001179| ACCT-39450273|        interest|1378.52|     USD|      9544.56|reversed|                NULL|    NULL|Los Angeles, CA|2025-04-19 15:02:...|file:///c:/GitHub...|Financial_DE_Pipe...|      2023-05-05|        03:42:36|   2023-05|2025-04-19 15:06:...|
# |   TXN00000002|2023-08-11 06:24:46| CUST001188| ACCT-55298556|          refund| 1626.4|     JPY|      9598.17|disputed|               Zelle|shopping|     Austin, TX|2025-04-19 15:02:...|file:///c:/GitHub...|Financial_DE_Pipe...|      2023-08-11|        06:24:46|   2023-08|2025-04-19 15:06:...|
# |   TXN00000004|2023-08-21 09:51:49| CUST001079| ACCT-49823450|      withdrawal| 130.66|     USD|      3709.27|reversed|                NULL|    NULL|         Branch|2025-04-19 15:02:...|file:///c:/GitHub...|Financial_DE_Pipe...|      2023-08-21|        09:51:49|   2023-08|2025-04-19 15:06:...|
# |   TXN00000005|2023-12-29 19:26:50| CUST001033| ACCT-22201654|         deposit|1958.59|     JPY|      5587.82| pending|Direct Deposit - ...|  income|         Branch|2025-04-19 15:02:...|file:///c:/GitHub...|Financial_DE_Pipe...|      2023-12-29|        19:26:50|   2023-12|2025-04-19 15:06:...|
# |   TXN00000006|2023-01-28 05:31:27| CUST001039| ACCT-31227574|         deposit|1997.84|     USD|       8020.5|disputed|Direct Deposit - ...|  income|     Boston, MA|2025-04-19 15:02:...|file:///c:/GitHub...|Financial_DE_Pipe...|      2023-01-28|        05:31:27|   2023-01|2025-04-19 15:06:...|
# +--------------+-------------------+-----------+--------------+----------------+-------+--------+-------------+--------+--------------------+--------+---------------+--------------------+--------------------+--------------------+----------------+----------------+----------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ##### Investigating Silver Validation Check Failures:
# Corrupt "status" column

# %%
silverdf.groupBy('status').count().show()
# Out:
# +---------+-----+
# |   status|count|
# +---------+-----+
# | dqsputed|    1|
# |  pgnding|    1|
# |completed|  195|
# |   failen|    1|
# |   failed|  179|
# |bompleted|    1|
# |     NULL|   17|
# |comcleted|    1|
# | disputad|    1|
# | dmsputed|    1|
# | diiputed|    1|
# |  pending|  164|
# | disputed|  190|
# | reverszd|    1|
# | reversed|  196|
# +---------+-----+

# %% [markdown]
# #### Gold

# %%
gold_dfs = process_batch_gold_layer(spark, silver_table, silver_version=None, 
                                 gold_table=gold_table, 
                                 gold_transform=gold_transform, 
                                 validation_rules=gold_validation_rules, 
                                 pipeline_id='test', 
                                 mode='test',
                                 gold_writer=None)
# Out:
# 2025-04-19 15:06:13,598 - INFO - Starting gold layer processing
# 2025-04-19 15:06:14,254 - INFO - Successfully read silver data version 20
# 2025-04-19 15:06:14,439 - INFO - Transformation function applied
# 2025-04-19 15:06:14,441 - WARNING - Gold layer in Test Mode
# 2025-04-19 15:06:14,443 - INFO - Running data quality checks for de_pipelines.financial_osb_gold_type1_daily_category layer
# 2025-04-19 15:06:26,128 - INFO - Data Quality Metrics for de_pipelines.financial_osb_gold_type1_daily_category layer:
# 2025-04-19 15:06:26,129 - INFO -   - Shape: [9,702] (approx. row count)
# 2025-04-19 15:06:26,131 - INFO -   - Schema:
# root
#  |-- transaction_date: date (nullable = true)
#  |-- category: string (nullable = true)
#  |-- transaction_count: long (nullable = false)
#  |-- total_amount: double (nullable = true)
#  |-- avg_amount: double (nullable = true)
#  |-- min_amount: double (nullable = true)
#  |-- max_amount: double (nullable = true)
#  |-- unique_customers: long (nullable = false)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-19 15:06:26,133 - INFO -   - Sample size: 151
# 2025-04-19 15:06:26,135 - WARNING -   - Columns with high null percentages: {'category': 40.397350993377486}
# 2025-04-19 15:06:26,136 - INFO - Validating dataframe with 2 rules
# 2025-04-19 15:06:30,974 - INFO - Validation rule 'positive_transaction_counts' PASSED - 0 records (0.00%) failed
# 2025-04-19 15:06:32,294 - INFO - Validation rule 'valid_total_amounts' PASSED - 0 records (0.00%) failed
# 2025-04-19 15:06:32,307 - INFO - Checkpoint created:
# {
#   "pipeline_id": "test",
#   "layer": "gold_daily_category",
#   "version": "test",
#   "timestamp": "2025-04-19T15:06:32.306282",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "de_pipelines.financial_osb_gold_type1_daily_category",
#       "shape": "[9,702] (approx. row count)",
#       "schema": "root\n |-- transaction_date: date (nullable = true)\n |-- category: string (nullable = true)\n |-- transaction_count: long (nullable = false)\n |-- total_amount: double (nullable = true)\n |-- avg_amount: double (nullable = true)\n |-- min_amount: double (nullable = true)\n |-- max_amount: double (nullable = true)\n |-- unique_customers: long (nullable = false)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 151,
#       "null_percentages": {
#         "transaction_date": 0.0,
#         "category": 40.397350993377486,
#         "transaction_count": 0.0,
#         "total_amount": 0.0,
#         "avg_amount": 0.0,
#         "min_amount": 0.0,
#         "max_amount": 0.0,
#         "unique_customers": 0.0,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {
#         "category": 40.397350993377486
#       },
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-19T15:06:26.128284"
#     },
#     "validation_results": {
#       "validation_results": {
#         "positive_transaction_counts": {
#           "description": "Transaction counts should be positive",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_total_amounts": {
#           "description": "Total amounts should not be negative",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         }
#       },
#       "sample_size": 151,
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-19T15:06:32.306282",
#       "all_passed": true
#     },
#     "source_silver_version": 20
#   }
# }
# 2025-04-19 15:06:32,309 - INFO - Running data quality checks for de_pipelines.financial_osb_gold_type1_customer_summary layer
# 2025-04-19 15:06:41,122 - INFO - Data Quality Metrics for de_pipelines.financial_osb_gold_type1_customer_summary layer:
# 2025-04-19 15:06:41,123 - INFO -   - Shape: [9,217] (approx. row count)
# 2025-04-19 15:06:41,124 - INFO -   - Schema:
# root
#  |-- customer_id: string (nullable = true)
#  |-- transaction_count: long (nullable = false)
#  |-- total_amount: double (nullable = true)
#  |-- avg_amount: double (nullable = true)
#  |-- first_transaction_date: date (nullable = true)
#  |-- last_transaction_date: date (nullable = true)
#  |-- category_count: long (nullable = false)
#  |-- processing_timestamp: timestamp (nullable = false)
#  |-- days_since_last_transaction: integer (nullable = true)
#
# 2025-04-19 15:06:41,125 - INFO -   - Sample size: 51
# 2025-04-19 15:06:41,126 - INFO - Validating dataframe with 2 rules
# 2025-04-19 15:06:47,643 - INFO - Validation rule 'positive_transaction_counts' PASSED - 0 records (0.00%) failed
# 2025-04-19 15:06:49,049 - INFO - Validation rule 'valid_total_amounts' PASSED - 0 records (0.00%) failed
# 2025-04-19 15:06:49,055 - INFO - Checkpoint created:
# {
#   "pipeline_id": "test",
#   "layer": "gold_customer_summary",
#   "version": "test",
#   "timestamp": "2025-04-19T15:06:49.055936",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "de_pipelines.financial_osb_gold_type1_customer_summary",
#       "shape": "[9,217] (approx. row count)",
#       "schema": "root\n |-- customer_id: string (nullable = true)\n |-- transaction_count: long (nullable = false)\n |-- total_amount: double (nullable = true)\n |-- avg_amount: double (nullable = true)\n |-- first_transaction_date: date (nullable = true)\n |-- last_transaction_date: date (nullable = true)\n |-- category_count: long (nullable = false)\n |-- processing_timestamp: timestamp (nullable = false)\n |-- days_since_last_transaction: integer (nullable = true)\n",
#       "sample_size": 51,
#       "null_percentages": {
#         "customer_id": 0.0,
#         "transaction_count": 0.0,
#         "total_amount": 0.0,
#         "avg_amount": 0.0,
#         "first_transaction_date": 0.0,
#         "last_transaction_date": 0.0,
#         "category_count": 0.0,
#         "processing_timestamp": 0.0,
#         "days_since_last_transaction": 0.0
#       },
#       "high_null_columns": {},
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-19T15:06:41.122436"
#     },
#     "validation_results": {
#       "validation_results": {
#         "positive_transaction_counts": {
#           "description": "Transaction counts should be positive",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_total_amounts": {
#           "description": "Total amounts should not be negative",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         }
#       },
#       "sample_size": 51,
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-19T15:06:49.055936",
#       "all_passed": true
#     },
#     "source_silver_version": 20
#   }
# }
# 2025-04-19 15:06:49,057 - INFO - Running data quality checks for de_pipelines.financial_osb_gold_type1_transaction_type_summary layer
# 2025-04-19 15:06:55,111 - INFO - Data Quality Metrics for de_pipelines.financial_osb_gold_type1_transaction_type_summary layer:
# 2025-04-19 15:06:55,112 - INFO -   - Shape: [5,17] (approx. row count)
# 2025-04-19 15:06:55,114 - INFO -   - Schema:
# root
#  |-- transaction_type: string (nullable = true)
#  |-- transaction_count: long (nullable = false)
#  |-- total_amount: double (nullable = true)
#  |-- avg_amount: double (nullable = true)
#  |-- processing_timestamp: timestamp (nullable = false)
#
# 2025-04-19 15:06:55,115 - INFO -   - Sample size: 3
# 2025-04-19 15:06:55,116 - INFO - Validating dataframe with 2 rules
# 2025-04-19 15:06:59,123 - INFO - Validation rule 'positive_transaction_counts' PASSED - 0 records (0.00%) failed
# 2025-04-19 15:07:00,938 - INFO - Validation rule 'valid_total_amounts' PASSED - 0 records (0.00%) failed
# 2025-04-19 15:07:00,941 - INFO - Checkpoint created:
# {
#   "pipeline_id": "test",
#   "layer": "gold_transaction_type_summary",
#   "version": "test",
#   "timestamp": "2025-04-19T15:07:00.941632",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "de_pipelines.financial_osb_gold_type1_transaction_type_summary",
#       "shape": "[5,17] (approx. row count)",
#       "schema": "root\n |-- transaction_type: string (nullable = true)\n |-- transaction_count: long (nullable = false)\n |-- total_amount: double (nullable = true)\n |-- avg_amount: double (nullable = true)\n |-- processing_timestamp: timestamp (nullable = false)\n",
#       "sample_size": 3,
#       "null_percentages": {
#         "transaction_type": 0.0,
#         "transaction_count": 0.0,
#         "total_amount": 0.0,
#         "avg_amount": 0.0,
#         "processing_timestamp": 0.0
#       },
#       "high_null_columns": {},
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-19T15:06:55.111923"
#     },
#     "validation_results": {
#       "validation_results": {
#         "positive_transaction_counts": {
#           "description": "Transaction counts should be positive",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         },
#         "valid_total_amounts": {
#           "description": "Total amounts should not be negative",
#           "failing_count": 0,
#           "failing_percentage": 0.0,
#           "passed": true
#         }
#       },
#       "sample_size": 3,
#       "sample_ratio": 0.2,
#       "timestamp": "2025-04-19T15:07:00.941632",
#       "all_passed": true
#     },
#     "source_silver_version": 20
#   }
# }
# 2025-04-19 15:07:00,943 - INFO - Gold layer processing completed in 47.34 seconds

# %%
for table_name in gold_dfs.keys():
    gold_dfs[table_name].show(5)
# Out:
# +----------------+----------+-----------------+------------+----------+----------+----------+----------------+--------------------+
# |transaction_date|  category|transaction_count|total_amount|avg_amount|min_amount|max_amount|unique_customers|processing_timestamp|
# +----------------+----------+-----------------+------------+----------+----------+----------+----------------+--------------------+
# |      2023-05-25|      fees|                1|       30.89|     30.89|     30.89|     30.89|               1|2025-04-19 15:07:...|
# |      2023-09-25|    income|                1|      1384.1|    1384.1|    1384.1|    1384.1|               1|2025-04-19 15:07:...|
# |      2023-06-22|      NULL|                1|       64.69|     64.69|     64.69|     64.69|               1|2025-04-19 15:07:...|
# |      2023-12-18|investment|                1|      626.53|    626.53|    626.53|    626.53|               1|2025-04-19 15:07:...|
# |      2023-08-28|   housing|                1|       37.49|     37.49|     37.49|     37.49|               1|2025-04-19 15:07:...|
# +----------------+----------+-----------------+------------+----------+----------+----------+----------------+--------------------+
# only showing top 5 rows
#
# +-----------+-----------------+------------------+------------------+----------------------+---------------------+--------------+--------------------+---------------------------+
# |customer_id|transaction_count|      total_amount|        avg_amount|first_transaction_date|last_transaction_date|category_count|processing_timestamp|days_since_last_transaction|
# +-----------+-----------------+------------------+------------------+----------------------+---------------------+--------------+--------------------+---------------------------+
# | CUST001122|                7| 5558.129999999999| 794.0185714285714|            2023-03-20|           2023-12-22|             3|2025-04-19 15:07:...|                        484|
# | CUST001189|                7|           4529.01| 647.0014285714286|            2023-01-24|           2023-11-23|             3|2025-04-19 15:07:...|                        513|
# | CUST001193|                5|         1937500.9|         387500.18|            2023-02-09|           2023-10-23|             1|2025-04-19 15:07:...|                        544|
# | CUST001098|                4|1725.2000000000003|431.30000000000007|            2023-05-13|           2023-12-20|             1|2025-04-19 15:07:...|                        486|
# | CUST001102|                7|2648.9399999999996|378.41999999999996|            2023-02-02|           2023-12-21|             4|2025-04-19 15:07:...|                        485|
# +-----------+-----------------+------------------+------------------+----------------------+---------------------+--------------+--------------------+---------------------------+
# only showing top 5 rows
#
# +----------------+-----------------+------------------+------------------+--------------------+
# |transaction_type|transaction_count|      total_amount|        avg_amount|processing_timestamp|
# +----------------+-----------------+------------------+------------------+--------------------+
# |         dbposit|                1|            383.95|            383.95|2025-04-19 15:07:...|
# |            NULL|               22|14064.100000000002| 639.2772727272728|2025-04-19 15:07:...|
# |      withdrawal|              137|           73410.6|  535.843795620438|2025-04-19 15:07:...|
# |             fee|              122|           3127.05| 25.63155737704918|2025-04-19 15:07:...|
# |        interest|              129|        2067572.54|16027.694108527132|2025-04-19 15:07:...|
# +----------------+-----------------+------------------+------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ## SCD Type 1:
# ##### Change Data Capture (Merge)

# %% [markdown]
# ##### Inputs/Outputs

# %%
# Change Data Capture
file_list = [
    "financial_transactions_20250414_113413.csv",
    "financial_transactions_20250417_113413.csv"
]

abs_file_list = []
for file in file_list:
    # Join data_dir with filename
    relative_path = os.path.join(data_dir, file)
    # Convert to absolute path
    abs_path = os.path.abspath(relative_path)
    abs_file_list.append(abs_path)

# %% [markdown]
# #### Define: Validation Rules(Same), Transformations(Same), Write Executions (Merge)

# %%
def bronze_writer(df: DataFrame, table_name: str):

    # drop duplicates
    df = (df
            .orderBy(F.col("timestamp").desc())
            .dropDuplicates(subset=["transaction_id", "account_number"])  # Keeps only the latest record
        )

    # Merge the source and target DataFrame
    df.createOrReplaceTempView("source")

    # Execute merge
    spark.sql(f"""
        MERGE INTO {table_name} t
        USING source s
        ON s.transaction_id = t.transaction_id AND s.account_number = t.account_number
        WHEN MATCHED AND (t.amount != s.amount OR t.balance_after != s.balance_after) THEN 
            UPDATE SET *
        WHEN NOT MATCHED THEN
            INSERT *
    """)

    return None

# %%
def silver_writer(df: DataFrame, table_name: str):

    # get max ingested timestamp from silver table
    max_ts = spark.sql(f"SELECT MAX(ingested_timestamp) FROM {table_name}").collect()[0][0]

    # filter incoming data to only include records with a later ingested timestamp
    df = df.filter(F.col("ingested_timestamp") > max_ts)

    # drop duplicates
    df = (df
            .orderBy(F.col("transaction_timestamp").desc())
            .dropDuplicates(subset=["transaction_id", "account_number"])  # Keeps only the latest record
        )

    # Merge the source and target DataFrame
    df.createOrReplaceTempView("source")

    # Execute merge
    spark.sql(f"""
        MERGE INTO {table_name} t
        USING source s
        ON s.transaction_id = t.transaction_id 
            AND s.account_number = t.account_number 
        WHEN MATCHED AND (t.amount != s.amount OR t.balance_after != s.balance_after) THEN 
            UPDATE SET *
        WHEN NOT MATCHED THEN
            INSERT *
    """)

    return None

# %% [markdown]
# #### Running CDC Full Batch Pipeline (Bronze, Silver)

# %%
run_batch_de_pipeline(spark, 'csv', abs_file_list, get_schema(), 
                     bronze_table=bronze_table, silver_table=silver_table, gold_table=None, 
                     bronze_transform=None, silver_transform=silver_transform, gold_transform=None,
                     bronze_writer=bronze_writer, silver_writer=silver_writer, gold_writer=None,
                     bronze_validation_rules=bronze_validation_rules, 
                     silver_validation_rules=silver_validation_rules, 
                     gold_validation_rules=None,
                     pipeline_name='Financial_DE_Pipeline')
# Out:
# 2025-04-19 15:07:04,739 - INFO - --Starting data pipeline execution with ID: Financial_DE_Pipeline_20250419_150704--
# 2025-04-19 15:07:04,741 - INFO - Starting bronze layer processing
# 2025-04-19 15:07:04,798 - INFO - Successfully read CSV data from:
#   - c:\GitHub\DE_Pipelines\data\financial_transactions_20250414_113413.csv
#   - c:\GitHub\DE_Pipelines\data\financial_transactions_20250417_113413.csv
# 2025-04-19 15:07:04,800 - INFO - No transformation function defined
# 2025-04-19 15:07:04,801 - INFO - Writing to bronze table: de_pipelines.financial_osb_bronze_type1
# 2025-04-19 15:07:16,540 - INFO - Successfully wrote to bronze table: de_pipelines.financial_osb_bronze_type1
# 2025-04-19 15:07:16,542 - INFO - Write Metrics:
# [
#   {
#     "numOutputRows": "1540",
#     "numTargetBytesAdded": "59467",
#     "numTargetRowsInserted": "540",
#     "numTargetFilesAdded": "1",
#     "materializeSourceTimeMs": "1719",
#     "numTargetRowsMatchedDeleted": "0",
#     "numTargetFilesRemoved": "1",
#     "numTargetRowsMatchedUpdated": "217",
#     "executionTimeMs": "6203",
#     "numTargetDeletionVectorsUpdated": "0",
#     "numTargetRowsCopied": "783",
#     "rewriteTimeMs": "1544",
#     "numTargetRowsUpdated": "217",
#     "numTargetDeletionVectorsRemoved": "0",
#     "numTargetRowsDeleted": "0",
#     "scanTimeMs": "2827",
#     "numSourceRows": "1500",
#     "numTargetDeletionVectorsAdded": "0",
#     "numTargetChangeFilesAdded": "0",
#     "numTargetRowsNotMatchedBySourceUpdated": "0",
#     "numTargetRowsNotMatchedBySourceDeleted": "0",
#     "numTargetBytesRemoved": "42673"
#   }
# ]
# 2025-04-19 15:07:16,894 - INFO - Running data quality checks for bronze layer
# 2025-04-19 15:07:20,920 - INFO - Data Quality Metrics for bronze layer:
# 2025-04-19 15:07:20,922 - INFO -   - Shape: [15,2750] (approx. row count)
# 2025-04-19 15:07:20,927 - INFO -   - Schema:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- account_number: string (nullable = true)
#  |-- transaction_type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- balance_after: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#  |-- source_file: string (nullable = false)
#  |-- batch_id: string (nullable = false)
#
# 2025-04-19 15:07:20,930 - INFO -   - Sample size: 276
# 2025-04-19 15:07:20,932 - WARNING -   - Columns with high null percentages: {'merchant': 50.36231884057971, 'category': 51.08695652173913}
# 2025-04-19 15:07:20,933 - INFO - Validating dataframe with 3 rules
# 2025-04-19 15:07:21,373 - INFO - Validation rule 'has_transaction_id' FAILED - 5 records (1.81%) failed
# 2025-04-19 15:07:21,481 - INFO - Validation rule 'valid_amount' FAILED - 170 records (61.59%) failed
# 2025-04-19 15:07:21,573 - INFO - Validation rule 'valid_timestamp' FAILED - 5 records (1.81%) failed
# 2025-04-19 15:07:21,576 - INFO - Checkpoint created:
# {
#   "pipeline_id": "Financial_DE_Pipeline_20250419_150704",
#   "layer": "bronze",
#   "version": 27,
#   "timestamp": "2025-04-19T15:07:21.575108",
#   "metadata": {
#     "quality_metrics": {
#       "layer": "bronze",
#       "shape": "[15,2750] (approx. row count)",
#       "schema": "root\n |-- transaction_id: string (nullable = true)\n |-- timestamp: string (nullable = true)\n |-- customer_id: string (nullable = true)\n |-- account_number: string (nullable = true)\n |-- transaction_type: string (nullable = true)\n |-- amount: double (nullable = true)\n |-- currency: string (nullable = true)\n |-- balance_after: double (nullable = true)\n |-- status: string (nullable = true)\n |-- merchant: string (nullable = true)\n |-- category: string (nullable = true)\n |-- location: string (nullable = true)\n |-- ingestion_timestamp: timestamp (nullable = false)\n |-- source_file: string (nullable = false)\n |-- batch_id: string (nullable = false)\n",
#       "sample_size": 276,
#       "null_percentages": {
#         "transaction_id": 1.8115942028985508,
#         "timestamp": 1.8115942028985508,
#         "customer_id": 1.4492753623188406,
#         "account_number": 2.1739130434782608,
#         "transaction_type": 2.898550724637681,
#         "amount": 1.8115942028985508,
#         "currency": 1.4492753623188406,
#         "balance_after": 1.8115942028985508,
#         "status": 1.4492753623188406,
#         "merchant": 50.36231884057971,
#         "category": 51.08695652173913,
#         "location": 0.7246376811594203,
#         "ingestion_timestamp": 0.0,
#         "source_file": 0.0,
#         "batch_id": 0.0
#       },
#       "high_null_columns": {
#         "merchant": 50.36231884057971,
#         "category": 51.08695652173913
#       },
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-19T15:07:20.920718"
#     },
#     "validation_results": {
#       "validation_results": {
#         "has_transaction_id": {
#           "description": "Transaction ID must be present",
#           "failing_count": 5,
#           "failing_percentage": 1.8115942028985508,
#           "passed": false
#         },
#         "valid_amount": {
#           "description": "Amount must be positive if not null",
#           "failing_count": 170,
#           "failing_percentage": 61.59420289855072,
#           "passed": false
#         },
#         "valid_timestamp": {
#           "description": "Timestamp must not be in the future",
#           "failing_count": 5,
#           "failing_percentage": 1.8115942028985508,
#           "passed": false
#         }
#       },
#       "sample_size": 276,
#       "sample_ratio": 0.1,
#       "timestamp": "2025-04-19T15:07:21.575108",
#       "all_passed": false
#     },
#     "source_path": [
#       "c:\\GitHub\\DE_Pipelines\\data\\financial_transactions_20250414_113413.csv",
#       "c:\\GitHub\\DE_Pipelines\\data\\financial_transactions_20250417_113413.csv"
#     ],
#     "duration_seconds": 16.832237243652344
#   }
# }
# 2025-04-19 15:07:21,578 - INFO - Bronze layer processing completed in 16.84 seconds
# 2025-04-19 15:07:21,581 - INFO - Starting table optimization
# 2025-04-19 15:07:23,608 - INFO - Optimized de_pipelines.financial_osb_bronze_type1. Files: before=1, after=1
# 2025-04-19 15:07:23,610 - INFO - --Bronze layer successfully optimized in 2.03 seconds--
# 2025-04-19 15:07:23,612 - INFO - Starting silver layer processing
# 2025-04-19 15:07:23,810 - INFO - Successfully read bronze data version 27
# 2025-04-19 15:07:23,932 - INFO - Transformation function applied
# 2025-04-19 15:07:23,933 - INFO - Writing to silver table: de_pipelines.financial_osb_silver_type1
# 2025-04-19 15:07:24,618 - ERROR - Failed to process silver layer: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `ingested_timestamp` cannot be resolved. Did you mean one of the following? [`ingestion_timestamp`, `processing_timestamp`, `timestamp`, `customer_id`, `source_file`].; line 1 pos 11;
# 'Project [unresolvedalias('MAX('ingested_timestamp), None)]
# +- SubqueryAlias spark_catalog.de_pipelines.financial_osb_silver_type1
#    +- Relation spark_catalog.de_pipelines.financial_osb_silver_type1[transaction_id#179466,timestamp#179467,customer_id#179468,account_number#179469,transaction_type#179470,amount#179471,currency#179472,balance_after#179473,status#179474,merchant#179475,category#179476,location#179477,ingestion_timestamp#179478,source_file#179479,batch_id#179480,transaction_date#179481,transaction_time#179482,year_month#179483,processing_timestamp#179484] parquet
#
# 2025-04-19 15:07:24,625 - ERROR - Pipeline failed after 19.88 seconds: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `ingested_timestamp` cannot be resolved. Did you mean one of the following? [`ingestion_timestamp`, `processing_timestamp`, `timestamp`, `customer_id`, `source_file`].; line 1 pos 11;
# 'Project [unresolvedalias('MAX('ingested_timestamp), None)]
# +- SubqueryAlias spark_catalog.de_pipelines.financial_osb_silver_type1
#    +- Relation spark_catalog.de_pipelines.financial_osb_silver_type1[transaction_id#179466,timestamp#179467,customer_id#179468,account_number#179469,transaction_type#179470,amount#179471,currency#179472,balance_after#179473,status#179474,merchant#179475,category#179476,location#179477,ingestion_timestamp#179478,source_file#179479,batch_id#179480,transaction_date#179481,transaction_time#179482,year_month#179483,processing_timestamp#179484] parquet
#
# 2025-04-19 15:07:25,486 - INFO - Spark session stopped
# {'status': 'failed',
#  'pipeline_id': 'Financial_DE_Pipeline_20250419_150704',
#  'error': "[UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `ingested_timestamp` cannot be resolved. Did you mean one of the following? [`ingestion_timestamp`, `processing_timestamp`, `timestamp`, `customer_id`, `source_file`].; line 1 pos 11;\n'Project [unresolvedalias('MAX('ingested_timestamp), None)]\n+- SubqueryAlias spark_catalog.de_pipelines.financial_osb_silver_type1\n   +- Relation spark_catalog.de_pipelines.financial_osb_silver_type1[transaction_id#179466,timestamp#179467,customer_id#179468,account_number#179469,transaction_type#179470,amount#179471,currency#179472,balance_after#179473,status#179474,merchant#179475,category#179476,location#179477,ingestion_timestamp#179478,source_file#179479,batch_id#179480,transaction_date#179481,transaction_time#179482,year_month#179483,processing_timestamp#179484] parquet\n",
#  'timestamp': '2025-04-19T15:07:24.627058',
#  'duration_seconds': 19.87919569015503,
#  'metrics': {'pipeline_id': 'Financial_DE_Pipeline_20250419_150704',
#   'start_time': '2025-04-19T15:07:04.739871',
#   'stages': {'bronze': {'duration_seconds': 16.839240074157715,
#     'version': 27,
#     'status': 'success'},
#    'bronze_optimize': {'layer': 'bronze',
#     'duration_seconds': 2.02896785736084,
#     'status': 'success'}},
#   'status': 'failed',
#   'end_time': '2025-04-19T15:07:24.625057',
#   'total_duration_seconds': 19.87919569015503,
#   'error': "[UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `ingested_timestamp` cannot be resolved. Did you mean one of the following? [`ingestion_timestamp`, `processing_timestamp`, `timestamp`, `customer_id`, `source_file`].; line 1 pos 11;\n'Project [unresolvedalias('MAX('ingested_timestamp), None)]\n+- SubqueryAlias spark_catalog.de_pipelines.financial_osb_silver_type1\n   +- Relation spark_catalog.de_pipelines.financial_osb_silver_type1[transaction_id#179466,timestamp#179467,customer_id#179468,account_number#179469,transaction_type#179470,amount#179471,currency#179472,balance_after#179473,status#179474,merchant#179475,category#179476,location#179477,ingestion_timestamp#179478,source_file#179479,batch_id#179480,transaction_date#179481,transaction_time#179482,year_month#179483,processing_timestamp#179484] parquet\n"}}
